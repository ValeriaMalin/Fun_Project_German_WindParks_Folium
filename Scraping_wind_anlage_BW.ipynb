# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd
import numpy as np

# %% [markdown]
# ## Scraping the data for the windparks from Wikipedia , Bundesland, one after another:

# %% [markdown]
# ### Baden-Würtemeberg:

# %%
def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %%
#baden-würtemberg windparks

bw_url = "https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Baden-Württemberg"


# use requests.get() method with the provided bw_url
response_bw=requests.get(bw_url).text

# assign the response to a object
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup_bw=BeautifulSoup(response_bw, 'html.parser')

# Use soup.title attribute
print('The title is:')
for title in soup_bw.find_all('title'):
    print(title.get_text())
    
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables=soup_bw.find_all('table')

#to see how many objects in the list

len(html_tables)
# Out:
# The title is:
# Liste der Landkreise in Deutschland – Wikipedia
# 1

# %%
# Let's print the third table and check its content
table_BW = html_tables[0]
print(table_BW)
# Out:
# <table class="wikitable sortable zebra tabelle-kopf-fixiert" style="font-size:95%">
# <tbody><tr bgcolor="#dfdfdf">
# <th width="15%">Name
# </th>
# <th width="6%">Baujahr
# </th>
# <th width="4%">Gesamt-<br/>leistung (MW)
# </th>
# <th width="4%">Anzahl
# </th>
# <th width="20%">Typ (WKA)
# </th>
# <th width="10%">Ort
# </th>
# <th width="4%">Land-<br/>kreis
# </th>
# <th width="7%">Koordinaten
# </th>
# <th width="15%">Projektierer / Betreiber
# </th>
# <th width="15%">Bemerkungen
# </th></tr>
# <tr>
# <td><a href="/wiki/Fraunhofer-Institut_f%C3%BCr_Chemische_Technologie" title="Fraunhofer-Institut für Chemische Technologie">Forschungswindkraftanlage RedoxWind</a><sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </td>
# <td style="text-align:center">2017
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td>Qreon Q82 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Karlsruhe" title="Karlsruhe">Karlsruhe</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Karlsruhe" title="Karlsruhe">KA</a>
# </td>
# <td><span class="plainlinks-print" id="Forschungswindkraftanlage_ICT" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.019166666666666666667_N_8.51766666666666666666666666667_E_region:DE_type:landmark&amp;title=Forschungswindkraftanlage+ICT">49° 1′ 9″ N, 8° 31′ 4″ O</a></span>
# </td>
# <td>Fraunhofer ICT
# </td>
# <td>Forschungsprojekt mit kombiniertem Batteriespeicher
# </td></tr>
# <tr>
# <td>Windkraftanlage <a href="/wiki/Alexanderschanze" title="Alexanderschanze">Alexanderschanze</a><sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">1,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Südwind S70</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Bad_Peterstal-Griesbach" title="Bad Peterstal-Griesbach">Bad Peterstal-Griesbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Alexanderschanze" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.472833333333333_N_8.2685_E_region:DE_type:landmark&amp;title=Windkraftanlage+Alexanderschanze">48° 28′ 22″ N, 8° 16′ 7″ O</a></span>
# </td>
# <td>Schmalz, Windenergieanlage „Bei der Schanz“
# </td>
# <td>errichtet an der <a href="/wiki/Schwarzwaldhochstra%C3%9Fe" title="Schwarzwaldhochstraße">Schwarzwaldhochstraße</a> im Bereich der <a href="/wiki/Alexanderschanze" title="Alexanderschanze">Alexanderschanze</a>
# </td></tr>
# <tr>
# <td>Windkraftanlage Alpirsbach<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup>
# </td>
# <td style="text-align:center">1999<br/>2013
# </td>
# <td style="text-align:center">2,3
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70 E4</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Alpirsbach" title="Alpirsbach">Römlinsdorf</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Freudenstadt" title="Landkreis Freudenstadt">FDS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Alpirsbach-Römlinsdorf" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.333333333333333333_N_8.476_E_region:DE_type:landmark&amp;title=Windkraftanlage+Alpirsbach-R%C3%B6mlinsdorf">48° 20′ 0″ N, 8° 28′ 34″ O</a></span>
# </td>
# <td>Windkraft Römlinsdorf, <a href="/wiki/Stadtwerke_Stuttgart" title="Stadtwerke Stuttgart">Stadtwerke Stuttgart</a>
# </td>
# <td><a href="/wiki/Repowering" title="Repowering">Repowering</a> 2013 (1× <a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70 E4</a> statt 1× <a href="/wiki/Fuhrl%C3%A4nder#Produktpalette" title="Fuhrländer">Fuhrländer FL 300/30</a>)
# </td></tr>
# <tr>
# <td>Windkraftanlage Auenberg<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup>
# </td>
# <td style="text-align:center">1990
# </td>
# <td style="text-align:center">0,095
# </td>
# <td style="text-align:center">1
# </td>
# <td>Reymo DANmark 22 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/H%C3%BCfingen" title="Hüfingen">Hausen vor Wald</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Schwarzwald-Baar-Kreis" title="Schwarzwald-Baar-Kreis">VS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Auenberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.8886666666666666667_N_8.473333333333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Auenberg">47° 53′ 19″ N, 8° 28′ 24″ O</a></span>
# </td>
# <td>Pionier-Windmühle Auenberg
# </td>
# <td>(*); erste kommerziell betriebene Windkraftanlage in Baden-Württemberg, Prototyp und einzige Anlage des Typs
# </td></tr>
# <tr>
# <td><a href="/wiki/Hohwart#Windkraftanlage_auf_dem_Hohwartsattel" title="Hohwart">Windkraftanlage auf dem Hohwartsattel</a><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
# </td>
# <td style="text-align:center">1992
# </td>
# <td style="text-align:center">0,3
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-32_/_E-33" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-33</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Breitnau" title="Breitnau">Breitnau</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Breisgau-Hochschwarzwald" title="Landkreis Breisgau-Hochschwarzwald">FR</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Breitnau" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.937333333333333_N_8.053_E_region:DE_type:landmark&amp;title=Windkraftanlage+Breitnau">47° 56′ 14″ N, 8° 3′ 11″ O</a></span>
# </td>
# <td>Christian Riesterer, Uwe Tischler
# </td>
# <td>(*)
# </td></tr>
# <tr>
# <td>Windkraftanlage Bad Mergentheim
# </td>
# <td style="text-align:center">2002
# </td>
# <td style="text-align:center">0,8
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Nordex N50/800</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Apfelbach_(Bad_Mergentheim)" title="Apfelbach (Bad Mergentheim)">Apfelbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Main-Tauber-Kreis" title="Main-Tauber-Kreis">TBB</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Bad_Mergentheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.43829_N_9.80851_E_region:DE_type:landmark&amp;title=Windkraftanlage+Bad+Mergentheim">49° 26′ 18″ N, 9° 48′ 31″ O</a></span>
# </td>
# <td>Glotter
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Binselberg
# </td>
# <td style="text-align:center">2001
# </td>
# <td style="text-align:center">1,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Fuhrl%C3%A4nder#Produktpalette" title="Fuhrländer">Fuhrländer FL 1000/54</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Gerabronn" title="Gerabronn">Binselberg</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Schw%C3%A4bisch_Hall" title="Landkreis Schwäbisch Hall">SHA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Binselberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.2681266_N_9.926405_E_region:DE-BW_type:landmark&amp;title=Windkraftanlage+Binselberg">49° 16′ 5″ N, 9° 55′ 35″ O</a></span>
# </td>
# <td>Windkraft Binselberg
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Birkenzell<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </td>
# <td style="text-align:center">2014
# </td>
# <td style="text-align:center">0,8
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-53" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-53</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/St%C3%B6dtlen" title="Stödtlen">Birkenzell</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Birkenzell" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.9908333333333333_N_10.25483333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Birkenzell">48° 59′ 27″ N, 10° 15′ 17″ O</a></span>
# </td>
# <td>Alois Erhardt
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Bopfingen
# </td>
# <td style="text-align:center">2020
# </td>
# <td style="text-align:center">0,08
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-17_/_E-18" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-18</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Bopfingen" title="Bopfingen">Bopfingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Bopfingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.84273071986216_N_10.330629113342624_E_region:DE_type:landmark&amp;title=Windkraftanlage+Bopfingen">48° 50′ 34″ N, 10° 19′ 50″ O</a></span>
# </td>
# <td>
# </td>
# <td>errichtet auf 10 Meter Nabenhöhe
# </td></tr>
# <tr>
# <td>Windkraftanlage Bronn<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </td>
# <td style="text-align:center">2015
# </td>
# <td style="text-align:center">0,8
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-53" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-53</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Weikersheim" title="Weikersheim">Bronn</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Main-Tauber-Kreis" title="Main-Tauber-Kreis">TBB</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Bronn" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.43706666666666666667_N_9.9023_E_region:DE_type:landmark&amp;title=Windkraftanlage+Bronn">49° 26′ 13″ N, 9° 54′ 8″ O</a></span>
# </td>
# <td><a class="mw-redirect" href="/wiki/Nordostwasserversorgung" title="Nordostwasserversorgung">NOW</a> Wasserwerk Bronn
# </td>
# <td>Eigenversorgung von Wasserwerk
# </td></tr>
# <tr>
# <td>Windkraftanlage Dauchingen
# </td>
# <td style="text-align:center">2001
# </td>
# <td style="text-align:center">0,85
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V52-850kW</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Dauchingen" title="Dauchingen">Dauchingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Schwarzwald-Baar-Kreis" title="Schwarzwald-Baar-Kreis">VS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Dauchingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.09116666666666666667_N_8.525_E_region:DE_type:landmark&amp;title=Windkraftanlage+Dauchingen">48° 5′ 28″ N, 8° 31′ 30″ O</a></span>
# </td>
# <td>
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Dettenberg
# </td>
# <td style="text-align:center">2014
# </td>
# <td style="text-align:center">0,15
# </td>
# <td style="text-align:center">1
# </td>
# <td>AN Bonus 150/30 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Uttenweiler" title="Uttenweiler">Uttenweiler</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Biberach" title="Landkreis Biberach">BC</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Dettenberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.144059_N_9.644238_E_region:DE_type:landmark&amp;title=Windkraftanlage+Dettenberg">48° 8′ 39″ N, 9° 38′ 39″ O</a></span>
# </td>
# <td>
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Dewangen
# </td>
# <td style="text-align:center">1998
# </td>
# <td style="text-align:center">0,11
# </td>
# <td style="text-align:center">1
# </td>
# <td>Seewind 20/110 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Dewangen" title="Dewangen">Dewangen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Dewangen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.8713_N_10.03606_E_region:DE_type:landmark&amp;title=Windkraftanlage+Dewangen">48° 52′ 17″ N, 10° 2′ 10″ O</a></span>
# </td>
# <td>Haase Geländerbau
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Dornhan
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">1,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 82/1500</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Dornhan" title="Dornhan">Dornhan</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Rottweil" title="Landkreis Rottweil">RW</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Dorhan" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.35833333333333333_N_8.550166666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Dorhan">48° 21′ 30″ N, 8° 33′ 1″ O</a></span>
# </td>
# <td>Theolia, Windreich
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Dornstetten
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">0,85
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V52-850kW</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Dornstetten" title="Dornstetten">Dornstetten</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Freudenstadt" title="Landkreis Freudenstadt">FDS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Dornstetten" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.4669283_N_8.523733_E_region:DE-BW_type:landmark&amp;title=Windkraftanlage+Dornstetten">48° 28′ 1″ N, 8° 31′ 25″ O</a></span>
# </td>
# <td>Windenergieanlage Schmelzle
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Ellenberg
# </td>
# <td style="text-align:center">2001
# </td>
# <td style="text-align:center">1,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-58" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-58</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Ellenberg_(W%C3%BCrttemberg)" title="Ellenberg (Württemberg)">Ellenberg</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Ellenberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.005265_N_10.206953_E_region:DE-BW_type:landmark&amp;title=Windkraftanlage+Ellenberg">49° 0′ 19″ N, 10° 12′ 25″ O</a></span>
# </td>
# <td>Uhl Windkraft
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Jettingen#Windkraftanlagen" title="Jettingen">Windkraftanlage Emmingen</a>
# </td>
# <td style="text-align:center">1993<br/>1995
# </td>
# <td style="text-align:center">0,11
# </td>
# <td style="text-align:center">1
# </td>
# <td>Seewind 20/110 (1×)
# </td>
# <td style="text-align:center"><a class="mw-redirect" href="/wiki/Emmingen_(Nagold)" title="Emmingen (Nagold)">Emmingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Calw" title="Landkreis Calw">CW</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Emmingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.5715_N_8.75_E_region:DE_type:landmark&amp;title=Windkraftanlage+Emmingen">48° 34′ 17″ N, 8° 45′ 0″ O</a></span>
# </td>
# <td>Firma Erlöspool WP Külsheim
# </td>
# <td>eine baugleiche Seewind-Anlage wurde bereits abgebaut. Bestehende Anlage 2022 stillgelegt.
# </td></tr>
# <tr>
# <td>Windkraftanlage Fernhöhe
# </td>
# <td style="text-align:center">1996
# </td>
# <td style="text-align:center">0,25
# </td>
# <td style="text-align:center">1
# </td>
# <td><i><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Nordex N29/250</a></i> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Furtwangen_im_Schwarzwald" title="Furtwangen im Schwarzwald">Furtwangen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Schwarzwald-Baar-Kreis" title="Schwarzwald-Baar-Kreis">VS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Fernhöhe" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.9915_N_8.071166666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Fernh%C3%B6he">47° 59′ 29″ N, 8° 4′ 16″ O</a></span>
# </td>
# <td>Ottmar Bärmann, Heinz Winterhalder
# </td>
# <td>(*)
# </td></tr>
# <tr>
# <td><s>Windkraftanlage Fischerbach</s>
# </td>
# <td style="text-align:center">1997
# </td>
# <td style="text-align:center"><s>0,6</s>
# </td>
# <td style="text-align:center"><s>1</s>
# </td>
# <td><s><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Nordex N43/600</a> (1×)</s>
# </td>
# <td style="text-align:center"><a href="/wiki/Fischerbach" title="Fischerbach">Fischerbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Fischerbach" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.327249_N_8.127534_E_region:DE_type:landmark&amp;title=Windkraftanlage+Fischerbach">48° 19′ 38″ N, 8° 7′ 39″ O</a></span>
# </td>
# <td>RaBe Windenergie
# </td>
# <td>Abbau vermutlich 2008/2009
# </td></tr>
# <tr>
# <td>Windkraftanlage Fröhnd<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup>
# </td>
# <td style="text-align:center">2005
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Fr%C3%B6hnd" title="Fröhnd">Fröhnd</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_L%C3%B6rrach" title="Landkreis Lörrach">LÖ</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Fröhnd" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.75883333333333333_N_7.85283333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Fr%C3%B6hnd">47° 45′ 32″ N, 7° 51′ 10″ O</a></span>
# </td>
# <td>fesa, Ökostrom Freiburg, WP Fröhnd
# </td>
# <td>ursprünglich zwei <a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70</a>, davon eine wegen Unrentabilität 2007 wieder zurückgebaut
# </td></tr>
# <tr>
# <td>Windkraftanlage Fürstenberg
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">1,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Senvion#Frühere_Anlagentypen" title="Senvion">REpower MD77</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/F%C3%BCrstenberg_(H%C3%BCfingen)" title="Fürstenberg (Hüfingen)">Fürstenberg</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Schwarzwald-Baar-Kreis" title="Schwarzwald-Baar-Kreis">VS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Fürstenberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.889032_N_8.583207_E_region:DE-BW_type:landmark&amp;title=Windkraftanlage+F%C3%BCrstenberg">47° 53′ 21″ N, 8° 35′ 0″ O</a></span>
# </td>
# <td>Fürstwind GmbH &amp; Co. KG
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Glatten#Windkraftanlage" title="Glatten">Windkraftanlage Glatten</a><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </td>
# <td style="text-align:center">2000
# </td>
# <td style="text-align:center">0,6
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-40" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-40/6.44</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Glatten" title="Glatten">Glatten</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Freudenstadt" title="Landkreis Freudenstadt">FDS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Glatten" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.4403333333333333333_N_8.524666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Glatten">48° 26′ 25″ N, 8° 31′ 29″ O</a></span>
# </td>
# <td>Schmalz
# </td>
# <td>Am Turm der Anlage befindet sich die Antenne des Senders <i><a href="/wiki/Freies_Radio_Freudenstadt" title="Freies Radio Freudenstadt">Freies Radio Freudenstadt</a></i>
# </td></tr>
# <tr>
# <td><a href="/wiki/Gr%C3%BCner_Heiner#Windkraftanlage" title="Grüner Heiner">Windkraftanlage Grüner Heiner</a>
# </td>
# <td style="text-align:center">2000
# </td>
# <td style="text-align:center">0,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-40" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-40/5.40</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Weilimdorf" title="Weilimdorf">Weilimdorf</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Stuttgart" title="Stuttgart">S</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Grüner_Heiner" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.82516666666666666666667_N_9.0916666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Gr%C3%BCner+Heiner">48° 49′ 31″ N, 9° 5′ 30″ O</a></span>
# </td>
# <td>Gedea Windkraft Grüner Heiner
# </td>
# <td>errichtet auf <a href="/wiki/Schuttberg" title="Schuttberg">Schuttberg</a> an der <a href="/wiki/Bundesautobahn_81" title="Bundesautobahn 81">A 81</a>
# </td></tr>
# <tr>
# <td>Windkraftanlage Herbolzheim<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup>
# </td>
# <td style="text-align:center">1999
# </td>
# <td style="text-align:center">0,6
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/GE_Wind_Energy#Frühere_Anlagen_(Beispiele)" title="GE Wind Energy">Tacke TW 600a</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Herbolzheim" title="Herbolzheim">Herbolzheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Emmendingen" title="Landkreis Emmendingen">EM</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Herbolzheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.223_N_7.75183333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Herbolzheim">48° 13′ 23″ N, 7° 45′ 7″ O</a></span>
# </td>
# <td>Europa-Park Rasthof Herbolzheim
# </td>
# <td>errichtet an der <a href="/wiki/Bundesautobahn_5" title="Bundesautobahn 5">A 5</a>
# </td></tr>
# <tr>
# <td>Windkraftanlage Honhardt
# </td>
# <td style="text-align:center">2007
# </td>
# <td style="text-align:center">2,05
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Senvion#MM-Baureihe" title="Senvion">REpower MM92</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Frankenhardt" title="Frankenhardt">Honhardt</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Schw%C3%A4bisch_Hall" title="Landkreis Schwäbisch Hall">SHA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Honhardt" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.05905_N_10.0561666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Honhardt">49° 3′ 33″ N, 10° 3′ 22″ O</a></span>
# </td>
# <td>Reg.En GmbH, THEOLIA Naturenergien GmbH
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Hornisgrinde#Windpark" title="Hornisgrinde">Windkraftanlage Hornisgrinde</a><sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup>
# </td>
# <td style="text-align:center">1994<br/>1996<br/>2015
# </td>
# <td style="text-align:center">2,3
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70 E4</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Seebach_(Baden)" title="Seebach (Baden)">Seebach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Hornisgrinde" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.6045_N_8.2011666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Hornisgrinde">48° 36′ 16″ N, 8° 12′ 4″ O</a></span>
# </td>
# <td>Peter Griebl
# </td>
# <td><a href="/wiki/Repowering" title="Repowering">Repowering</a> 2015 (1× <a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70 E4</a> statt 2× Seewind 20/110 und 1× Seewind 25/132), höchstgelegene Windkraftanlage Deutschlands (1164 m über NN)<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/Ingersheim_(Neckar)#Windkraftanlage" title="Ingersheim (Neckar)">Windkraftanlage Ingersheim</a><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
# </td>
# <td style="text-align:center">2012
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-82" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-82</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Ingersheim_(Neckar)" title="Ingersheim (Neckar)">Ingersheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Ludwigsburg" title="Landkreis Ludwigsburg">LB</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Ingersheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.971333333333333333_N_9.16966666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Ingersheim">48° 58′ 17″ N, 9° 10′ 11″ O</a></span>
# </td>
# <td>EG Ingersheim
# </td>
# <td>höchste Windkraftanlage in der <a href="/wiki/Region_Stuttgart" title="Region Stuttgart">Region Stuttgart</a> (Nabenhöhe 138 m, Gesamthöhe 179 m)
# </td></tr>
# <tr>
# <td>Windkraftanlage Kallenwald
# </td>
# <td style="text-align:center">2023
# </td>
# <td style="text-align:center">4,2
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-138_EP3" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-138 EP3 E2</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Seelbach_(Schutter)#Schönberg" title="Seelbach (Schutter)">Schönberg</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Kallenwald" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.305449_N_7.974896_E_region:DE_type:landmark&amp;title=Windkraftanlage+Kallenwald">48° 18′ 20″ N, 7° 58′ 30″ O</a></span>
# </td>
# <td>Badenova
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlagen Königseiche
# </td>
# <td style="text-align:center">2023-2024
# </td>
# <td style="text-align:center">9,0
# </td>
# <td style="text-align:center">2
# </td>
# <td><a href="/wiki/Nordex_SE#N149/4000-4500" title="Nordex SE">Nordex N149/4500</a> (2×)
# </td>
# <td style="text-align:center"><a href="/wiki/Ebersbach_an_der_Fils" title="Ebersbach an der Fils">Ebersbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_G%C3%B6ppingen" title="Landkreis Göppingen">GP</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlagen_Königseiche" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.748069_N_9.51073_E_region:DE_type:landmark&amp;title=Windkraftanlagen+K%C3%B6nigseiche">48° 44′ 53″ N, 9° 30′ 39″ O</a></span>
# </td>
# <td>Uhl Windkraft
# </td>
# <td>in Bau
# </td></tr>
# <tr>
# <td>Windkraftanlagen Laichingen
# </td>
# <td style="text-align:center">2023-2024
# </td>
# <td style="text-align:center">7,2
# </td>
# <td style="text-align:center">2
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#4-MW-Plattform" title="Vestas Wind Systems">Vestas V136-3.6MW</a> (2×)
# </td>
# <td style="text-align:center"><a href="/wiki/Laichingen" title="Laichingen">Laichingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Alb-Donau-Kreis" title="Alb-Donau-Kreis">UL</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlagen_Laichingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.524086_N_9.693308_E_region:DE_type:landmark&amp;title=Windkraftanlagen+Laichingen">48° 31′ 27″ N, 9° 41′ 36″ O</a></span>
# </td>
# <td>WPD
# </td>
# <td>in Bau
# </td></tr>
# <tr>
# <td>Windkraftanlage Leibertingen
# </td>
# <td style="text-align:center">1994
# </td>
# <td style="text-align:center">0,6
# </td>
# <td style="text-align:center">1
# </td>
# <td>Markham VS45 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Leibertingen" title="Leibertingen">Leibertingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Sigmaringen" title="Landkreis Sigmaringen">SIG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Leibertingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.05083333333333333_N_9.0231666666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Leibertingen">48° 3′ 3″ N, 9° 1′ 23″ O</a></span>
# </td>
# <td>Bäumlehof Leibertingen
# </td>
# <td>Prototyp der Markham VS45, stand ursprünglich im <a href="/wiki/Windenergiepark_Westk%C3%BCste" title="Windenergiepark Westküste">Windenergiepark Westküste</a>, wo sie abgebaut und 1994 in Leibertingen wieder aufgebaut wurde, seit 2008 wegen defekter Steuerung und Blättern außer Betrieb, Ersatz gegen eine neue 600-kW-Anlage war geplant, Rückbau wegen Repowering geplant
# </td></tr>
# <tr>
# <td>Windkraftanlage Lenzkirch-Kopp
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">1,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Südwind S77</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Lenzkirch" title="Lenzkirch">Lenzkirch</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Breisgau-Hochschwarzwald" title="Landkreis Breisgau-Hochschwarzwald">FR</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Lenzkirch" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.834666666666666666667_N_8.206333333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Lenzkirch">47° 50′ 5″ N, 8° 12′ 23″ O</a></span>
# </td>
# <td>WKA Lenzkirch-Kopp
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Maxau
# </td>
# <td style="text-align:center">1997
# </td>
# <td style="text-align:center">0,11
# </td>
# <td style="text-align:center">1
# </td>
# <td>Seewind 20/110 (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Maxau" title="Maxau">Maxau</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Karlsruhe" title="Karlsruhe">KA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Maxau" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.0338333333333333333_N_8.303_E_region:DE_type:landmark&amp;title=Windkraftanlage+Maxau">49° 2′ 2″ N, 8° 18′ 11″ O</a></span>
# </td>
# <td>Windmühlenberg Windkraftanlage GmbH &amp; Co. KG
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Mengen
# </td>
# <td style="text-align:center">2002
# </td>
# <td style="text-align:center">0,85
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V52-850kW</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Blochingen" title="Blochingen">Blochingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Sigmaringen" title="Landkreis Sigmaringen">SIG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Mengen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.0725_N_9.3553333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Mengen">48° 4′ 21″ N, 9° 21′ 19″ O</a></span>
# </td>
# <td>Rettich Ingenieurbüro
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Mulfingen
# </td>
# <td style="text-align:center">2006
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-82" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-82</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Mulfingen" title="Mulfingen">Hollenbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Hohenlohekreis" title="Hohenlohekreis">KÜN</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Mulfingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.4036666666666666666667_N_9.793_E_region:DE_type:landmark&amp;title=Windkraftanlage+Mulfingen">49° 24′ 13″ N, 9° 47′ 35″ O</a></span>
# </td>
# <td>Beermann Energiesysteme
# </td>
# <td>
# </td></tr>
# <tr>
# <td><a href="/wiki/Schopfloch_(Schwarzwald)#Energie" title="Schopfloch (Schwarzwald)">Windkraftanlage Oberiflingen</a><sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
# </td>
# <td style="text-align:center">2012
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-82" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-82</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Schopfloch_(Schwarzwald)" title="Schopfloch (Schwarzwald)">Oberiflingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Freudenstadt" title="Landkreis Freudenstadt">FDS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Oberiflingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.4023333333333333333_N_8.5551666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Oberiflingen">48° 24′ 8″ N, 8° 33′ 19″ O</a></span>
# </td>
# <td><a href="/wiki/EnBW_Energie_Baden-W%C3%BCrttemberg" title="EnBW Energie Baden-Württemberg">EnBW Windkraftprojekte</a>, ee Rottenburg
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Oberkirch<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">0,055
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">Micon M 55-11</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Nu%C3%9Fbach_(Oberkirch)" title="Nußbach (Oberkirch)">Nußbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Oberkirch" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.546101_N_8.038877_E_region:DE_type:landmark&amp;title=Windkraftanlage+Oberkirch">48° 32′ 46″ N, 8° 2′ 20″ O</a></span>
# </td>
# <td>Max Rohrhirsch
# </td>
# <td>(*); Stand bis 2003 auf <a href="/wiki/Fehmarn" title="Fehmarn">Fehmarn</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Ochsenberg_(K%C3%B6nigsbronn)#Energie" title="Ochsenberg (Königsbronn)">Windkraftanlage Ochsenberg</a>
# </td>
# <td style="text-align:center">2020
# </td>
# <td style="text-align:center">3,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-138_EP3" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-138 EP3</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Ochsenberg_(K%C3%B6nigsbronn)" title="Ochsenberg (Königsbronn)">Ochsenberg</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Heidenheim" title="Landkreis Heidenheim">HDH</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Ochsenberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.75282_N_10.15975_E_region:DE_type:landmark&amp;title=Windkraftanlage+Ochsenberg">48° 45′ 10″ N, 10° 9′ 35″ O</a></span>
# </td>
# <td><a class="mw-redirect" href="/wiki/EnBW" title="EnBW">EnBW</a>
# </td>
# <td>Ende September bis Anfang Oktober 2023 wurde der Rotorträger ausgetauscht.
# </td></tr>
# <tr>
# <td>Windkraftanlage Rohrhardsberg<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup>
# </td>
# <td style="text-align:center">2003
# </td>
# <td style="text-align:center">1,8
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-66" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-66/18.70</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Elzach" title="Elzach">Yach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Emmendingen" title="Landkreis Emmendingen">EM</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Rohrhardsberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.135333333333333333_N_8.1206666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Rohrhardsberg">48° 8′ 7″ N, 8° 7′ 14″ O</a></span>
# </td>
# <td>fesa, Ökostrom Freiburg
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Schweighausen<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup>
# </td>
# <td style="text-align:center">1997<br/>1998<br/>2013
# </td>
# <td style="text-align:center">3,05
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-101" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-101</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Schuttertal#Schweighausen" title="Schuttertal">Schweighausen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Schweighausen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.22633333333333333_N_7.97516666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Schweighausen">48° 13′ 35″ N, 7° 58′ 31″ O</a></span>
# </td>
# <td>fesa, Stadtwerke Emmendingen
# </td>
# <td><a href="/wiki/Repowering" title="Repowering">Repowering</a> 2013 (1× <a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-101" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-101</a> statt 1× Seewind 52/750 und 1× Seewind 20/110)
# </td></tr>
# <tr>
# <td>Windkraftanlage Sontheim
# </td>
# <td style="text-align:center">1996
# </td>
# <td style="text-align:center">0,08
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Lagerwey_(Windkraftanlagenhersteller)#Frühere_Anlagentypen" title="Lagerwey (Windkraftanlagenhersteller)">Lagerwey LW 18/80</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Sontheim_an_der_Brenz" title="Sontheim an der Brenz">Sontheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Heidenheim" title="Landkreis Heidenheim">HDH</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Sontheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.53633333333333333_N_10.3_E_region:DE_type:landmark&amp;title=Windkraftanlage+Sontheim">48° 32′ 11″ N, 10° 18′ 0″ O</a></span>
# </td>
# <td>
# </td>
# <td>Zweiflügler
# </td></tr>
# <tr>
# <td>Windkraftanlage Streuberg
# </td>
# <td style="text-align:center">2006
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-70" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-70</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Kre%C3%9Fberg" title="Kreßberg">Bergertshofen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Schw%C3%A4bisch_Hall" title="Landkreis Schwäbisch Hall">SHA</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Streuberg" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.1576666666666666666667_N_10.21683333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Streuberg">49° 9′ 28″ N, 10° 13′ 1″ O</a></span>
# </td>
# <td>
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Ummendorf
# </td>
# <td style="text-align:center">2001
# </td>
# <td style="text-align:center">0,9
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 52/900</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Ummendorf_(bei_Biberach)" title="Ummendorf (bei Biberach)">Ummendorf</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Biberach" title="Landkreis Biberach">BC</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Ummendorf" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.056166666666666666667_N_9.856_E_region:DE_type:landmark&amp;title=Windkraftanlage+Ummendorf">48° 3′ 22″ N, 9° 51′ 22″ O</a></span>
# </td>
# <td>Bürgerwindrad Ummendorf
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Unterkessach<sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[21]</a></sup>
# </td>
# <td style="text-align:center">2011
# </td>
# <td style="text-align:center">2,0
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#2-MW-Plattform" title="Vestas Wind Systems">Vestas V90-2.0MW</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Unterkessach" title="Unterkessach">Unterkessach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Heilbronn" title="Landkreis Heilbronn">HN</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Unterkessach" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.3566666666666666667_N_9.440333333333333333333333_E_region:DE_type:landmark&amp;title=Windkraftanlage+Unterkessach">49° 21′ 24″ N, 9° 26′ 25″ O</a></span>
# </td>
# <td>Reg.En GmbH, seebaWIND
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Untermusbach
# </td>
# <td style="text-align:center">2002
# </td>
# <td style="text-align:center">1,5
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Südwind S77</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Freudenstadt" title="Freudenstadt">Untermusbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Freudenstadt" title="Landkreis Freudenstadt">FDS</a>
# </td>
# <td><span class="plainlinks-print" id="Windkraftanlage_Untermusbach" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.521833333333333333_N_8.4336666666666666666667_E_region:DE_type:landmark&amp;title=Windkraftanlage+Untermusbach">48° 31′ 19″ N, 8° 26′ 1″ O</a></span>
# </td>
# <td>WKA Kaltenbach
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windkraftanlage Veringenstadt
# </td>
# <td style="text-align:center">2022
# </td>
# <td style="text-align:center">4,2
# </td>
# <td style="text-align:center">1
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-138_EP3" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-138 EP3 E2</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Veringenstadt" title="Veringenstadt">Veringenstadt</a>
# </td>
# ...
# </td>
# <td style="text-align:center"><a href="/wiki/Ortenaukreis" title="Ortenaukreis">OG</a><br/><a href="/wiki/Landkreis_Rottweil" title="Landkreis Rottweil">RW</a><br/><a href="/wiki/Schwarzwald-Baar-Kreis" title="Schwarzwald-Baar-Kreis">VS</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Tennenbronn" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.186_N_8.303666666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Tennenbronn">48° 11′ 10″ N, 8° 18′ 13″ O</a></span>
# </td>
# <td>Windkraft Tennenbronn; vento ludens, dge Wind Brogen, Solarcomplex
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Tomerdingen-Bermaringen<sup class="reference" id="cite_ref-119"><a href="#cite_note-119">[119]</a></sup><sup class="reference" id="cite_ref-120"><a href="#cite_note-120">[120]</a></sup> (Windpark Keltische Schanze)
# </td>
# <td style="text-align:center">2007<br/>2013<br/>2017
# </td>
# <td style="text-align:center">21,9
# </td>
# <td style="text-align:center">11
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V82-1.5MW</a> (5×)<br/><a href="/wiki/Nordex_SE#N117/2400" title="Nordex SE">Nordex N117/2400</a> (6×)
# </td>
# <td style="text-align:center"><a href="/wiki/Tomerdingen" title="Tomerdingen">Tomerdingen</a><br/><a href="/wiki/Bermaringen" title="Bermaringen">Bermaringen</a><br/><a href="/wiki/Temmenhausen" title="Temmenhausen">Temmenhausen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Alb-Donau-Kreis" title="Alb-Donau-Kreis">UL</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Tomerdingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.470236_N_9.863394_E_region:DE_type:landmark&amp;title=Windpark+Tomerdingen">48° 28′ 13″ N, 9° 51′ 48″ O</a></span>
# </td>
# <td><a class="mw-redirect" href="/wiki/Greenpeace_Energy" title="Greenpeace Energy">Planet Energy</a>, Solarinvest AG; Efi Wind, THEOLIA Naturenergien GmbH, Windreich
# </td>
# <td>errichtet an der <a href="/wiki/Bundesautobahn_8" title="Bundesautobahn 8">A 8</a>
# </td></tr>
# <tr>
# <td>Windpark Verenafohren<sup class="reference" id="cite_ref-121"><a href="#cite_note-121">[121]</a></sup>
# </td>
# <td style="text-align:center">2017
# </td>
# <td style="text-align:center">9,9
# </td>
# <td style="text-align:center">3
# </td>
# <td><a href="/wiki/Nordex_SE#N131/3300" title="Nordex SE">Nordex N131/3300</a> (3×)
# </td>
# <td style="text-align:center"><a href="/wiki/Wiechs_am_Randen" title="Wiechs am Randen">Wiechs am Randen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Konstanz" title="Landkreis Konstanz">KN</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Verenafohren" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=47.7685_N_8.6255_E_region:DE_type:landmark&amp;title=Windpark+Verenafohren">47° 46′ 7″ N, 8° 37′ 32″ O</a></span>
# </td>
# <td>hegauwind
# </td>
# <td>errichtet direkt an der Schweizer Grenze
# </td></tr>
# <tr>
# <td><a href="/wiki/Aalen#Windpark_Waldhausen" title="Aalen">Windpark Waldhausen</a><sup class="reference" id="cite_ref-122"><a href="#cite_note-122">[122]</a></sup>
# </td>
# <td style="text-align:center">2007<br/>2017
# </td>
# <td style="text-align:center">30,85
# </td>
# <td style="text-align:center">12
# </td>
# <td><a href="/wiki/Senvion#MM-Baureihe" title="Senvion">REpower MM92</a> (7×)<br/><a href="/wiki/Vestas_Wind_Systems#4-MW-Plattform" title="Vestas Wind Systems">Vestas V126-3.3MW</a> (5×)
# </td>
# <td style="text-align:center"><a href="/wiki/Waldhausen_(Aalen)" title="Waldhausen (Aalen)">Waldhausen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Waldhausen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.8355_N_10.206666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Waldhausen">48° 50′ 8″ N, 10° 12′ 24″ O</a></span>
# </td>
# <td>Uhl Windkraft; ENBW
# </td>
# <td>errichtet an der <a href="/wiki/Bundesautobahn_7" title="Bundesautobahn 7">A 7</a>
# </td></tr>
# <tr>
# <td>Windpark Waldmössingen<sup class="reference" id="cite_ref-123"><a href="#cite_note-123">[123]</a></sup>
# </td>
# <td style="text-align:center">2002
# </td>
# <td style="text-align:center">3,6
# </td>
# <td style="text-align:center">4
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 52/900</a> (4×)
# </td>
# <td style="text-align:center"><a href="/wiki/Waldm%C3%B6ssingen" title="Waldmössingen">Waldmössingen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Rottweil" title="Landkreis Rottweil">RW</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Waldmössingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.2576666666666667_N_8.5045_E_region:DE_type:landmark&amp;title=Windpark+Waldm%C3%B6ssingen">48° 15′ 28″ N, 8° 30′ 16″ O</a></span>
# </td>
# <td>Theolia, <a href="/wiki/Windreich" title="Windreich">Windreich</a>, WP Hummelbühl
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Wallhausen<sup class="reference" id="cite_ref-124"><a href="#cite_note-124">[124]</a></sup>
# </td>
# <td style="text-align:center">2011<br/>2018
# </td>
# <td style="text-align:center">7,6
# </td>
# <td style="text-align:center">4
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-53" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-53</a> (2×)<br/><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-115" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-115</a> (2×)
# </td>
# <td style="text-align:center"><a href="/wiki/Wallhausen_(W%C3%BCrttemberg)" title="Wallhausen (Württemberg)">Schainbach</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Schw%C3%A4bisch_Hall" title="Landkreis Schwäbisch Hall">SHA</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Wallhausen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.23633333333333333_N_10.0525_E_region:DE_type:landmark&amp;title=Windpark+Wallhausen">49° 14′ 11″ N, 10° 3′ 9″ O</a></span>
# </td>
# <td>Stollmeier
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Weilermerkingen-Ohmenheim
# </td>
# <td style="text-align:center">2007<br/>2016
# </td>
# <td style="text-align:center">22,65
# </td>
# <td style="text-align:center">9
# </td>
# <td><a href="/wiki/Senvion#MM-Baureihe" title="Senvion">REpower MM92</a> (3×)<br/><a href="/wiki/GE_Wind_Energy#2-MW-Plattform" title="GE Wind Energy">GE Wind Energy 2.75-120</a> (6×)
# </td>
# <td style="text-align:center"><a href="/wiki/Dorfmerkingen" title="Dorfmerkingen">Weilermerkingen</a><br/><a href="/wiki/Neresheim" title="Neresheim">Ohmenheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Ostalbkreis" title="Ostalbkreis">AA</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Weilmerkingen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.791_N_10.35033333333333333_E_region:DE_type:landmark&amp;title=Windpark+Weilmerkingen">48° 47′ 28″ N, 10° 21′ 1″ O</a></span>
# </td>
# <td>WP Weilermerkingen; WP Ohmenheim
# </td>
# <td>Am 17. Juli 2018 wurde durch einen Blitzschlag ein Rotorblatt eines der REpower-Anlagen beschädigt<sup class="reference" id="cite_ref-125"><a href="#cite_note-125">[125]</a></sup>
# </td></tr>
# <tr>
# <td>Windpark Weißbach<sup class="reference" id="cite_ref-126"><a href="#cite_note-126">[126]</a></sup>
# </td>
# <td style="text-align:center">2001<br/>2016
# </td>
# <td style="text-align:center">18,5
# </td>
# <td style="text-align:center">7
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 60/1000</a> (2×)<br/><a href="/wiki/Vestas_Wind_Systems#4-MW-Plattform" title="Vestas Wind Systems">Vestas V126-3.3MW</a> (5×)
# </td>
# <td style="text-align:center"><a href="/wiki/Crispenhofen" title="Crispenhofen">Crispenhofen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Hohenlohekreis" title="Hohenlohekreis">KÜN</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Weißbach" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.323_N_9.5751666666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Wei%C3%9Fbach">49° 19′ 23″ N, 9° 34′ 31″ O</a></span>
# </td>
# <td>Specht Windkraft, Bürger-WP Hohenlohe
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Wenkheim<sup class="reference" id="cite_ref-127"><a href="#cite_note-127">[127]</a></sup>
# </td>
# <td style="text-align:center">2007
# </td>
# <td style="text-align:center">18,0
# </td>
# <td style="text-align:center">9
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V80-2.0MW</a> (9×)
# </td>
# <td style="text-align:center"><a href="/wiki/Wenkheim_(Werbach)" title="Wenkheim (Werbach)">Wenkheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Main-Tauber-Kreis" title="Main-Tauber-Kreis">TBB</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Wenkheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.708666666666666666666667_N_9.685166666666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Wenkheim">49° 42′ 31″ N, 9° 41′ 7″ O</a></span>
# </td>
# <td><a href="/wiki/Energiequelle" title="Energiequelle">Energiequelle</a>, UMaAG
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Werbachhausen<sup class="reference" id="cite_ref-windreich.ag_65-1"><a href="#cite_note-windreich.ag-65">[65]</a></sup>
# </td>
# <td style="text-align:center">2012
# </td>
# <td style="text-align:center">6,3
# </td>
# <td style="text-align:center">3
# </td>
# <td><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-82" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-82</a> (2×)<br/><a href="/wiki/Liste_der_Windkraftanlagentypen_von_Enercon#E-82_E2" title="Liste der Windkraftanlagentypen von Enercon">Enercon E-82 E2</a> (1×)
# </td>
# <td style="text-align:center"><a href="/wiki/Werbachhausen" title="Werbachhausen">Werbachhausen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Main-Tauber-Kreis" title="Main-Tauber-Kreis">TBB</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Werbachhausen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.671_N_9.7033333333333333333_E_region:DE_type:landmark&amp;title=Windpark+Werbachhausen">49° 40′ 16″ N, 9° 42′ 12″ O</a></span>
# </td>
# <td><a href="/wiki/Windreich" title="Windreich">Windreich</a>, Energie Bals, W-I-N-D Energien
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Werdeck
# </td>
# <td style="text-align:center">2017
# </td>
# <td style="text-align:center">9,9
# </td>
# <td style="text-align:center">3
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#4-MW-Plattform" title="Vestas Wind Systems">Vestas V126-3.3MW</a> (3×)
# </td>
# <td style="text-align:center"><a href="/wiki/Rot_am_See" title="Rot am See">Werdeck</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_Schw%C3%A4bisch_Hall" title="Landkreis Schwäbisch Hall">SHA</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Werdeck" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.23183_N_9.94678_E_region:DE_type:landmark&amp;title=Windpark+Werdeck">49° 13′ 55″ N, 9° 56′ 48″ O</a></span>
# </td>
# <td>
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Westerheim<sup class="reference" id="cite_ref-128"><a href="#cite_note-128">[128]</a></sup>
# </td>
# <td style="text-align:center">1998<br/>2001<br/>2002<br/>2020
# </td>
# <td style="text-align:center">4,5
# </td>
# <td style="text-align:center">3
# </td>
# <td><a href="/wiki/Nordex_SE#Früher_gefertigte_Anlagen" title="Nordex SE">Südwind S70</a> (1×)<br/><a href="/wiki/Senvion#Frühere_Anlagentypen" title="Senvion">REpower MD77</a> (2×)
# </td>
# <td style="text-align:center"><a href="/wiki/Westerheim_(W%C3%BCrttemberg)" title="Westerheim (Württemberg)">Westerheim</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Alb-Donau-Kreis" title="Alb-Donau-Kreis">UL</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Westerheim" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.5341666666666666666667_N_9.62566666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Westerheim">48° 32′ 3″ N, 9° 37′ 32″ O</a></span>
# </td>
# <td>Alb-Windkraft, <a href="/wiki/EnBW_Energie_Baden-W%C3%BCrttemberg" title="EnBW Energie Baden-Württemberg">EnBW Energie Baden-Württemberg</a>
# </td>
# <td>eine <a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 48/600</a> 2020 abgebaut
# </td></tr>
# <tr>
# <td>Windpark Wiesensteig<sup class="reference" id="cite_ref-129"><a href="#cite_note-129">[129]</a></sup>
# </td>
# <td style="text-align:center">1999
# </td>
# <td style="text-align:center">4,5
# </td>
# <td style="text-align:center">6
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Micon" title="Vestas Wind Systems">NEG Micon NM 48/750</a> (6×)
# </td>
# <td style="text-align:center"><a href="/wiki/Wiesensteig" title="Wiesensteig">Wiesensteig</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Landkreis_G%C3%B6ppingen" title="Landkreis Göppingen">GP</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Wiesensteig" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=48.5515_N_9.619666666666666666667_E_region:DE_type:landmark&amp;title=Windpark+Wiesensteig">48° 33′ 5″ N, 9° 37′ 11″ O</a></span>
# </td>
# <td>SoWiTec
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Windpark Wittighausen<sup class="reference" id="cite_ref-130"><a href="#cite_note-130">[130]</a></sup>
# </td>
# <td style="text-align:center">2002
# </td>
# <td style="text-align:center">5,94
# </td>
# <td style="text-align:center">9
# </td>
# <td><a href="/wiki/Vestas_Wind_Systems#Frühere_Anlagentypen_(Beispiele)" title="Vestas Wind Systems">Vestas V47-660kW</a> (9×)
# </td>
# <td style="text-align:center"><a href="/wiki/Wittighausen" title="Wittighausen">Unterwittighausen</a>
# </td>
# <td style="text-align:center"><a href="/wiki/Main-Tauber-Kreis" title="Main-Tauber-Kreis">TBB</a>
# </td>
# <td><span class="plainlinks-print" id="Windpark_Wittighausen" title="Koordinate"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Liste_von_Windkraftanlagen_in_Baden-W%C3%BCrttemberg&amp;language=de&amp;params=49.619667_N_9.802667_E_region:DE_type:landmark&amp;title=Windpark+Wittighausen">49° 37′ 11″ N, 9° 48′ 10″ O</a></span>
# </td>
# <td>UMaAG
# </td>
# <td>Am 17.3.2019 brach durch das Sturmtief Eberhard bei einer Anlage ein Flügel ab. Die Anlage wurde nicht repariert. Eine weitere Anlage seither außer Betrieb.
# </td></tr></tbody></table>

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_BW.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)

# %%
print(column_names)
# Out:
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]

# %%
rows=[]
table_rows = table_BW.find_all('tr')    

for row in table_rows:
    td = row.find_all('td')
    row = [row.text for row in td]
    rows.append(row)

# %%
rows
# Out:
# [[],
#  ['Forschungswindkraftanlage RedoxWind[4]\n',
#   '2017\n',
#   '2,0\n',
#   '1\n',
#   'Qreon Q82 (1×)\n',
#   'Karlsruhe\n',
#   'KA\n',
#   '49°\xa01′\xa09″\xa0N, 8°\xa031′\xa04″\xa0O\n',
#   'Fraunhofer ICT\n',
#   'Forschungsprojekt mit kombiniertem Batteriespeicher\n'],
#  ['Windkraftanlage Alexanderschanze[5]\n',
#   '2003\n',
#   '1,5\n',
#   '1\n',
#   'Südwind S70 (1×)\n',
#   'Bad Peterstal-Griesbach\n',
#   'OG\n',
#   '48°\xa028′\xa022″\xa0N, 8°\xa016′\xa07″\xa0O\n',
#   'Schmalz, Windenergieanlage „Bei der Schanz“\n',
#   'errichtet an der Schwarzwaldhochstraße im Bereich der Alexanderschanze\n'],
#  ['Windkraftanlage Alpirsbach[6]\n',
#   '19992013\n',
#   '2,3\n',
#   '1\n',
#   'Enercon E-70 E4 (1×)\n',
#   'Römlinsdorf\n',
#   'FDS\n',
#   '48°\xa020′\xa00″\xa0N, 8°\xa028′\xa034″\xa0O\n',
#   'Windkraft Römlinsdorf, Stadtwerke Stuttgart\n',
#   'Repowering 2013 (1× Enercon E-70 E4 statt 1× Fuhrländer FL 300/30)\n'],
#  ['Windkraftanlage Auenberg[7]\n',
#   '1990\n',
#   '0,095\n',
#   '1\n',
#   'Reymo DANmark 22 (1×)\n',
#   'Hausen vor Wald\n',
#   'VS\n',
#   '47°\xa053′\xa019″\xa0N, 8°\xa028′\xa024″\xa0O\n',
#   'Pionier-Windmühle Auenberg\n',
#   '(*); erste kommerziell betriebene Windkraftanlage in Baden-Württemberg, Prototyp und einzige Anlage des Typs\n'],
#  ['Windkraftanlage auf dem Hohwartsattel[8]\n',
#   '1992\n',
#   '0,3\n',
#   '1\n',
#   'Enercon E-33 (1×)\n',
#   'Breitnau\n',
#   'FR\n',
#   '47°\xa056′\xa014″\xa0N, 8°\xa03′\xa011″\xa0O\n',
#   'Christian Riesterer, Uwe Tischler\n',
#   '(*)\n'],
#  ['Windkraftanlage Bad Mergentheim\n',
#   '2002\n',
#   '0,8\n',
#   '1\n',
#   'Nordex N50/800 (1×)\n',
#   'Apfelbach\n',
#   'TBB\n',
#   '49°\xa026′\xa018″\xa0N, 9°\xa048′\xa031″\xa0O\n',
#   'Glotter\n',
#   '\n'],
#  ['Windkraftanlage Binselberg\n',
#   '2001\n',
#   '1,0\n',
#   '1\n',
#   'Fuhrländer FL 1000/54 (1×)\n',
#   'Binselberg\n',
#   'SHA\n',
#   '49°\xa016′\xa05″\xa0N, 9°\xa055′\xa035″\xa0O\n',
#   'Windkraft Binselberg\n',
#   '\n'],
#  ['Windkraftanlage Birkenzell[9]\n',
#   '2014\n',
#   '0,8\n',
#   '1\n',
#   'Enercon E-53 (1×)\n',
#   'Birkenzell\n',
#   'AA\n',
#   '48°\xa059′\xa027″\xa0N, 10°\xa015′\xa017″\xa0O\n',
#   'Alois Erhardt\n',
#   '\n'],
#  ['Windkraftanlage Bopfingen\n',
#   '2020\n',
#   '0,08\n',
#   '1\n',
#   'Enercon E-18 (1×)\n',
#   'Bopfingen\n',
#   'AA\n',
#   '48°\xa050′\xa034″\xa0N, 10°\xa019′\xa050″\xa0O\n',
#   '\n',
#   'errichtet auf 10 Meter Nabenhöhe\n'],
#  ['Windkraftanlage Bronn[10]\n',
#   '2015\n',
#   '0,8\n',
#   '1\n',
#   'Enercon E-53 (1×)\n',
#   'Bronn\n',
#   'TBB\n',
#   '49°\xa026′\xa013″\xa0N, 9°\xa054′\xa08″\xa0O\n',
#   'NOW Wasserwerk Bronn\n',
#   'Eigenversorgung von Wasserwerk\n'],
#  ['Windkraftanlage Dauchingen\n',
#   '2001\n',
#   '0,85\n',
#   '1\n',
#   'Vestas V52-850kW (1×)\n',
#   'Dauchingen\n',
#   'VS\n',
#   '48°\xa05′\xa028″\xa0N, 8°\xa031′\xa030″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windkraftanlage Dettenberg\n',
#   '2014\n',
#   '0,15\n',
#   '1\n',
#   'AN Bonus 150/30 (1×)\n',
#   'Uttenweiler\n',
#   'BC\n',
#   '48°\xa08′\xa039″\xa0N, 9°\xa038′\xa039″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windkraftanlage Dewangen\n',
#   '1998\n',
#   '0,11\n',
#   '1\n',
#   'Seewind 20/110 (1×)\n',
#   'Dewangen\n',
#   'AA\n',
#   '48°\xa052′\xa017″\xa0N, 10°\xa02′\xa010″\xa0O\n',
#   'Haase Geländerbau\n',
#   '\n'],
#  ['Windkraftanlage Dornhan\n',
#   '2003\n',
#   '1,5\n',
#   '1\n',
#   'NEG Micon NM 82/1500 (1×)\n',
#   'Dornhan\n',
#   'RW\n',
#   '48°\xa021′\xa030″\xa0N, 8°\xa033′\xa01″\xa0O\n',
#   'Theolia, Windreich\n',
#   '\n'],
#  ['Windkraftanlage Dornstetten\n',
#   '2003\n',
#   '0,85\n',
#   '1\n',
#   'Vestas V52-850kW (1×)\n',
#   'Dornstetten\n',
#   'FDS\n',
#   '48°\xa028′\xa01″\xa0N, 8°\xa031′\xa025″\xa0O\n',
#   'Windenergieanlage Schmelzle\n',
#   '\n'],
#  ['Windkraftanlage Ellenberg\n',
#   '2001\n',
#   '1,0\n',
#   '1\n',
#   'Enercon E-58 (1×)\n',
#   'Ellenberg\n',
#   'AA\n',
#   '49°\xa00′\xa019″\xa0N, 10°\xa012′\xa025″\xa0O\n',
#   'Uhl Windkraft\n',
#   '\n'],
#  ['Windkraftanlage Emmingen\n',
#   '19931995\n',
#   '0,11\n',
#   '1\n',
#   'Seewind 20/110 (1×)\n',
#   'Emmingen\n',
#   'CW\n',
#   '48°\xa034′\xa017″\xa0N, 8°\xa045′\xa00″\xa0O\n',
#   'Firma Erlöspool WP Külsheim\n',
#   'eine baugleiche Seewind-Anlage wurde bereits abgebaut. Bestehende Anlage 2022 stillgelegt.\n'],
#  ['Windkraftanlage Fernhöhe\n',
#   '1996\n',
#   '0,25\n',
#   '1\n',
#   'Nordex N29/250 (1×)\n',
#   'Furtwangen\n',
#   'VS\n',
#   '47°\xa059′\xa029″\xa0N, 8°\xa04′\xa016″\xa0O\n',
#   'Ottmar Bärmann, Heinz Winterhalder\n',
#   '(*)\n'],
#  ['Windkraftanlage Fischerbach\n',
#   '1997\n',
#   '0,6\n',
#   '1\n',
#   'Nordex N43/600 (1×)\n',
#   'Fischerbach\n',
#   'OG\n',
#   '48°\xa019′\xa038″\xa0N, 8°\xa07′\xa039″\xa0O\n',
#   'RaBe Windenergie\n',
#   'Abbau vermutlich 2008/2009\n'],
#  ['Windkraftanlage Fröhnd[11]\n',
#   '2005\n',
#   '2,0\n',
#   '1\n',
#   'Enercon E-70 (1×)\n',
#   'Fröhnd\n',
#   'LÖ\n',
#   '47°\xa045′\xa032″\xa0N, 7°\xa051′\xa010″\xa0O\n',
#   'fesa, Ökostrom Freiburg, WP Fröhnd\n',
#   'ursprünglich zwei Enercon E-70, davon eine wegen Unrentabilität 2007 wieder zurückgebaut\n'],
#  ['Windkraftanlage Fürstenberg\n',
#   '2003\n',
#   '1,5\n',
#   '1\n',
#   'REpower MD77 (1×)\n',
#   'Fürstenberg\n',
#   'VS\n',
#   '47°\xa053′\xa021″\xa0N, 8°\xa035′\xa00″\xa0O\n',
#   'Fürstwind GmbH & Co. KG\n',
#   '\n'],
#  ['Windkraftanlage Glatten[12]\n',
#   '2000\n',
#   '0,6\n',
#   '1\n',
#   'Enercon E-40/6.44 (1×)\n',
#   'Glatten\n',
#   'FDS\n',
#   '48°\xa026′\xa025″\xa0N, 8°\xa031′\xa029″\xa0O\n',
#   'Schmalz\n',
#   'Am Turm der Anlage befindet sich die Antenne des Senders Freies Radio Freudenstadt\n'],
#  ['Windkraftanlage Grüner Heiner\n',
#   '2000\n',
#   '0,5\n',
#   '1\n',
#   'Enercon E-40/5.40 (1×)\n',
#   'Weilimdorf\n',
#   'S\n',
#   '48°\xa049′\xa031″\xa0N, 9°\xa05′\xa030″\xa0O\n',
#   'Gedea Windkraft Grüner Heiner\n',
#   'errichtet auf Schuttberg an der A\xa081\n'],
#  ['Windkraftanlage Herbolzheim[13]\n',
#   '1999\n',
#   '0,6\n',
#   '1\n',
#   'Tacke TW 600a (1×)\n',
#   'Herbolzheim\n',
#   'EM\n',
#   '48°\xa013′\xa023″\xa0N, 7°\xa045′\xa07″\xa0O\n',
#   'Europa-Park Rasthof Herbolzheim\n',
#   'errichtet an der A\xa05\n'],
#  ['Windkraftanlage Honhardt\n',
#   '2007\n',
#   '2,05\n',
#   '1\n',
#   'REpower MM92 (1×)\n',
#   'Honhardt\n',
#   'SHA\n',
#   '49°\xa03′\xa033″\xa0N, 10°\xa03′\xa022″\xa0O\n',
#   'Reg.En GmbH, THEOLIA Naturenergien GmbH\n',
#   '\n'],
#  ['Windkraftanlage Hornisgrinde[14]\n',
#   '199419962015\n',
#   '2,3\n',
#   '1\n',
#   'Enercon E-70 E4 (1×)\n',
#   'Seebach\n',
#   'OG\n',
#   '48°\xa036′\xa016″\xa0N, 8°\xa012′\xa04″\xa0O\n',
#   'Peter Griebl\n',
#   'Repowering 2015 (1× Enercon E-70 E4 statt 2× Seewind 20/110 und 1× Seewind 25/132), höchstgelegene Windkraftanlage Deutschlands (1164 m über NN)[15]\n'],
#  ['Windkraftanlage Ingersheim[16]\n',
#   '2012\n',
#   '2,0\n',
#   '1\n',
#   'Enercon E-82 (1×)\n',
#   'Ingersheim\n',
#   'LB\n',
#   '48°\xa058′\xa017″\xa0N, 9°\xa010′\xa011″\xa0O\n',
#   'EG Ingersheim\n',
#   'höchste Windkraftanlage in der Region Stuttgart (Nabenhöhe 138\xa0m, Gesamthöhe 179\xa0m)\n'],
#  ['Windkraftanlage Kallenwald\n',
#   '2023\n',
#   '4,2\n',
#   '1\n',
#   'Enercon E-138 EP3 E2 (1×)\n',
#   'Schönberg\n',
#   'OG\n',
#   '48°\xa018′\xa020″\xa0N, 7°\xa058′\xa030″\xa0O\n',
#   'Badenova\n',
#   '\n'],
#  ['Windkraftanlagen Königseiche\n',
#   '2023-2024\n',
#   '9,0\n',
#   '2\n',
#   'Nordex N149/4500 (2×)\n',
#   'Ebersbach\n',
#   'GP\n',
#   '48°\xa044′\xa053″\xa0N, 9°\xa030′\xa039″\xa0O\n',
#   'Uhl Windkraft\n',
#   'in Bau\n'],
#  ['Windkraftanlagen Laichingen\n',
#   '2023-2024\n',
#   '7,2\n',
#   '2\n',
#   'Vestas V136-3.6MW (2×)\n',
#   'Laichingen\n',
#   'UL\n',
#   '48°\xa031′\xa027″\xa0N, 9°\xa041′\xa036″\xa0O\n',
#   'WPD\n',
#   'in Bau\n'],
#  ['Windkraftanlage Leibertingen\n',
#   '1994\n',
#   '0,6\n',
#   '1\n',
#   'Markham VS45 (1×)\n',
#   'Leibertingen\n',
#   'SIG\n',
#   '48°\xa03′\xa03″\xa0N, 9°\xa01′\xa023″\xa0O\n',
#   'Bäumlehof Leibertingen\n',
#   'Prototyp der Markham VS45, stand ursprünglich im Windenergiepark Westküste, wo sie abgebaut und 1994 in Leibertingen wieder aufgebaut wurde, seit 2008 wegen defekter Steuerung und Blättern außer Betrieb, Ersatz gegen eine neue 600-kW-Anlage war geplant, Rückbau wegen Repowering geplant\n'],
#  ['Windkraftanlage Lenzkirch-Kopp\n',
#   '2003\n',
#   '1,5\n',
#   '1\n',
#   'Südwind S77 (1×)\n',
#   'Lenzkirch\n',
#   'FR\n',
#   '47°\xa050′\xa05″\xa0N, 8°\xa012′\xa023″\xa0O\n',
#   'WKA Lenzkirch-Kopp\n',
#   '\n'],
#  ['Windkraftanlage Maxau\n',
#   '1997\n',
#   '0,11\n',
#   '1\n',
#   'Seewind 20/110 (1×)\n',
#   'Maxau\n',
#   'KA\n',
#   '49°\xa02′\xa02″\xa0N, 8°\xa018′\xa011″\xa0O\n',
#   'Windmühlenberg Windkraftanlage GmbH & Co. KG\n',
#   '\n'],
#  ['Windkraftanlage Mengen\n',
#   '2002\n',
#   '0,85\n',
#   '1\n',
#   'Vestas V52-850kW (1×)\n',
#   'Blochingen\n',
#   'SIG\n',
#   '48°\xa04′\xa021″\xa0N, 9°\xa021′\xa019″\xa0O\n',
#   'Rettich Ingenieurbüro\n',
#   '\n'],
#  ['Windkraftanlage Mulfingen\n',
#   '2006\n',
#   '2,0\n',
#   '1\n',
#   'Enercon E-82 (1×)\n',
#   'Hollenbach\n',
#   'KÜN\n',
#   '49°\xa024′\xa013″\xa0N, 9°\xa047′\xa035″\xa0O\n',
#   'Beermann Energiesysteme\n',
#   '\n'],
#  ['Windkraftanlage Oberiflingen[17]\n',
#   '2012\n',
#   '2,0\n',
#   '1\n',
#   'Enercon E-82 (1×)\n',
#   'Oberiflingen\n',
#   'FDS\n',
#   '48°\xa024′\xa08″\xa0N, 8°\xa033′\xa019″\xa0O\n',
#   'EnBW Windkraftprojekte, ee Rottenburg\n',
#   '\n'],
#  ['Windkraftanlage Oberkirch[18]\n',
#   '2003\n',
#   '0,055\n',
#   '1\n',
#   'Micon M 55-11 (1×)\n',
#   'Nußbach\n',
#   'OG\n',
#   '48°\xa032′\xa046″\xa0N, 8°\xa02′\xa020″\xa0O\n',
#   'Max Rohrhirsch\n',
#   '(*); Stand bis 2003 auf Fehmarn\n'],
#  ['Windkraftanlage Ochsenberg\n',
#   '2020\n',
#   '3,5\n',
#   '1\n',
#   'Enercon E-138 EP3 (1×)\n',
#   'Ochsenberg\n',
#   'HDH\n',
#   '48°\xa045′\xa010″\xa0N, 10°\xa09′\xa035″\xa0O\n',
#   'EnBW\n',
#   'Ende September bis Anfang Oktober 2023 wurde der Rotorträger ausgetauscht.\n'],
#  ['Windkraftanlage Rohrhardsberg[19]\n',
#   '2003\n',
#   '1,8\n',
#   '1\n',
#   'Enercon E-66/18.70 (1×)\n',
#   'Yach\n',
#   'EM\n',
#   '48°\xa08′\xa07″\xa0N, 8°\xa07′\xa014″\xa0O\n',
#   'fesa, Ökostrom Freiburg\n',
#   '\n'],
#  ['Windkraftanlage Schweighausen[20]\n',
#   '199719982013\n',
#   '3,05\n',
#   '1\n',
#   'Enercon E-101 (1×)\n',
#   'Schweighausen\n',
#   'OG\n',
#   '48°\xa013′\xa035″\xa0N, 7°\xa058′\xa031″\xa0O\n',
#   'fesa, Stadtwerke Emmendingen\n',
#   'Repowering 2013 (1× Enercon E-101 statt 1× Seewind 52/750 und 1× Seewind 20/110)\n'],
#  ['Windkraftanlage Sontheim\n',
#   '1996\n',
#   '0,08\n',
#   '1\n',
#   'Lagerwey LW 18/80 (1×)\n',
#   'Sontheim\n',
#   'HDH\n',
#   '48°\xa032′\xa011″\xa0N, 10°\xa018′\xa00″\xa0O\n',
#   '\n',
#   'Zweiflügler\n'],
#  ['Windkraftanlage Streuberg\n',
#   '2006\n',
#   '2,0\n',
#   '1\n',
#   'Enercon E-70 (1×)\n',
#   'Bergertshofen\n',
#   'SHA\n',
#   '49°\xa09′\xa028″\xa0N, 10°\xa013′\xa01″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windkraftanlage Ummendorf\n',
#   '2001\n',
#   '0,9\n',
#   '1\n',
#   'NEG Micon NM 52/900 (1×)\n',
#   'Ummendorf\n',
#   'BC\n',
#   '48°\xa03′\xa022″\xa0N, 9°\xa051′\xa022″\xa0O\n',
#   'Bürgerwindrad Ummendorf\n',
#   '\n'],
#  ['Windkraftanlage Unterkessach[21]\n',
#   '2011\n',
#   '2,0\n',
#   '1\n',
#   'Vestas V90-2.0MW (1×)\n',
#   'Unterkessach\n',
#   'HN\n',
#   '49°\xa021′\xa024″\xa0N, 9°\xa026′\xa025″\xa0O\n',
#   'Reg.En GmbH, seebaWIND\n',
#   '\n'],
#  ['Windkraftanlage Untermusbach\n',
#   '2002\n',
#   '1,5\n',
#   '1\n',
#   'Südwind S77 (1×)\n',
#   'Untermusbach\n',
#   'FDS\n',
#   '48°\xa031′\xa019″\xa0N, 8°\xa026′\xa01″\xa0O\n',
#   'WKA Kaltenbach\n',
#   '\n'],
#  ['Windkraftanlage Veringenstadt\n',
#   '2022\n',
#   '4,2\n',
#   '1\n',
#   'Enercon E-138 EP3 E2 (1×)\n',
#   'Veringenstadt\n',
#   'SIG\n',
#   '48°\xa010′\xa034″\xa0N, 9°\xa014′\xa013″\xa0O\n',
#   'EnBW\n',
#   '\n'],
#  ['Windkraftanlage Walzbachtal[22]\n',
#   '1990\n',
#   '0,11\n',
#   '1\n',
#   'Seewind 20/110 (1×)\n',
#   'Wössingen\n',
#   'KA\n',
#   '49°\xa00′\xa010″\xa0N, 8°\xa037′\xa04″\xa0O\n',
#   'Gerd Seel\n',
#   'Prototyp der Seewind 20/110, Deutschlands größte Eigenbauanlage\n'],
#  ['Windkraftanlage Wegses[23]\n',
#   '2005\n',
#   '1,5\n',
#   '1\n',
#   'Fuhrländer FL MD77 (1×)\n',
#   'Wegses\n',
#   'SHA\n',
#   '49°\xa07′\xa04″\xa0N, 10°\xa08′\xa017″\xa0O\n',
#   'Bürgerwindpark Hohenlohe\n',
#   '\n'],
#  ['Windkraftanlage Weitingen\n',
#   '1998\n',
#   '0,6\n',
#   '1\n',
#   'Nordex N43/600 (1×)\n',
#   'Weitingen\n',
#   'FDS\n',
#   '48°\xa028′\xa05″\xa0N, 8°\xa048′\xa014″\xa0O\n',
#   'Windkraft Wasserturm Weitingen GbR mit Haftungsbeschränkung\n',
#   '\n'],
#  ['Windkraftanlage Welzheim\n',
#   '2004\n',
#   '1,0\n',
#   '1\n',
#   'Fuhrländer FL 1000/54 (1×)\n',
#   'Aichstrut\n',
#   'WN\n',
#   '48°\xa053′\xa022″\xa0N, 9°\xa039′\xa019″\xa0O\n',
#   'Bürgerwind Welzheim\n',
#   '\n'],
#  ['Windkraftanlage Zimmern\n',
#   '2000\n',
#   '0,8\n',
#   '1\n',
#   'Nordex N50/800 (1×)\n',
#   'Zimmern ob Rottweil\n',
#   'RW\n',
#   '48°\xa010′\xa029″\xa0N, 8°\xa033′\xa015″\xa0O\n',
#   'WKA Zimmern\n',
#   '\n'],
#  ['Windkraftanlagen Bad Wildbad[24]\n',
#   '2024\n',
#   '11,2\n',
#   '2\n',
#   'Vestas V162-5.6MW (2×)\n',
#   'Bad Wildbad\n',
#   'CW\n',
#   '48°\xa045′\xa043,8″\xa0N, 8°\xa036′\xa031″\xa0O48.7621578.608602\n',
#   'EnBW\n',
#   'in Bau\n'],
#  ['Windkraftanlagen Bonndorf[25]\n',
#   '19982005\n',
#   '1,3\n',
#   '2\n',
#   'Enercon E-40/5.40 (1×)Enercon E-48 (1×)\n',
#   'Bonndorf\n',
#   'WT\n',
#   '47°\xa049′\xa030,1″\xa0N, 8°\xa020′\xa052″\xa0O47.82503418.3477908\n',
#   'Burr Windenergieanlage\n',
#   '\n'],
#  ['Windkraftanlagen Brettenfeld\n',
#   '2017\n',
#   '6,6\n',
#   '2\n',
#   'Nordex N131/3300 (2×)\n',
#   'Brettenfeld\n',
#   'SHA\n',
#   '49°\xa016′\xa09″\xa0N, 10°\xa00′\xa033″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windkraftanlagen Buchhausen\n',
#   '20042006\n',
#   '1,4\n',
#   '2\n',
#   'Enercon E-40/6.44 (1×)Enercon E-48 (1×)\n',
#   'Buchhausen\n',
#   'AA\n',
#   '48°\xa057′\xa027″\xa0N, 10°\xa018′\xa08″\xa0O\n',
#   'Windkraft Buchhausen\n',
#   '\n'],
#  ['Windkraftanlagen Bühlerzimmern/Veinau[26][27]\n',
#   '1996\n',
#   '1,0\n',
#   '2\n',
#   'Enercon E-40/5.40 (2×)\n',
#   'Bühlerzimmern/Veinau\n',
#   'SHA\n',
#   '49°\xa08′\xa042″\xa0N, 9°\xa047′\xa024″\xa0O\n',
#   'WIKRA, Stadtwerke Schw. Hall, Solar Invest AG, Bürger-WP Hohenlohe\n',
#   'Nach bereits 18 Jahren im Juli 2014 Abschaltung und Demontage aufgrund Repowering-Bonus, der andernorts zum Tragen kommt[28]\n'],
#  ['Windkraftanlagen Dürrenmettstetten\n',
#   '19972003\n',
#   '1,2\n',
#   '2\n',
#   'Vestas V44-600kW (1×)Enercon E-40/6.44 (1×)\n',
#   'Dürrenmettstetten\n',
#   'RW\n',
#   '48°\xa023′\xa029″\xa0N, 8°\xa034′\xa032″\xa0O\n',
#   'Windkraft Kruse, Lothar Kopp\n',
#   'eine Vestas V47-660kW wurde 2015 abgebaut\n'],
#  ['Windkraftanlagen Fluorn-Winzeln\n',
#   '2003\n',
#   '3,0\n',
#   '2\n',
#   'REpower MD77 (2×)\n',
#   'Fluorn-Winzeln\n',
#   'RW\n',
#   '48°\xa018′\xa04″\xa0N, 8°\xa030′\xa015″\xa0O\n',
#   'Windkraft Fluorn-Winzeln\n',
#   '\n'],
#  ['Windkraftanlagen Gerchsheim\n',
#   '20022003\n',
#   '1,6\n',
#   '2\n',
#   'Enercon E-40/6.44 (1×)Enercon E-58 (1×)\n',
#   'Gerchsheim\n',
#   'TBB\n',
#   '49°\xa042′\xa019″\xa0N, 9°\xa046′\xa01″\xa0O\n',
#   'BadenWind\n',
#   '\n'],
#  ['Windkraftanlagen Gissigheim\n',
#   '20052010\n',
#   '1,8\n',
#   '2\n',
#   'Enercon E-58 (1×)Enercon E-48 (1×)\n',
#   'Gissigheim\n',
#   'TBB\n',
#   '49°\xa035′\xa01″\xa0N, 9°\xa035′\xa042″\xa0O\n',
#   'BadenWind\n',
#   '\n'],
#  ['Windkraftanlagen Grömbach\n',
#   '2024\n',
#   '6,9\n',
#   '2\n',
#   'Vestas V136-3.45MW (2×)\n',
#   'Grömbach\n',
#   'FDS\n',
#   '48°\xa033′\xa021″\xa0N, 8°\xa030′\xa037″\xa0O\n',
#   'EnBW\n',
#   'in Bau\n'],
#  ['Windkraftanlagen Häusern\n',
#   '2023\n',
#   '6,9\n',
#   '2\n',
#   'Vestas V126-3.45MW (2×)\n',
#   'Häusern\n',
#   'FR\n',
#   '47°\xa045′\xa058″\xa0N, 8°\xa010′\xa017″\xa0O\n',
#   'EnBW\n',
#   '\n'],
#  ['Windkraftanlagen Hettingen[29]\n',
#   '2002\n',
#   '3,0\n',
#   '2\n',
#   'Fuhrländer FL MD77 (2×)\n',
#   'Hettingen\n',
#   'MOS\n',
#   '49°\xa031′\xa028″\xa0N, 9°\xa022′\xa09″\xa0O\n',
#   'Windenergie S & H, WP Hettinger Eulsberg\n',
#   '\n'],
#  ['Windkraftanlagen Holzschlägermatte[30]\n',
#   '20032024\n',
#   '6,0\n',
#   '2\n',
#   'Enercon E-66/18.70 (1×)Enercon E-138 EP3 E2 (1×)\n',
#   'Freiburg im Breisgau\n',
#   'FR\n',
#   '47°\xa055′\xa02″\xa0N, 7°\xa052′\xa034″\xa0O\n',
#   'fesa, Ökostrom Freiburg\n',
#   'Repowering im Gange (1× Enercon E-138 EP3 E2 statt 2× Enercon E-66/18.70)\n'],
#  ['Windkraftanlagen Karlsruhe (Energieberg Karlsruhe[31])\n',
#   '1998200020032019\n',
#   '3,5\n',
#   '2\n',
#   'Fuhrländer FL MD77 (1×)Senvion MM100 (1×)\n',
#   'Karlsruhe\n',
#   'KA\n',
#   '49°\xa01′\xa07″\xa0N, 8°\xa019′\xa035″\xa0O\n',
#   'Windmühlenberg WKA\n',
#   'Repowering 2019 (1× Senvion MM100 statt 2× Seewind 52/750)\n'],
#  ['Windkraftanlagen Kreßberg\n',
#   '2020\n',
#   '5,5\n',
#   '2\n',
#   'Vensys 112/2500 (1×)Vensys 120/3000 (1×)\n',
#   'Kreßberg\n',
#   'SHA\n',
#   '49°\xa07′\xa044″\xa0N, 10°\xa09′\xa028″\xa0O\n',
#   'Bürgerwind Kreßberg\n',
#   '\n'],
#  ['Windkraftanlagen Loßburg\n',
#   '2001\n',
#   '1,7\n',
#   '2\n',
#   'Vestas V52-850kW (2×)\n',
#   'Loßburg\n',
#   'FDS\n',
#   '48°\xa023′\xa022″\xa0N, 8°\xa026′\xa027″\xa0O\n',
#   'Keinath DYRA-AIR\n',
#   '\n'],
#  ['Windkraftanlagen Nassau[32]\n',
#   '2015\n',
#   '4,7\n',
#   '2\n',
#   'Enercon E-92 (2×)\n',
#   'Nassau\n',
#   'TBB\n',
#   '49°\xa031′\xa019″\xa0N, 9°\xa054′\xa020″\xa0O\n',
#   'juwi, Stadtwerke Tübingen\n',
#   '\n'],
#  ['Windkraftanlagen Nellingen\n',
#   '1999\n',
#   '1,2\n',
#   '2\n',
#   'Tacke TW 600a (2×)\n',
#   'Nellingen\n',
#   'UL\n',
#   '48°\xa032′\xa07″\xa0N, 9°\xa049′\xa09″\xa0O\n',
#   'Schwabenwind\n',
#   '\n'],
#  ['Windkraftanlagen Nesselbach[33]\n',
#   '20002002\n',
#   '2,0\n',
#   '2\n',
#   'Fuhrländer FL 1000/54 (2×)\n',
#   'Nesselbach\n',
#   'SHA\n',
#   '49°\xa013′\xa032″\xa0N, 9°\xa049′\xa035″\xa0O\n',
#   'Bürgerwindpark Hohenlohe\n',
#   '\n'],
#  ['Windkraftanlagen Neueck\n',
#   '2003\n',
#   '1,2\n',
#   '2\n',
#   'Enercon E-40/6.44 (2×)\n',
#   'Gütenbach\n',
#   'VS\n',
#   '48°\xa02′\xa031″\xa0N, 8°\xa010′\xa04″\xa0O\n',
#   'RENA Renewable Energy\n',
#   '\n'],
#  ['Windkraftanlagen Schalkstetten\n',
#   '20012002\n',
#   '2,6\n',
#   '2\n',
#   'AN Bonus 1300/62 (2×)\n',
#   'Schalkstetten\n',
#   'UL\n',
#   '48°\xa037′\xa022″\xa0N, 9°\xa055′\xa012″\xa0O\n',
#   'EES Erneuerbare Energie\n',
#   '\n'],
#  ['Windkraftanlagen Seckach\n',
#   '2008\n',
#   '4,1\n',
#   '2\n',
#   'REpower MM92 (2×)\n',
#   'Großeicholzheim\n',
#   'MOS\n',
#   '49°\xa027′\xa010″\xa0N, 9°\xa016′\xa011″\xa0O\n',
#   'Reg.En GmbH, THEOLIA Naturenergien GmbH\n',
#   '\n'],
#  ['Windkraftanlagen Suppingen\n',
#   '2000\n',
#   '1,5\n',
#   '2\n',
#   'NEG Micon NM 48/750 (2×)\n',
#   'Suppingen\n',
#   'UL\n',
#   '48°\xa027′\xa04″\xa0N, 9°\xa043′\xa014″\xa0O\n',
#   'Glotter, Windkraft Suppingen\n'],
#  ['Windkraftanlagen Taubenkopf[34]\n',
#   '2024\n',
#   '9,32\n',
#   '2\n',
#   'Enercon E-138 EP3 E3 (1×)Enercon E-160 EP5 E3 (1×)\n',
#   'Freiburg im Breisgau\n',
#   'FR\n',
#   '47°\xa056′\xa04″\xa0N, 7°\xa052′\xa053″\xa0O\n',
#   'Ökostrom Freiburg\n',
#   'in Bau\n',
#   '\n'],
#  ['Windkraftanlagen Unterriffingen\n',
#   '20002003\n',
#   '1,6\n',
#   '2\n',
#   'Enercon E-40/6.44 (1×)Enercon E-58 (1×)\n',
#   'Unterriffingen\n',
#   'AA\n',
#   '48°\xa050′\xa07″\xa0N, 10°\xa018′\xa025″\xa0O\n',
#   'Förderverein Wind- und Wasserkraft Ostalb\n',
#   '\n'],
#  ['Windkraftanlagen Unterschwarzach\n',
#   '2005\n',
#   '2,6\n',
#   '2\n',
#   'AN Bonus 1300/62 (2×)\n',
#   'Unterschwarzach\n',
#   'RV\n',
#   '47°\xa058′\xa04″\xa0N, 9°\xa052′\xa03″\xa0O\n',
#   'Glotter, WKA IM WAS Windenergie\n',
#   '\n'],
#  ['Windkraftanlagen Weilersbach\n',
#   '2001\n',
#   '1,9\n',
#   '2\n',
#   'Enercon E-40/6.44 E1 (1×)Nordex N62/1300 (1×)\n',
#   'Weilersbach\n',
#   'VS\n',
#   '48°\xa05′\xa016″\xa0N, 8°\xa029′\xa050″\xa0O\n',
#   'Neue Energien Projekt, Windkraft Weilersbach\n',
#   '\n'],
#  ['Windkraftanlagen Wolpertshausen\n',
#   '2001\n',
#   '1,2\n',
#   '2\n',
#   'DeWind D4 48/600 (2×)\n',
#   'Wolpertshausen\n',
#   'SHA\n',
#   '49°\xa09′\xa030″\xa0N, 9°\xa051′\xa034″\xa0O\n',
#   'Baram Windkraft-Projektierungs GmbH\n',
#   '\n'],
#  ['Windkraftanlage Zottishofen\n',
#   '2016\n',
#   '3,05\n',
#   '1\n',
#   'Enercon E-101 (1×)\n',
#   'Zottishofen\n',
#   'SHA\n',
#   '49°\xa013′\xa016″\xa0N, 9°\xa049′\xa028″\xa0O\n',
#   'EE Bürgerenergie Braunsbach\n',
#   '\n'],
#  ['Windkraftanlagentestfeld Heroldstatt[35]\n',
#   '19891990\n',
#   '0,135\n',
#   '2\n',
#   'Enercon E-17 (1×)Dornier Darrieus 55 (1×)\n',
#   'Ennabeuren\n',
#   'UL\n',
#   '48°\xa026′\xa050″\xa0N, 9°\xa038′\xa017″\xa0O\n',
#   'EVS (EnBW)\n',
#   'Testfeld der EVS (heute EnBW) zur Erprobung unterschiedlicher Windkraftanlagentypen (konventioneller und Darrieus-Rotor) 1989–2000, erste zu Testzwecken errichtete Windkraftanlagen in Süddeutschland; 1989–2013 zusätzlich Enercon E-17, wurde wegen Getriebeschaden abgebaut; Darrieus-Rotor ebenfalls außer Betrieb, jedoch noch aufgebaut.\n'],
#  ['Windpark Ahorn-Buch[36]\n',
#   '2017\n',
#   '11,0\n',
#   '4\n',
#   'GE Wind Energy 2.75-120 (4×)\n',
#   'Buch\n',
#   'TBB\n',
#   '49°\xa032′\xa021″\xa0N, 9°\xa034′\xa029″\xa0O\n',
#   'Stadtwerke Heidenheim AG - Unternehmensgruppe (25,1 Prozent), Windpark Ahorn-Buch Bürgerbeteiligung GmbH & Co. KG (24,9 Prozent) sowie weitere Energieversorger aus dem Netzwerk der Stadtwerke Heidenheim AG - Unternehmensgruppe\n',
#   '\n'],
#  ['Windpark Ahorn-Schillingstadt[37]\n',
#   '201120162017\n',
#   '29,85\n',
#   '11\n',
#   'Enercon E-53 (1×)Enercon E-115 (4×)GE Wind Energy 2.75-120 (5×)Nordex N131/3300 (1×)\n',
#   'Schillingstadt\n',
#   'TBB\n',
#   '49°\xa028′\xa017″\xa0N, 9°\xa034′\xa026″\xa0O\n',
#   'ABO Wind, Genossenschaft\nEnergie + Umwelt, Bürgerwindpark\nHohenlohe GmbH; Reg.En GmbH\n\n',
#   'Mehr als 1.800 Bürger der Region sind finanziell beteiligt[38]\n'],
#  ['Windpark Altheimer Höhe[39]\n',
#   '200020112023\n',
#   '11,66\n',
#   '5\n',
#   'Fuhrländer FL 1000/54 (2×)REpower MM92 (2×)Enercon E-160 EP5 E3 (1×)\n',
#   'Altheim\n',
#   'MOS\n',
#   '49°\xa031′\xa026″\xa0N, 9°\xa028′\xa022″\xa0O\n',
#   'Windenergie S & H\n',
#   '2023 Repowering (1× Enercon E-160 EP5 E3 statt 1× Fuhrländer FL 1000/54)\n'],
#  ['Windpark Am Hochsträß[40]\n',
#   '20012002200320182023-2024\n',
#   '33,1\n',
#   '11\n',
#   'REpower MD77 (5×)Nordex N117/3600 (4×)Vestas V150-5.6MW (2×)\n',
#   'Gussenstadt\n',
#   'HDH\n',
#   '48°\xa039′\xa011″\xa0N, 9°\xa056′\xa06″\xa0O\n',
#   'Glotter, Alb-Windkraft, Stadtwerke Fellbach\n',
#   'Repowering im Gange (2× Vestas V150-5.6MW statt 4× Vestas V47-660kW)\n'],
#  ['Windpark Amstetten\n',
#   '19982002\n',
#   '3,7\n',
#   '5\n',
#   'DeWind D4 48/600 (4×)AN Bonus 1300/62 (1×)\n',
#   'Amstetten\n',
#   'UL\n',
#   '48°\xa033′\xa035″\xa0N, 9°\xa050′\xa019″\xa0O\n',
#   'Aufwind, FC Windenergy, Windreich\n',
#   '\n'],
#  ['Windpark Amtenhauser Berg\n',
#   '20172022\n',
#   '37,5\n',
#   '10\n',
#   'Vestas V126-3.3MW (5×)Vestas V150-4.2MW (5×)\n',
#   'Immendingen\n',
#   'TUT\n',
#   '47°\xa057′\xa031″\xa0N, 8°\xa040′\xa024″\xa0O\n',
#   'WP Amtenhauser Berg, Juwi\n',
#   '\n'],
#  ['Windpark Aufhausen\n',
#   '20022005\n',
#   '8,0\n',
#   '4\n',
#   'Vestas V80-2.0MW (2×)Vestas V90-2.0MW (2×)\n',
#   'Aufhausen\n',
#   'GP\n',
#   '48°\xa034′\xa026″\xa0N, 9°\xa045′\xa00″\xa0O\n',
#   'Megawatt\n',
#   '\n'],
#  ['Windpark Auingen\n',
#   '20002006\n',
#   '2,3\n',
#   '3\n',
#   'NEG Micon NM 48/750 (2×)Enercon E-48 (1×)\n',
#   'Auingen\n',
#   'RT\n',
#   '48°\xa024′\xa08″\xa0N, 9°\xa031′\xa044″\xa0O\n',
#   'SoWiTec, Theolia, wks-energy, Windreich\n',
#   '\n'],
#  ['Windpark Bad Rippoldsau-Schapbach[41][42]\n',
#   '200720152024\n',
#   '12,55\n',
#   '5\n',
#   'Vestas V90-2.0MW (3×)Enercon E-92 (1×)Enercon E-138 EP3 E2 (1×)\n',
#   'Schapbach\n',
#   'FDS\n',
#   '48°\xa024′\xa01″\xa0N, 8°\xa017′\xa06″\xa0O\n',
#   'vento ludens\n',
#   'Erweiterung in Bau (1× Enercon E-138 EP3 E2)\n'],
#  ['Windpark Bad Saulgau (Windpark Schellenberg)\n',
#   '2019\n',
#   '10,8\n',
#   '3\n',
#   'Vestas V136-3.6MW (3×)\n',
#   'Bad Saulgau\n',
#   'SIG\n',
#   '48°\xa01′\xa016″\xa0N, 9°\xa034′\xa010″\xa0O\n',
#   'Uhl Windkraft Projektierung GmbH & Co. KG\n',
#   '(*)2020 Änderung des Powermodes auf 3.6MW\n'],
#  ['Windpark Berghülen-Blaubeuren[43]\n',
#   '2002200920122017\n',
#   '11,0\n',
#   '6\n',
#   'Enercon E-40/6.44 (1×)Enercon E-82 (4×)Nordex N117/2400 (1×)\n',
#   'BerghülenSeißen\n',
#   'UL\n',
#   '48°\xa027′\xa03″\xa0N, 9°\xa045′\xa029″\xa0O\n',
#   'EnBW Windkraftprojekte; Windenergie Wennender Heide\n',
#   '\n'],
#  ['Windpark Blaufelden-Langenburg\n',
#   '20172018\n',
#   '40,05\n',
#   '12\n',
#   'Vestas V126-3.3MW (9×)Vestas V126-3.45MW (3×)\n',
#   'BlaufeldenLangenburg\n',
#   'SHA\n',
#   '49°\xa016′\xa042″\xa0N, 9°\xa052′\xa053″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Bobstadt\n',
#   '2018\n',
#   '12,0\n',
#   '4\n',
#   'Enercon E-115 (4×)\n',
#   'Bobstadt\n',
#   'TBB\n',
#   '49°\xa028′\xa04″\xa0N, 9°\xa041′\xa039″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Böhmenkirch\n',
#   '20012007\n',
#   '6,0\n',
#   '4\n',
#   'Südwind S70 (3×)Fuhrländer FL MD70 (1×)\n',
#   'Böhmenkirch\n',
#   'GP\n',
#   '48°\xa041′\xa031″\xa0N, 9°\xa056′\xa032″\xa0O\n',
#   'Alb-Windkraft\n',
#   '\n'],
#  ['Windpark Böttingen\n',
#   '2000\n',
#   '2,25\n',
#   '3\n',
#   'NEG Micon NM 48/750 (3×)\n',
#   'Böttingen\n',
#   'RT\n',
#   '48°\xa024′\xa07″\xa0N, 9°\xa033′\xa04″\xa0O\n',
#   'SoWiTec, Theolia, Windreich\n',
#   '\n'],
#  ['Windpark Boxberg[44]\n',
#   '20042017\n',
#   '12,35\n',
#   '6\n',
#   'Vestas V90-2.0MW (5×)Enercon E-92 (1×)\n',
#   'Uiffingen\n',
#   'TBB\n',
#   '49°\xa030′\xa025″\xa0N, 9°\xa034′\xa012″\xa0O\n',
#   'Global Wind Power, juwi\n',
#   'errichtet an der A\xa081\n'],
#  ['Windpark Brandberg-Rosenberg-Virngrund[45]\n',
#   '201420162017\n',
#   '20,45\n',
#   '7\n',
#   'Enercon E-92 (2×)Nordex N131/3300 (2×)Enercon E-115 (3×)\n',
#   'LeinenfirstHohenbergHinterlengenberg\n',
#   'AA\n',
#   '48°\xa059′\xa017″\xa0N, 10°\xa02′\xa050″\xa0O48.98805555555610.047222222222\n',
#   'EnBW Windkraftprojekte, EnBW-ODR; W-I-N-D Energien; Stadtwerke Ellwangen\n',
#   '\n'],
#  ['Windpark Brandenkopf-Nillkopf[46]\n',
#   '199720022018\n',
#   '7,6\n',
#   '4\n',
#   'Tacke TW 600e (1×)Enercon E-58 (1×)Enercon E-115 (2×)\n',
#   'FischerbachUnterharmersbach\n',
#   'OG\n',
#   '48°\xa020′\xa013″\xa0N, 8°\xa08′\xa033″\xa0O\n',
#   'JALBO Windkraft, fesa, Bürgerwindrad Brandenkopf\n',
#   '\n'],
#  ['Windpark Braunsbach[47]\n',
#   '2016\n',
#   '12,0\n',
#   '4\n',
#   'Enercon E-115 (4×)\n',
#   'Zottishofen\n',
#   'SHA\n',
#   '49°\xa014′\xa016″\xa0N, 9°\xa048′\xa027″\xa0O\n',
#   'ZEAG, BE Braunsbach\n',
#   '\n'],
#  ['Windpark Bühlertann\n',
#   '2017\n',
#   '13,2\n',
#   '4\n',
#   'Vestas V126-3.3MW (4×)\n',
#   'Bühlertann\n',
#   'SHA\n',
#   '49°\xa01′\xa018″\xa0N, 9°\xa058′\xa07″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Burgberg\n',
#   '20212022-2023\n',
#   '17,0\n',
#   '5\n',
#   'Enercon E-138 EP3 E2 (5×)\n',
#   'Crailsheim\n',
#   'SHA\n',
#   '49°\xa08′\xa020″\xa0N, 9°\xa057′\xa015″\xa0O\n',
#   'WP Burgberg\n',
#   'Erweiterung um eine Anlage in Bau\n'],
#  ['Windpark Büttenbuch[48]\n',
#   '20162019\n',
#   '10,8\n',
#   '4\n',
#   'Nordex N117/2400 (3×)Nordex N117/3600 (1×)\n',
#   'EschachGöggingen\n',
#   'AA\n',
#   '48°\xa052′\xa013″\xa0N, 9°\xa052′\xa06″\xa0O\n',
#   'W-I-N-D Energien\n',
#   '\n'],
#  ['Windpark Dainbach[49]\n',
#   '2024\n',
#   '16,8\n',
#   '4\n',
#   'Vestas V150-4.2MW (4×)\n',
#   'Dainbach\n',
#   'TBB\n',
#   '49°\xa028′\xa039″\xa0N, 9°\xa041′\xa042″\xa0O\n',
#   'EnBW\n',
#   'in Bau\n'],
#  ['Windpark Dischingen-Ohrberg[50]\n',
#   '2016\n',
#   '13,75\n',
#   '5\n',
#   'GE Wind Energy 2.75-120 (5×)\n',
#   'Dischingen\n',
#   'HDH\n',
#   '48°\xa043′\xa03″\xa0N, 10°\xa019′\xa01″\xa0O\n',
#   'WP Ohrberg\n',
#   '\n'],
#  ['Windpark Dittwar[51]\n',
#   '20172018\n',
#   '9,9\n',
#   '3\n',
#   'Vestas V126-3.3MW (3×)\n',
#   'Dittwar\n',
#   'TBB\n',
#   '49°\xa035′\xa056″\xa0N, 9°\xa036′\xa058″\xa0O\n',
#   '\n',
#   'errichtet auf dem Neuberg bei Dittwar\n'],
#  ['Windpark Drackenstein (incl. Windpark Gosbacher Alb)\n',
#   '20002020\n',
#   '19,05\n',
#   '8\n',
#   'Vestas V52-850kW (3×)Nordex N131/3300 (5×)\n',
#   'Bad DitzenbachDrackenstein\n',
#   'GP\n',
#   '48°\xa032′\xa040″\xa0N, 9°\xa042′\xa014″\xa0O\n',
#   '2× Albwerk, 3× Planet Energy, Megawatt\n',
#   '\n'],
#  ['Windpark Dunningen\n',
#   '2000\n',
#   '3,6\n',
#   '3\n',
#   'Enercon E-40/6.44 E1 (1×)Enercon E-66/15.66 (2×)\n',
#   'Dunningen\n',
#   'RW\n',
#   '48°\xa013′\xa010″\xa0N, 8°\xa031′\xa033″\xa0O\n',
#   'windwin, Lothar Kopp\n',
#   '\n'],
#  ['Windpark Ebnat-Ochsenberg[52]\n',
#   '2016\n',
#   '33,6\n',
#   '14\n',
#   'Nordex N117/2400 (14×)\n',
#   'EbnatNietheim\n',
#   'AAHDH\n',
#   '48°\xa045′\xa026″\xa0N, 10°\xa010′\xa016″\xa0O\n',
#   'Blauwind\n',
#   'Es sind 15 Windräder zu sehen, eines gehört jedoch nicht zu diesem Windpark, es ist das Windrad Königsbronn[53]\n'],
#  ['Windpark Ellwanger Berge[54]\n',
#   '20162017\n',
#   '30,5\n',
#   '10\n',
#   'Enercon E-115 (10×)\n',
#   'JagstzellBreitenbach\n',
#   'AA\n',
#   '49°\xa02′\xa027″\xa0N, 10°\xa010′\xa028″\xa0O\n',
#   'Stadtwerke Tübingen, W-I-N-D Energien\n',
#   'errichtet an der A\xa07\n'],
#  ['Windpark Ettenheim-Kippenheim[55][56]\n',
#   '20002001\n',
#   '16,68\n',
#   '3\n',
#   'Enercon E-160 EP5 E3 (3×)\n',
#   'EttenheimKippenheim\n',
#   'OG\n',
#   '48°\xa015′\xa016″\xa0N, 7°\xa052′\xa014″\xa0O\n',
#   'fesa, Ökostrom Freiburg\n',
#   'Windpark mit Aussichtsturm2021 Abbau von 3× Nordex N62/1300, 1× Nordex N80/2500 und 1× Südwind S70eine weitere Nordex N80/2500 wurde 2020 abgebaut3× Enercon E-160 EP5 E3 als Ersatz 2024 in Bau[57].\n'],
#  ['Windpark Falkenhöhe\n',
#   '2021\n',
#   '12,6\n',
#   '3\n',
#   'Vestas V136-4.2MW (3×)\n',
#   'LauterbachHornberg\n',
#   'RWOG\n',
#   '48°\xa012′\xa047″\xa0N, 8°\xa018′\xa048″\xa0O\n',
#   'Windkraft Schonach\n',
#   'Erweiterung geplant (1× Vestas V136-4.2MW)\n'],
#  ['Windpark Fichtenau\n',
#   '2017\n',
#   '9,9\n',
#   '3\n',
#   'Vestas V126-3.3MW (3×)\n',
#   'Fichtenau\n',
#   'SHA\n',
#   '49°\xa05′\xa030″\xa0N, 10°\xa011′\xa058″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Frauental[58][59]\n',
#   '20042015\n',
#   '6,55\n',
#   '4\n',
#   'REpower MD77 (3×)Senvion MM100 (1×)\n',
#   'Frauental\n',
#   'TBB\n',
#   '49°\xa030′\xa020″\xa0N, 10°\xa05′\xa016″\xa0O\n',
#   'SEG AG, HWE Hohenloher Windenergie\n',
#   '\n'],
#  ['Windpark Freiamt[60][61] (incl. Windkraftanlage Tännlebühl)\n',
#   '200120022004201120142023-2024\n',
#   '16,95\n',
#   '7\n',
#   'Enercon E-66/18.70 (3×)Enercon E-66/20.70 (1×)Enercon E-82 E2 (1×)Enercon E-101 (1×)Enercon E-138 EP3 E2 (1×)\n',
#   'Freiamt\n',
#   'EM\n',
#   '48°\xa010′\xa016″\xa0N, 7°\xa057′\xa026″\xa0O\n',
#   'fesa, Ökostrom Freiburg; Windenergie Tännlebühl\n',
#   'Repowering im Gange (1× Enercon E-138 EP3 E2 statt 2× Enercon E-66/18.70)\n'],
#  ['Windpark Freudenberg[62]\n',
#   '20072016\n',
#   '20,9\n',
#   '9\n',
#   'REpower MM82 (2×)Nordex N117/2400 (7×)\n',
#   'Freudenberg\n',
#   'TBB\n',
#   '49°\xa044′\xa026″\xa0N, 9°\xa021′\xa019″\xa0O\n',
#   'Reg.En, THEOLIA Naturenergien GmbH, MVV Energie\n',
#   '\n'],
#  ['Windpark Gaildorf (Naturstromspeicher Gaildorf[63])\n',
#   '2017\n',
#   '14,8\n',
#   '4\n',
#   'GE Wind Energy 3.6-137 (4×)\n',
#   'Gaildorf\n',
#   'SHA\n',
#   '49°\xa00′\xa02″\xa0N, 9°\xa048′\xa015″\xa0O\n',
#   'MBS Naturstromspeicher\n',
#   'Windpark mit integriertem 16MW-Pumpspeicherkraftwerk, Türme stehen auf 40m hohen Wasserspeichern, bei Inbetriebnahme die höchsten Anlagen der Welt (Nabenhöhe bis 178\xa0m, Gesamthöhe bis 246,5\xa0m)2020 Leistungsupgrade der GE Wind Energy 3.4-137\n'],
#  ['Windpark Gerabronn\n',
#   '199820022005\n',
#   '2,2\n',
#   '3\n',
#   'DeWind D4 48/600 (1×)Nordex N50/800 (1×)Enercon E-48 (1×)\n',
#   'Gerabronn\n',
#   'SHA\n',
#   '49°\xa015′\xa052″\xa0N, 9°\xa056′\xa023″\xa0O\n',
#   'BadenWind, LB-Converter, Steck Energie\n',
#   '\n'],
#  ['Windpark Gerichtstetten[64]\n',
#   '20182021\n',
#   '23,8\n',
#   '6\n',
#   'Enercon E-141 EP4 (4×)Enercon E-138 EP3 (2×)\n',
#   'Gerichtstetten\n',
#   'MOS\n',
#   '49°\xa031′\xa07″\xa0N, 9°\xa030′\xa036″\xa0O\n',
#   '\n',
#   'Bürger-Windparks\n'],
#  ['Windpark Gnannenweiler[65]\n',
#   '20092020-2021\n',
#   '25,2\n',
#   '11\n',
#   'Enercon E-82 (8×)Enercon E-53 (1×)Enercon E-138 EP3 E2 (2×)\n',
#   'Gnannenweiler\n',
#   'HDH\n',
#   '48°\xa041′\xa022″\xa0N, 9°\xa059′\xa034″\xa0O\n',
#   'Albuch-Wind, Windreich\n',
#   '\n'],
#  ['Windpark Goldboden[66]\n',
#   '2017\n',
#   '9,9\n',
#   '3\n',
#   'Nordex N131/3300 (3×)\n',
#   'Winterbach\n',
#   'WN\n',
#   '48°\xa046′\xa019″\xa0N, 9°\xa028′\xa011″\xa0O\n',
#   'EnBW Windkraftprojekte\n',
#   '\n'],
#  ['Windpark Großer Wald[67]\n',
#   '2013\n',
#   '16,0\n',
#   '5\n',
#   'REpower 3.2M114 (5×)\n',
#   'HettingenRinschheim\n',
#   'MOS\n',
#   '49°\xa032′\xa019″\xa0N, 9°\xa023′\xa012″\xa0O\n',
#   'Windenergie S & H\n',
#   '\n'],
#  ['Windpark Gütenbach\n',
#   '2003\n',
#   '3,2\n',
#   '3\n',
#   'Enercon E-40/6.44 (2×)Enercon E-66/18.70 (1×)\n',
#   'Gütenbach\n',
#   'VS\n',
#   '48°\xa02′\xa032″\xa0N, 8°\xa07′\xa019″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Hainstadt-Buchen\n',
#   '2022\n',
#   '13,8\n',
#   '4\n',
#   'Vestas V126-3.45MW (4×)\n',
#   'HainstadtBuchen (Odenwald)\n',
#   'MOS\n',
#   '49°\xa033′\xa042″\xa0N, 9°\xa017′\xa053″\xa0O\n',
#   'ABO Wind\n',
#   '\n'],
#  ['Windpark Harthäuser Wald[68][69]\n',
#   '20152017\n',
#   '54,9\n',
#   '18\n',
#   'Enercon E-115 (18×)\n',
#   'WiddernHardthausen a. K.JagsthausenMöckmühlForchtenberg\n',
#   'HNKÜN\n',
#   '49°\xa017′\xa028″\xa0N, 9°\xa024′\xa034″\xa0O\n',
#   'ZEAG, Bürgerenergie Hardthausen\n',
#   'leistungsstärkster Windpark in Baden-Württemberg sowie im süddeutschen Raum\n'],
#  ['Windpark Hasel\n',
#   '2017\n',
#   '9,9\n',
#   '3\n',
#   'Vestas V126-3.3MW (3×)\n',
#   'Hasel\n',
#   'LÖ\n',
#   '47°\xa040′\xa044″\xa0N, 7°\xa054′\xa057″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Heckfeld\n',
#   '20022017\n',
#   '5,05\n',
#   '3\n',
#   'Enercon E-58 (2×)Enercon E-101 (1×)\n',
#   'Heckfeld\n',
#   'TBB\n',
#   '49°\xa033′\xa010″\xa0N, 9°\xa039′\xa04″\xa0O\n',
#   'BadenWind\n',
#   '\n'],
#  ['Windpark Herrenzimmern (Windpark Hühnernest)\n',
#   '20192020\n',
#   '13,95\n',
#   '4\n',
#   'Vestas V126-3.45MW (3×)Vestas V126-3.6MW (1×)\n',
#   'Herrenzimmern\n',
#   'TBB\n',
#   '49°\xa026′\xa04″\xa0N, 9°\xa052′\xa032″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Heide[70][71]\n',
#   '19972000200220032004200520102011201220152016\n',
#   '31,1\n',
#   '15\n',
#   'Enercon E-40/5.40 (1×)Enercon E-58 (2×)Enercon E-66/18.70 (2×)Enercon E-70 (1×)Enercon E-82 E2 (2×)REpower MM92 (2×)Senvion 3.2M114 (3×)Enercon E-92 (2×)\n',
#   'Neubronn\n',
#   'TBB\n',
#   '49°\xa028′\xa026″\xa0N, 9°\xa058′\xa011″\xa0O\n',
#   'Naturkraft Tauber, HWE Hohenloher Windenergie, Klaus Wagner\n',
#   '\n'],
#  ['Windpark Hilpensberg\n',
#   '2017\n',
#   '9,0\n',
#   '3\n',
#   'Vensys 120/3000 (3×)\n',
#   'Hilpensberg\n',
#   'SIG\n',
#   '47°\xa051′\xa056″\xa0N, 9°\xa018′\xa02″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Himmelberg\n',
#   '1995\n',
#   '1,8\n',
#   '3\n',
#   'Micon M 1500-600 (3×)\n',
#   'Melchingen\n',
#   'BL\n',
#   '48°\xa022′\xa05″\xa0N, 9°\xa09′\xa02″\xa0O\n',
#   'SoWiTec\n',
#   'erster Windpark in Baden-Württemberg\n'],
#  ['Windpark Hirschlanden[72]\n',
#   '20042016\n',
#   '9,6\n',
#   '4\n',
#   'REpower MM82 (2×)GE Wind Energy 2.75-120 (2×)\n',
#   'Hirschlanden\n',
#   'MOS\n',
#   'v49°\xa027′\xa022″\xa0N, 9°\xa030′\xa07″\xa0O\n',
#   'Rosenwind Naturstrom\n',
#   '\n'],
#  ['Windpark Hohenlochen[73]\n',
#   '2020-2021\n',
#   '16,8\n',
#   '4\n',
#   'Enercon E-138 EP3 E2 (4×)\n',
#   'HausachOberwolfach\n',
#   'OG\n',
#   '\n',
#   'Badenova; Wärmeplus\n',
#   '\n'],
#  ['Windpark Höhefeld[74]\n',
#   '20012002\n',
#   '14,85\n',
#   '14\n',
#   'Fuhrländer FL 1000/54 (3×)Vestas V52-850kW (3×)Fuhrländer FL MD70 (5×)Enercon E-40/6.44 (3×)\n',
#   'Höhefeld\n',
#   'TBB\n',
#   '49°\xa043′\xa032″\xa0N, 9°\xa036′\xa02″\xa0O\n',
#   'BadenWind, Energiequelle, Volta Windkraft, UMaAG\n',
#   '\n'],
#  ['Windpark Keltenschanze-Weilerhöhe\n',
#   '2022-2023\n',
#   '12,6\n',
#   '3\n',
#   'Nordex N131/3600 (1×)Nordex N149/4500 (2×)\n',
#   'Hohenstadt\n',
#   'GP\n',
#   '48°\xa031′\xa038″\xa0N, 9°\xa038′\xa040″\xa0O\n',
#   'Megawatt Gesellschaft für Windenergie mbH\n',
#   '\n'],
#  ['Windpark Holzkirch-Neenstetten\n',
#   '2008\n',
#   '6,15\n',
#   '3\n',
#   'REpower MM92 (3×)\n',
#   'HolzkirchNeenstetten\n',
#   'UL\n',
#   '48°\xa031′\xa035″\xa0N, 10°\xa00′\xa019″\xa0O\n',
#   'Reg.En, THEOLIA Naturenergien GmbH\n',
#   '\n'],
#  ['Windpark Hornberg[75]\n',
#   '200220092020\n',
#   '9,05\n',
#   '5\n',
#   'Fuhrländer FL 1000/54 (2×)Enercon E-82 (2×)Enercon E-115 (1×)\n',
#   'HornbergGutach\n',
#   'OG\n',
#   '48°\xa014′\xa012″\xa0N, 8°\xa014′\xa030″\xa0O\n',
#   'windwin, Windreich, badenova\n',
#   '\n'],
#  ['Windpark Hummelsweiler[76]\n',
#   '2017\n',
#   '12,0\n',
#   '4\n',
#   'Enercon E-115 (4×)\n',
#   'Rosenberg\n',
#   'AA\n',
#   '49°\xa02′\xa019″\xa0N, 10°\xa00′\xa010″\xa0O\n',
#   'W-I-N-D Energien\n',
#   '\n'],
#  ['Windpark Ilshofen-Ruppertshofen[77]\n',
#   '200620072014201520172021\n',
#   '23,75\n',
#   '8\n',
#   'Fuhrländer FL MD77 (1×)REpower MM92 (1×)Enercon E-101 (2×)Vestas V126-3.3MW (3×)Enercon E-138 EP3 E2 (1×)\n',
#   'RuppertshofenGerabronn\n',
#   'SHA\n',
#   '49°\xa010′\xa035″\xa0N, 9°\xa054′\xa05″\xa0O\n',
#   'Behlau Energiewende, Reg.En GmbH, ZEAG, THEOLIA Naturenergien GmbH\n',
#   '\n'],
#  ['Windpark Kambacher Eck[78]\n',
#   '2016\n',
#   '12,2\n',
#   '4\n',
#   'Enercon E-115 (4×)\n',
#   'BiberachSteinach\n',
#   'OG\n',
#   '48°\xa017′\xa028″\xa0N, 7°\xa059′\xa010″\xa0O\n',
#   'badenova, Ökostrom Consulting\n',
#   '\n'],
#  ['Windpark Kirchberg[79][80]\n',
#   '200020092016\n',
#   '32,4\n',
#   '11\n',
#   'Vestas V90-2.0MW (3×)Vestas V126-3.3MW (8×)\n',
#   'Kirchberg a. d. Jagst\n',
#   'SHA\n',
#   '49°\xa011′\xa04″\xa0N, 9°\xa057′\xa09″\xa0O\n',
#   'Behlau Energiewende, Bürger-WP Kirchberg, Hohenlohe Wind, reencon GmbH, ingenia, Gerhard Borchers\n',
#   'errichtet an der A\xa06, bis 2014 stand noch eine Nordex N50/800 im Park, größter Bürgerwindpark in Süddeutschland\n'],
#  ['Windpark Klosterwald[81]\n',
#   '2015\n',
#   '25,0\n',
#   '10\n',
#   'GE Wind Energy 2.5-120 (10×)\n',
#   'Creglingen\n',
#   'TBB\n',
#   '49°\xa029′\xa00″\xa0N, 10°\xa04′\xa030″\xa0O\n',
#   'WEBW, MVV Energie, Wirthwein\n',
#   '\n'],
#  ['Windpark Kohlenstraße[82]\n',
#   '2015\n',
#   '23,1\n',
#   '7\n',
#   'Vestas V126-3.3MW (7×)\n',
#   'Michelbach a. d. BilzGaildorfObersontheim\n',
#   'SHA\n',
#   '49°\xa03′\xa02″\xa0N, 9°\xa047′\xa020″\xa0O\n',
#   'Stadtwerke Schwäbisch Hall, Bürgerwindpark Hohenlohe\n',
#   'errichtet entlang der gleichnamigen Kohlenstraße in den Limpurger Bergen\n'],
#  ['Windpark Krautheim-Eckigbreit\n',
#   '2021\n',
#   '12,6\n',
#   '3\n',
#   'Enercon E-138 EP3 E2 (3×)\n',
#   'Krautheim\n',
#   'KÜN\n',
#   '49°\xa023′\xa049″\xa0N, 9°\xa036′\xa01″\xa0O\n',
#   'Bürgerenergie Krautheim\n',
#   '\n'],
#  ['Windpark Krensheim\n',
#   '2001\n',
#   '1,8\n',
#   '3\n',
#   'Enercon E-40/6.44 E1 (3×)\n',
#   'Krensheim\n',
#   'TBB\n',
#   '49°\xa037′\xa032″\xa0N, 9°\xa046′\xa08″\xa0O\n',
#   'BadenWind\n',
#   '\n'],
#  ['Windpark Külsheim[83][84]\n',
#   '2016\n',
#   '12,0\n',
#   '5\n',
#   'Nordex N117/2400 (5×)\n',
#   'Külsheim\n',
#   'TBB\n',
#   '49°\xa039′\xa013″\xa0N, 9°\xa032′\xa034″\xa0O\n',
#   'Thüga, Stadtwerk Tauberfranken\n',
#   '\n'],
#  ['Windpark Külsheim-Steinbach\n',
#   '2004\n',
#   '2,4\n',
#   '4\n',
#   'Enercon E-40/6.44 (4×)\n',
#   'Steinbach\n',
#   'TBB\n',
#   '49°\xa040′\xa031″\xa0N, 9°\xa029′\xa019″\xa0O\n',
#   'BadenWind, WP Külsheim\n',
#   '\n'],
#  ['Windpark Lahr-Seelbach[85][86] (Windkraftanlagen Kempfenbühl-Schlossbühl)\n',
#   '200520162021\n',
#   '8,7\n',
#   '3\n',
#   'Südwind S77 (1×)Enercon E-115 (1×)Enercon E-138 EP3 E2 (1×)\n',
#   'LahrSeelbach\n',
#   'OG\n',
#   '48°\xa017′\xa032″\xa0N, 7°\xa053′\xa034″\xa0O\n',
#   'fesa, Ökostrom Freiburg\n',
#   'Eine weitere Anlage des Typs Südwind S77 wurde im September 2013 durch einen Brand komplett zerstört, als Ersatz wurde 2016 eine Enercon E-115 an selber Stelle errichtet\nEine weitere Anlage des Typs Südwind S77 wurde im Februar 2019 durch einen Brand komplett zerstört. An dieser Stelle wurde 2021 eine neue Windkraftanlage des Typs Enercon E-138 EP3 E2 errichtet\n\n'],
#  ['Windpark Langenbrand\n',
#   '19992023\n',
#   '18,0\n',
#   '4\n',
#   'Nordex N149/4500 (4×)\n',
#   'Langenbrand\n',
#   'CW\n',
#   '48°\xa049′\xa08″\xa0N, 8°\xa035′\xa047″\xa0O\n',
#   'BayWa r.e.\n',
#   'eine Seewind 52/750 wurde 2021 aufgrund eines Brandschadens abgebaut, neue Anlagen aktuell in Bau\n'],
#  ['Windpark Lauda-Heckfeld[87]\n',
#   '200320202024\n',
#   '14,2\n',
#   '4\n',
#   'Enercon E-66/18.70 (1×)Vestas V126-3.45MW (2×)Vestas V162-5.6MW (1×)\n',
#   'HeckfeldDittwar\n',
#   'TBB\n',
#   '49°\xa034′\xa019″\xa0N, 9°\xa038′\xa04″\xa0O\n',
#   'juwi\n',
#   'errichtet an der A\xa081Erweiterung in Bau\n'],
#  ['Windpark Lauterburg[88]\n',
#   '2007\n',
#   '10,25\n',
#   '5\n',
#   'REpower MM92 (5×)\n',
#   'Lauterburg\n',
#   'AA\n',
#   '48°\xa046′\xa011″\xa0N, 10°\xa00′\xa06″\xa0O\n',
#   'WP Lauterburg\n',
#   '\n'],
#  ['Windpark Lauterstein[89]\n',
#   '2016\n',
#   '52,25\n',
#   '19\n',
#   'GE Wind Energy 2.75-120 (19×)\n',
#   'LautersteinBartholomä\n',
#   'GPAA\n',
#   '48°\xa044′\xa014″\xa0N, 9°\xa053′\xa014″\xa0O\n',
#   'wpd, drei der Anlagen werden von der Windpark Falkenberg GmbH (Stadtwerke Heidenheim AG - Unternehmensgruppe und deren Netzwerk) betrieben\n',
#   'größter Windpark in Baden-Württemberg sowie im süddeutschen Raum\n'],
#  ['Windpark Leipferdingen\n',
#   '1997\n',
#   '1,8\n',
#   '3\n',
#   'Vestas V44-600kW (3×)\n',
#   'Leipferdingen\n',
#   'TUT\n',
#   '47°\xa052′\xa06″\xa0N, 8°\xa041′\xa09″\xa0O\n',
#   'Aufwind\n',
#   'ursprünglich waren vier Anlagen des Typs geplant und genehmigt worden.\n'],
#  ['Windpark Lindlein[90]\n',
#   '2004\n',
#   '4,5\n',
#   '3\n',
#   'NEG Micon NM 82/1500 (3×)\n',
#   'Lindlein\n',
#   'SHA\n',
#   '49°\xa018′\xa023″\xa0N, 10°\xa00′\xa03″\xa0O\n',
#   'Bürgerwindpark Hohenlohe, Behlau Energiewende\n',
#   '\n'],
#  ['Windpark Lonsee-Ettlenschieß\n',
#   '20022012\n',
#   '4,64\n',
#   '5\n',
#   'Vestas V47-660kW (4×)Vestas V90-2.0MW (1×)\n',
#   'Ettlenschieß\n',
#   'UL\n',
#   '48°\xa034′\xa00″\xa0N, 9°\xa054′\xa013″\xa0O\n',
#   'Technische Werke Schussental, Willibald Heidrich\n',
#   '\n'],
#  ['Windpark Löwenstein[91][92] (Windpark Horkenberg)\n',
#   '20142020-2021\n',
#   '18,1\n',
#   '5\n',
#   'Enercon E-92 (2×)Nordex N149/4500 (3×)\n',
#   'Löwenstein\n',
#   'HN\n',
#   '49°\xa05′\xa031″\xa0N, 9°\xa026′\xa03″\xa0O\n',
#   'Kruck + Partner, DSG Energiefonds\n',
#   '\n'],
#  ['Windpark Nattheim[93]\n',
#   '2021\n',
#   '37,8\n',
#   '9\n',
#   'Enercon E-138 EP3 E2 (9×)\n',
#   'Nattheim\n',
#   'HDH\n',
#   '48°\xa042′\xa058″\xa0N, 10°\xa013′\xa015″\xa0O\n',
#   'Stadtwerke Heidenheim AG - Unternehmensgruppe (25,1 Prozent), Alterric (25,1 Prozent) sowie weitere Energieversorgungsunternehmen und Banken aus dem Netzwerk der Stadtwerke Heidenheim AG - Unternehmensgruppe\n',
#   'Durch Sturm Ignatz am 21.\xa0Oktober 2021 knickt an einer Anlage ein Rotorblatt ab. Die Reparatur ist inzwischen erfolgreich abgeschlossen.\n'],
#  ['Windpark Nonnenholz-Uhl[94]\n',
#   '2017\n',
#   '35,6\n',
#   '11\n',
#   'GE Wind Energy 2.75-120 (4×)Vestas V136-3.6MW (6×)Nordex N117/3000 (1×)\n',
#   'RöhlingenZöbingen\n',
#   'AA\n',
#   '48°\xa056′\xa017″\xa0N, 10°\xa016′\xa022″\xa0O\n',
#   'ABO Wind\n',
#   '\n'],
#  ['Windpark Nordschwarzwald[95]\n',
#   '2007\n',
#   '28,0\n',
#   '14\n',
#   'Vestas V80-2.0MW (4×)Vestas V90-2.0MW (10×)\n',
#   'SimmersfeldSeewald\n',
#   'CWFDS\n',
#   '48°\xa037′\xa05″\xa0N, 8°\xa027′\xa028″\xa0O\n',
#   'Altus, Breeze Two, Glotter\n',
#   'war bei der Errichtung bis 2015 der größte Windpark in Baden-Württemberg, errichtet auf einem ehemaligen Munitionsdepot und entlang der B\xa0294\n'],
#  ['Windpark Oberkochen[96][97]\n',
#   '2015\n',
#   '9,6\n',
#   '4\n',
#   'Nordex N117/2400 (4×)\n',
#   'Oberkochen\n',
#   'AA\n',
#   '48°\xa046′\xa012″\xa0N, 10°\xa07′\xa016″\xa0O\n',
#   'juwi, Stadtwerke Tübingen\n',
#   '\n'],
#  ['Windpark Obersontheim-Bühlenzell[98]\n',
#   '20172018\n',
#   '32,4\n',
#   '9\n',
#   'Vestas V136-3.6MW (9×)\n',
#   'ObersontheimBühlerzell\n',
#   'SHA\n',
#   '49°\xa00′\xa015″\xa0N, 9°\xa050′\xa027″\xa0O\n',
#   'Uhl Windkraft\n',
#   '\n'],
#  ['Windpark Prechtaler Schanze[99][100]\n',
#   '20152016\n',
#   '18,3\n',
#   '6\n',
#   'Enercon E-101 (3×)Enercon E-115 (3×)\n',
#   'GutachMühlenbach\n',
#   'OG\n',
#   '48°\xa013′\xa016″\xa0N, 8°\xa010′\xa08″\xa0O\n',
#   'E-Werk Mittelbaden\n',
#   '\n'],
#  ['Windpark Pülfringen Nord\n',
#   '20012017\n',
#   '10,8\n',
#   '10\n',
#   'Enercon E-40/6.44 (8×)Enercon E-115 (2×)\n',
#   'Pülfringen\n',
#   'TBB\n',
#   '49°\xa035′\xa024″\xa0N, 9°\xa031′\xa011″\xa0O\n',
#   'BadenWind\n',
#   '\n'],
#  ['Windpark Pülfringen Süd\n',
#   '200120022012\n',
#   '14,7\n',
#   '10\n',
#   'AN Bonus 1300/62 (7×)Enercon E-58 (1×)Enercon E-82 E2 (2×)\n',
#   'PülfringenErfeld\n',
#   'TBBMOS\n',
#   '49°\xa033′\xa017″\xa0N, 9°\xa030′\xa032″\xa0O\n',
#   'PNE Wind\n',
#   '\n'],
#  ['Windpark Rauhkasten-Steinfirst[101]\n',
#   '2017\n',
#   '12,2\n',
#   '4\n',
#   'Enercon E-115 (4×)\n',
#   'GengenbachFriesenheimHohberg\n',
#   'OG\n',
#   '48°\xa022′\xa05″\xa0N, 7°\xa058′\xa031″\xa0O\n',
#   'Enercon\n',
#   '\n'],
#  ['Windpark Ravenstein[102]\n',
#   '2015\n',
#   '10,0\n',
#   '4\n',
#   'GE Wind Energy 2.5-120 (4×)\n',
#   'Merchingen\n',
#   'MOS\n',
#   '49°\xa025′\xa01″\xa0N, 9°\xa029′\xa09″\xa0O\n',
#   'Green City Energy\n',
#   'errichtet an der A\xa081\n'],
#  ['Windpark Ravensteiner Höhe[103]\n',
#   '20042007\n',
#   '6,55\n',
#   '4\n',
#   'REpower MD77 (2×)Fuhrländer FL MD77 (1×)REpower MM92 (1×)\n',
#   'Merchingen\n',
#   'MOS\n',
#   '49°\xa023′\xa023″\xa0N, 9°\xa032′\xa05″\xa0O\n',
#   'Windenergie S & H, Reg.En GmbH, THEOLIA Naturenergien GmbH\n',
#   '\n'],
#  ['Windpark Rechenberg[104]\n',
#   '2017\n',
#   '9,0\n',
#   '3\n',
#   'Enercon E-115 (3×)\n',
#   'Rechenberg\n',
#   'SHA\n',
#   '49°\xa03′\xa05″\xa0N, 10°\xa07′\xa011″\xa0O\n',
#   'W-I-N-D Energien\n',
#   '\n'],
#  ['Windpark Renquishausen\n',
#   '1996\n',
#   '1,5\n',
#   '3\n',
#   'Enercon E-40/5.40 (3×)\n',
#   'Renquishausen\n',
#   'TUT\n',
#   '48°\xa05′\xa012″\xa0N, 8°\xa052′\xa029″\xa0O\n',
#   'WP Renquishausen\n',
#   'eine weitere baugleiche Anlage wurde bereits abgebaut\n'],
#  ['Windpark Rohrenkopf[105] (Windpark Schopfheim)\n',
#   '20162017\n',
#   '15,0\n',
#   '5\n',
#   'Enercon E-115 (5×)\n',
#   'Gersbach\n',
#   'LÖ\n',
#   '47°\xa043′\xa05″\xa0N, 7°\xa056′\xa022″\xa0O\n',
#   'EWS\n',
#   'Ein zwischenzeitlicher Baustopp wurde wieder aufgehoben[106]\n'],
#  ['Windpark Roßkopf[107]\n',
#   '2003\n',
#   '7,2\n',
#   '4\n',
#   'Enercon E-66/18.70 (4×)\n',
#   'GundelfingenFreiburg im Breisgau\n',
#   'FRFR\n',
#   '48°\xa00′\xa026″\xa0N, 7°\xa054′\xa08″\xa0O\n',
#   'fesa, Ökostrom Freiburg\n',
#   'Repowering geplant (2× Enercon E-138 EP3 E3 statt 4× Enercon E-66/18.70)\n'],
#  ['Windpark Rot am See[108] (Windpark Hausen am Bach)\n',
#   '20162019\n',
#   '13,2\n',
#   '4\n',
#   'Vestas V126-3.3MW (4×)\n',
#   'Hausen am Bach\n',
#   'SHA\n',
#   '49°\xa018′\xa011″\xa0N, 10°\xa07′\xa032″\xa0O\n',
#   'juwi, EnBW Windkraftprojekte, EnBW-ODR\n',
#   '\n'],
#  ['Windpark Rote Steige[109]\n',
#   '20172018\n',
#   '21,6\n',
#   '6\n',
#   'Vestas V136-3.6MW (6×)\n',
#   'MichelfeldMainhardt\n',
#   'SHA\n',
#   '49°\xa05′\xa010″\xa0N, 9°\xa038′\xa021″\xa0O\n',
#   'Stadtwerke Schwäbisch Hall, Uhl Windkraft\n',
#   'an der Bundesstraße 14\n'],
#  ['Windpark Rotzeleck[110]\n',
#   '20192020\n',
#   '8,9\n',
#   '3\n',
#   'Enercon E-92 (1×)Enercon E-103 EP2 (1×)Enercon E-138 EP3 E2 (1×)\n',
#   'Biederbach\n',
#   'EM\n',
#   '48°\xa012′\xa019″\xa0N, 7°\xa059′\xa011″\xa0O\n',
#   'Oeko Geno\n',
#   'Erweiterung geplant (1× Enercon E-175 EP5)\n'],
#  ['Windpark Schelklingen\n',
#   '2000\n',
#   '3,75\n',
#   '5\n',
#   'NEG Micon NM 48/750 (5×)\n',
#   'Ingstetten\n',
#   'UL\n',
#   '48°\xa023′\xa019″\xa0N, 9°\xa037′\xa019″\xa0O\n',
#   'Albwind Ingstetten-Justingen, Theolia, Windreich\n',
#   '\n'],
#  ['Windpark Schonach\n',
#   '200120022006\n',
#   '7,6\n',
#   '5\n',
#   'Enercon E-40/6.44 (1×)Südwind S77 (1×)Südwind S77 (1×)Enercon E-70 (2×)\n',
#   'Schonach\n',
#   'VS\n',
#   '48°\xa07′\xa027″\xa0N, 8°\xa011′\xa031″\xa0O\n',
#   'wks-energy, THEOLIA Naturenergien GmbH\n',
#   'eine Enercon E-12 bereits abgebaut\n'],
#  ['Windpark St. Peter[111][112] (incl. Windpark Plattenhöfe)\n',
#   '20002001200620102013\n',
#   '16,0\n',
#   '9\n',
#   'NEG Micon NM 60/1000 (3×)Enercon E-40/6.44 (1×)Enercon E-70 (2×)Enercon E-70 E4 (1×)Enercon E-101 (2×)\n',
#   'SägendobelSimonswald\n',
#   'FREM\n',
#   '48°\xa03′\xa06″\xa0N, 8°\xa04′\xa06″\xa0O\n',
#   'fesa, Ökostrom Freiburg; THEOLIA Naturenergien GmbH, Windreich\n',
#   '\n'],
#  ['Windpark Stachenhausen\n',
#   '200320072008\n',
#   '9,7\n',
#   '5\n',
#   'REpower MD77 (1×)REpower MM92 (4×)\n',
#   'Stachenhausen\n',
#   'KÜN\n',
#   '49°\xa020′\xa023″\xa0N, 9°\xa041′\xa022″\xa0O\n',
#   'Reg.En GmbH\n',
#   '\n'],
#  ['Windpark Steinbacher Höhe[113][114]\n',
#   '2010\n',
#   '6,15\n',
#   '3\n',
#   'REpower MM92 (3×)\n',
#   'Steinbach\n',
#   'MOS\n',
#   '49°\xa033′\xa017″\xa0N, 9°\xa015′\xa010″\xa0O\n',
#   'Naturstrom AG, Windenergie S & H, WP Mudau\n',
#   '\n'],
#  ['Windpark Stödtlen\n',
#   '20062022\n',
#   '13,35\n',
#   '5\n',
#   'REpower MM92 (3×)Vestas V126-3.6MW (2×)\n',
#   'Gerau\n',
#   'AA\n',
#   '48°\xa049′\xa02″\xa0N, 10°\xa017′\xa028″\xa0O\n',
#   'Uhl-Windkraft, Breeze Three Energy\n',
#   '\n'],
#  ['Windpark Stötten[115]\n',
#   '199620012002200620112023\n',
#   '13,2\n',
#   '11\n',
#   'Vestas V44-600kW (1×)Vestas V52-850kW (4×)DeWind D6 62/1000 (1×)Vestas V90-2.0MW (2×)Schuler SDD 100 2,7MW (1×)S&G Engineering SG750.54 (2×)\n',
#   'Stötten\n',
#   'GP\n',
#   '48°\xa039′\xa028″\xa0N, 9°\xa051′\xa017″\xa0O\n',
#   'Megawatt, wpd, Schuler\n',
#   'Windtestfeld Stötten seit 1956 (Begründer Ulrich W. Hütter), seit 1997 kommerzieller Windpark.\nPrototyp und einzige Anlage der Schuler SDD 100derzeit Errichtung von zwei Testanlagen des Typs S&G Engineering SG750.54 im Rahmen des ZSW-Forschungswindparks WinSent[116]\n\n'],
#  ['Windpark Straubenhardt\n',
#   '2017-2018\n',
#   '33\n',
#   '11\n',
#   'Siemens SWT-3.0-113 (11×)\n',
#   'Straubenhardt\n',
#   'PF\n',
#   '48°\xa048′\xa054″\xa0N, 8°\xa031′\xa031″\xa0O\n',
#   'Wirsol, Wircon GmbH, seit 2019 Kraftwerke Mainz-Wiesbaden\n',
#   '\n'],
#  ['Windpark Striethof[117]\n',
#   '20042009\n',
#   '10,0\n',
#   '5\n',
#   'Vestas V80-2.0MW (2×)Enercon E-82 (3×)\n',
#   'RuppertshofenEschach\n',
#   'AA\n',
#   '48°\xa053′\xa01″\xa0N, 9°\xa050′\xa05″\xa0O\n',
#   'WP Striethof\n',
#   '\n'],
#  ['Windpark Sturmberg\n',
#   '1996\n',
#   '3,0\n',
#   '3\n',
#   'Nordex N54/1000 (3×)\n',
#   'Judentenberg\n',
#   'SIG\n',
#   '47°\xa053′\xa08″\xa0N, 9°\xa021′\xa010″\xa0O\n',
#   'Glotter, Aufwind\n',
#   '\n'],
#  ['Windpark Südliche Ortenau[78]\n',
#   '2016\n',
#   '19,25\n',
#   '7\n',
#   'GE Wind Energy 2.75-120 (7×)\n',
#   'EttenheimSchuttertal\n',
#   'OG\n',
#   '48°\xa015′\xa016″\xa0N, 7°\xa055′\xa022″\xa0O\n',
#   'Green City Energy, Ettenheimer Bürgerenergie\n',
#   '\n'],
#  ['Windpark Sulzbach-Laufen\n',
#   '2016\n',
#   '38,92\n',
#   '7\n',
#   'Enercon E-160 EP5 E3 (7×)\n',
#   'Sulzbach-Laufen\n',
#   'SHA\n',
#   '48°\xa059′\xa010″\xa0N, 9°\xa050′\xa047″\xa0O\n',
#   'Uhl Windkraft\n',
#   'in Bau\n'],
#  ['Windpark Tegelberg\n',
#   '20172018\n',
#   '8,25\n',
#   '3\n',
#   'GE Wind Energy 2.75-120 (3×)\n',
#   'Donzdorf\n',
#   'GP\n',
#   '48°\xa038′\xa039″\xa0N, 9°\xa049′\xa05″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Tennenbronn[118] (incl. Windpark Steigers Eck)\n',
#   '200220032005201120162017\n',
#   '21,9\n',
#   '10\n',
#   'Enercon E-66/18.70 (1×)Enercon E-70 E4 (1×)Enercon E-115 (2×)REpower MD77 (2×)Vestas V90-2.0MW (2×)Nordex N117/2400 (2×)\n',
#   'TennenbronnBuchenbergLangenschiltachHornberg\n',
#   'OGRWVS\n',
#   '48°\xa011′\xa010″\xa0N, 8°\xa018′\xa013″\xa0O\n',
#   'Windkraft Tennenbronn; vento ludens, dge Wind Brogen, Solarcomplex\n',
#   '\n'],
#  ['Windpark Tomerdingen-Bermaringen[119][120] (Windpark Keltische Schanze)\n',
#   '200720132017\n',
#   '21,9\n',
#   '11\n',
#   'Vestas V82-1.5MW (5×)Nordex N117/2400 (6×)\n',
#   'TomerdingenBermaringenTemmenhausen\n',
#   'UL\n',
#   '48°\xa028′\xa013″\xa0N, 9°\xa051′\xa048″\xa0O\n',
#   'Planet Energy, Solarinvest AG; Efi Wind, THEOLIA Naturenergien GmbH, Windreich\n',
#   'errichtet an der A\xa08\n'],
#  ['Windpark Verenafohren[121]\n',
#   '2017\n',
#   '9,9\n',
#   '3\n',
#   'Nordex N131/3300 (3×)\n',
#   'Wiechs am Randen\n',
#   'KN\n',
#   '47°\xa046′\xa07″\xa0N, 8°\xa037′\xa032″\xa0O\n',
#   'hegauwind\n',
#   'errichtet direkt an der Schweizer Grenze\n'],
#  ['Windpark Waldhausen[122]\n',
#   '20072017\n',
#   '30,85\n',
#   '12\n',
#   'REpower MM92 (7×)Vestas V126-3.3MW (5×)\n',
#   'Waldhausen\n',
#   'AA\n',
#   '48°\xa050′\xa08″\xa0N, 10°\xa012′\xa024″\xa0O\n',
#   'Uhl Windkraft; ENBW\n',
#   'errichtet an der A\xa07\n'],
#  ['Windpark Waldmössingen[123]\n',
#   '2002\n',
#   '3,6\n',
#   '4\n',
#   'NEG Micon NM 52/900 (4×)\n',
#   'Waldmössingen\n',
#   'RW\n',
#   '48°\xa015′\xa028″\xa0N, 8°\xa030′\xa016″\xa0O\n',
#   'Theolia, Windreich, WP Hummelbühl\n',
#   '\n'],
#  ['Windpark Wallhausen[124]\n',
#   '20112018\n',
#   '7,6\n',
#   '4\n',
#   'Enercon E-53 (2×)Enercon E-115 (2×)\n',
#   'Schainbach\n',
#   'SHA\n',
#   '49°\xa014′\xa011″\xa0N, 10°\xa03′\xa09″\xa0O\n',
#   'Stollmeier\n',
#   '\n'],
#  ['Windpark Weilermerkingen-Ohmenheim\n',
#   '20072016\n',
#   '22,65\n',
#   '9\n',
#   'REpower MM92 (3×)GE Wind Energy 2.75-120 (6×)\n',
#   'WeilermerkingenOhmenheim\n',
#   'AA\n',
#   '48°\xa047′\xa028″\xa0N, 10°\xa021′\xa01″\xa0O\n',
#   'WP Weilermerkingen; WP Ohmenheim\n',
#   'Am 17. Juli 2018 wurde durch einen Blitzschlag ein Rotorblatt eines der REpower-Anlagen beschädigt[125]\n'],
#  ['Windpark Weißbach[126]\n',
#   '20012016\n',
#   '18,5\n',
#   '7\n',
#   'NEG Micon NM 60/1000 (2×)Vestas V126-3.3MW (5×)\n',
#   'Crispenhofen\n',
#   'KÜN\n',
#   '49°\xa019′\xa023″\xa0N, 9°\xa034′\xa031″\xa0O\n',
#   'Specht Windkraft, Bürger-WP Hohenlohe\n',
#   '\n'],
#  ['Windpark Wenkheim[127]\n',
#   '2007\n',
#   '18,0\n',
#   '9\n',
#   'Vestas V80-2.0MW (9×)\n',
#   'Wenkheim\n',
#   'TBB\n',
#   '49°\xa042′\xa031″\xa0N, 9°\xa041′\xa07″\xa0O\n',
#   'Energiequelle, UMaAG\n',
#   '\n'],
#  ['Windpark Werbachhausen[65]\n',
#   '2012\n',
#   '6,3\n',
#   '3\n',
#   'Enercon E-82 (2×)Enercon E-82 E2 (1×)\n',
#   'Werbachhausen\n',
#   'TBB\n',
#   '49°\xa040′\xa016″\xa0N, 9°\xa042′\xa012″\xa0O\n',
#   'Windreich, Energie Bals, W-I-N-D Energien\n',
#   '\n'],
#  ['Windpark Werdeck\n',
#   '2017\n',
#   '9,9\n',
#   '3\n',
#   'Vestas V126-3.3MW (3×)\n',
#   'Werdeck\n',
#   'SHA\n',
#   '49°\xa013′\xa055″\xa0N, 9°\xa056′\xa048″\xa0O\n',
#   '\n',
#   '\n'],
#  ['Windpark Westerheim[128]\n',
#   '1998200120022020\n',
#   '4,5\n',
#   '3\n',
#   'Südwind S70 (1×)REpower MD77 (2×)\n',
#   'Westerheim\n',
#   'UL\n',
#   '48°\xa032′\xa03″\xa0N, 9°\xa037′\xa032″\xa0O\n',
#   'Alb-Windkraft, EnBW Energie Baden-Württemberg\n',
#   'eine NEG Micon NM 48/600 2020 abgebaut\n'],
#  ['Windpark Wiesensteig[129]\n',
#   '1999\n',
#   '4,5\n',
#   '6\n',
#   'NEG Micon NM 48/750 (6×)\n',
#   'Wiesensteig\n',
#   'GP\n',
#   '48°\xa033′\xa05″\xa0N, 9°\xa037′\xa011″\xa0O\n',
#   'SoWiTec\n',
#   '\n'],
#  ['Windpark Wittighausen[130]\n',
#   '2002\n',
#   '5,94\n',
#   '9\n',
#   'Vestas V47-660kW (9×)\n',
#   'Unterwittighausen\n',
#   'TBB\n',
#   '49°\xa037′\xa011″\xa0N, 9°\xa048′\xa010″\xa0O\n',
#   'UMaAG\n',
#   'Am 17.3.2019 brach durch das Sturmtief Eberhard bei einer Anlage ein Flügel ab. Die Anlage wurde nicht repariert. Eine weitere Anlage seither außer Betrieb.\n']]

# %%
len(rows)
# Out:
# 202

# %%
# Example of string cleaning:

name=rows[1][0].strip()
name=re.sub(r'\[\d+\]', '', name)
name
# Out:
# 'Forschungswindkraftanlage RedoxWind'

# %%
#Example of years string cleaning (not completely perfect)

years=rows[3][1].strip()

commas=[3,7,11,15, 19, 23, 27,31]
output=''.join(c + ',' * (i in commas) for i, c in enumerate(years))


output
# Out:
# '1999,2013,'

# %%
#filling the dictionary
for x in rows[1:201]:
    
    years=x[1].strip()
    years=''.join(c + ',' * (i in commas) for i, c in enumerate(years))
    table_dict['Baujahr'].append(years)
    
table_dict['Baujahr']
# Out:
# ['2017,',
#  '2003,',
#  '1999,2013,',
#  '1990,',
#  '1992,',
#  '2002,',
#  '2001,',
#  '2014,',
#  '2020,',
#  '2015,',
#  '2001,',
#  '2014,',
#  '1998,',
#  '2003,',
#  '2003,',
#  '2001,',
#  '1993,1995,',
#  '1996,',
#  '1997,',
#  '2005,',
#  '2003,',
#  '2000,',
#  '2000,',
#  '1999,',
#  '2007,',
#  '1994,1996,2015,',
#  '2012,',
#  '2023,',
#  '2023,-202,4',
#  '2023,-202,4',
#  '1994,',
#  '2003,',
#  '1997,',
#  '2002,',
#  '2006,',
#  '2012,',
#  '2003,',
#  '2020,',
#  '2003,',
#  '1997,1998,2013,',
#  '1996,',
#  '2006,',
#  '2001,',
#  '2011,',
#  '2002,',
#  '2022,',
#  '1990,',
#  '2005,',
#  '1998,',
#  '2004,',
#  '2000,',
#  '2024,',
#  '1998,2005,',
#  '2017,',
#  '2004,2006,',
#  '1996,',
#  '1997,2003,',
#  '2003,',
#  '2002,2003,',
#  '2005,2010,',
#  '2024,',
#  '2023,',
#  '2002,',
#  '2003,2024,',
#  '1998,2000,2003,2019,',
#  '2020,',
#  '2001,',
#  '2015,',
#  '1999,',
#  '2000,2002,',
#  '2003,',
#  '2001,2002,',
#  '2008,',
#  '2000,',
#  '2024,',
#  '2000,2003,',
#  '2005,',
#  '2001,',
#  '2001,',
#  '2016,',
#  '1989,1990,',
#  '2017,',
#  '2011,2016,2017,',
#  '2000,2011,2023,',
#  '2001,2002,2003,2018,2023,-202,4',
#  '1998,2002,',
#  '2017,2022,',
#  '2002,2005,',
#  '2000,2006,',
#  '2007,2015,2024,',
#  '2019,',
#  '2002,2009,2012,2017,',
#  '2017,2018,',
#  '2018,',
#  '2001,2007,',
#  '2000,',
#  '2004,2017,',
#  '2014,2016,2017,',
#  '1997,2002,2018,',
#  '2016,',
#  '2017,',
#  '2021,2022,-202,3',
#  '2016,2019,',
#  '2024,',
#  '2016,',
#  '2017,2018,',
#  '2000,2020,',
#  '2000,',
#  '2016,',
#  '2016,2017,',
#  '2000,2001,',
#  '2021,',
#  '2017,',
#  '2004,2015,',
#  '2001,2002,2004,2011,2014,2023,-202,4',
#  '2007,2016,',
#  '2017,',
#  '1998,2002,2005,',
#  '2018,2021,',
#  '2009,2020,-202,1',
#  '2017,',
#  '2013,',
#  '2003,',
#  '2022,',
#  '2015,2017,',
#  '2017,',
#  '2002,2017,',
#  '2019,2020,',
#  '1997,2000,2002,2003,2004,2005,2010,2011,201220152016',
#  '2017,',
#  '1995,',
#  '2004,2016,',
#  '2020,-202,1',
#  '2001,2002,',
#  '2022,-202,3',
#  '2008,',
#  '2002,2009,2020,',
#  '2017,',
#  '2006,2007,2014,2015,2017,2021,',
#  '2016,',
#  '2000,2009,2016,',
#  '2015,',
#  '2015,',
#  '2021,',
#  '2001,',
#  '2016,',
#  '2004,',
#  '2005,2016,2021,',
#  '1999,2023,',
#  '2003,2020,2024,',
#  '2007,',
#  '2016,',
#  '1997,',
#  '2004,',
#  '2002,2012,',
#  '2014,2020,-202,1',
#  '2021,',
#  '2017,',
#  '2007,',
#  '2015,',
#  '2017,2018,',
#  '2015,2016,',
#  '2001,2017,',
#  '2001,2002,2012,',
#  '2017,',
#  '2015,',
#  '2004,2007,',
#  '2017,',
#  '1996,',
#  '2016,2017,',
#  '2003,',
#  '2016,2019,',
#  '2017,2018,',
#  '2019,2020,',
#  '2000,',
#  '2001,2002,2006,',
#  '2000,2001,2006,2010,2013,',
#  '2003,2007,2008,',
#  '2010,',
#  '2006,2022,',
#  '1996,2001,2002,2006,2011,2023,',
#  '2017,-201,8',
#  '2004,2009,',
#  '1996,',
#  '2016,',
#  '2016,',
#  '2017,2018,',
#  '2002,2003,2005,2011,2016,2017,',
#  '2007,2013,2017,',
#  '2017,',
#  '2007,2017,',
#  '2002,',
#  '2011,2018,',
#  '2007,2016,',
#  '2001,2016,',
#  '2007,',
#  '2012,',
#  '2017,',
#  '1998,2001,2002,2020,',
#  '1999,']

# %%
#I decided to leave only the first date
table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
table_dict['Baujahr']
# Out:
# ['2017',
#  '2003',
#  '1999',
#  '1990',
#  '1992',
#  '2002',
#  '2001',
#  '2014',
#  '2020',
#  '2015',
#  '2001',
#  '2014',
#  '1998',
#  '2003',
#  '2003',
#  '2001',
#  '1993',
#  '1996',
#  '1997',
#  '2005',
#  '2003',
#  '2000',
#  '2000',
#  '1999',
#  '2007',
#  '1994',
#  '2012',
#  '2023',
#  '2023',
#  '2023',
#  '1994',
#  '2003',
#  '1997',
#  '2002',
#  '2006',
#  '2012',
#  '2003',
#  '2020',
#  '2003',
#  '1997',
#  '1996',
#  '2006',
#  '2001',
#  '2011',
#  '2002',
#  '2022',
#  '1990',
#  '2005',
#  '1998',
#  '2004',
#  '2000',
#  '2024',
#  '1998',
#  '2017',
#  '2004',
#  '1996',
#  '1997',
#  '2003',
#  '2002',
#  '2005',
#  '2024',
#  '2023',
#  '2002',
#  '2003',
#  '1998',
#  '2020',
#  '2001',
#  '2015',
#  '1999',
#  '2000',
#  '2003',
#  '2001',
#  '2008',
#  '2000',
#  '2024',
#  '2000',
#  '2005',
#  '2001',
#  '2001',
#  '2016',
#  '1989',
#  '2017',
#  '2011',
#  '2000',
#  '2001',
#  '1998',
#  '2017',
#  '2002',
#  '2000',
#  '2007',
#  '2019',
#  '2002',
#  '2017',
#  '2018',
#  '2001',
#  '2000',
#  '2004',
#  '2014',
#  '1997',
#  '2016',
#  '2017',
#  '2021',
#  '2016',
#  '2024',
#  '2016',
#  '2017',
#  '2000',
#  '2000',
#  '2016',
#  '2016',
#  '2000',
#  '2021',
#  '2017',
#  '2004',
#  '2001',
#  '2007',
#  '2017',
#  '1998',
#  '2018',
#  '2009',
#  '2017',
#  '2013',
#  '2003',
#  '2022',
#  '2015',
#  '2017',
#  '2002',
#  '2019',
#  '1997',
#  '2017',
#  '1995',
#  '2004',
#  '2020',
#  '2001',
#  '2022',
#  '2008',
#  '2002',
#  '2017',
#  '2006',
#  '2016',
#  '2000',
#  '2015',
#  '2015',
#  '2021',
#  '2001',
#  '2016',
#  '2004',
#  '2005',
#  '1999',
#  '2003',
#  '2007',
#  '2016',
#  '1997',
#  '2004',
#  '2002',
#  '2014',
#  '2021',
#  '2017',
#  '2007',
#  '2015',
#  '2017',
#  '2015',
#  '2001',
#  '2001',
#  '2017',
#  '2015',
#  '2004',
#  '2017',
#  '1996',
#  '2016',
#  '2003',
#  '2016',
#  '2017',
#  '2019',
#  '2000',
#  '2001',
#  '2000',
#  '2003',
#  '2010',
#  '2006',
#  '1996',
#  '2017',
#  '2004',
#  '1996',
#  '2016',
#  '2016',
#  '2017',
#  '2002',
#  '2007',
#  '2017',
#  '2007',
#  '2002',
#  '2011',
#  '2007',
#  '2001',
#  '2007',
#  '2012',
#  '2017',
#  '1998',
#  '1999']

# %%
#filling the dictionaries:

for i in rows [1:201]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
table_dict['Name']
# Out:
# ['Forschungswindkraftanlage RedoxWind',
#  'Windkraftanlage Alexanderschanze',
#  'Windkraftanlage Alpirsbach',
#  'Windkraftanlage Auenberg',
#  'Windkraftanlage auf dem Hohwartsattel',
#  'Windkraftanlage Bad Mergentheim',
#  'Windkraftanlage Binselberg',
#  'Windkraftanlage Birkenzell',
#  'Windkraftanlage Bopfingen',
#  'Windkraftanlage Bronn',
#  'Windkraftanlage Dauchingen',
#  'Windkraftanlage Dettenberg',
#  'Windkraftanlage Dewangen',
#  'Windkraftanlage Dornhan',
#  'Windkraftanlage Dornstetten',
#  'Windkraftanlage Ellenberg',
#  'Windkraftanlage Emmingen',
#  'Windkraftanlage Fernhöhe',
#  'Windkraftanlage Fischerbach',
#  'Windkraftanlage Fröhnd',
#  'Windkraftanlage Fürstenberg',
#  'Windkraftanlage Glatten',
#  'Windkraftanlage Grüner Heiner',
#  'Windkraftanlage Herbolzheim',
#  'Windkraftanlage Honhardt',
#  'Windkraftanlage Hornisgrinde',
#  'Windkraftanlage Ingersheim',
#  'Windkraftanlage Kallenwald',
#  'Windkraftanlagen Königseiche',
#  'Windkraftanlagen Laichingen',
#  'Windkraftanlage Leibertingen',
#  'Windkraftanlage Lenzkirch-Kopp',
#  'Windkraftanlage Maxau',
#  'Windkraftanlage Mengen',
#  'Windkraftanlage Mulfingen',
#  'Windkraftanlage Oberiflingen',
#  'Windkraftanlage Oberkirch',
#  'Windkraftanlage Ochsenberg',
#  'Windkraftanlage Rohrhardsberg',
#  'Windkraftanlage Schweighausen',
#  'Windkraftanlage Sontheim',
#  'Windkraftanlage Streuberg',
#  'Windkraftanlage Ummendorf',
#  'Windkraftanlage Unterkessach',
#  'Windkraftanlage Untermusbach',
#  'Windkraftanlage Veringenstadt',
#  'Windkraftanlage Walzbachtal',
#  'Windkraftanlage Wegses',
#  'Windkraftanlage Weitingen',
#  'Windkraftanlage Welzheim',
#  'Windkraftanlage Zimmern',
#  'Windkraftanlagen Bad Wildbad',
#  'Windkraftanlagen Bonndorf',
#  'Windkraftanlagen Brettenfeld',
#  'Windkraftanlagen Buchhausen',
#  'Windkraftanlagen Bühlerzimmern/Veinau',
#  'Windkraftanlagen Dürrenmettstetten',
#  'Windkraftanlagen Fluorn-Winzeln',
#  'Windkraftanlagen Gerchsheim',
#  'Windkraftanlagen Gissigheim',
#  'Windkraftanlagen Grömbach',
#  'Windkraftanlagen Häusern',
#  'Windkraftanlagen Hettingen',
#  'Windkraftanlagen Holzschlägermatte',
#  'Windkraftanlagen Karlsruhe (Energieberg Karlsruhe)',
#  'Windkraftanlagen Kreßberg',
#  'Windkraftanlagen Loßburg',
#  'Windkraftanlagen Nassau',
#  'Windkraftanlagen Nellingen',
#  'Windkraftanlagen Nesselbach',
#  'Windkraftanlagen Neueck',
#  'Windkraftanlagen Schalkstetten',
#  'Windkraftanlagen Seckach',
#  'Windkraftanlagen Suppingen',
#  'Windkraftanlagen Taubenkopf',
#  'Windkraftanlagen Unterriffingen',
#  'Windkraftanlagen Unterschwarzach',
#  'Windkraftanlagen Weilersbach',
#  'Windkraftanlagen Wolpertshausen',
#  'Windkraftanlage Zottishofen',
#  'Windkraftanlagentestfeld Heroldstatt',
#  'Windpark Ahorn-Buch',
#  'Windpark Ahorn-Schillingstadt',
#  'Windpark Altheimer Höhe',
#  'Windpark Am Hochsträß',
#  'Windpark Amstetten',
#  'Windpark Amtenhauser Berg',
#  'Windpark Aufhausen',
#  'Windpark Auingen',
#  'Windpark Bad Rippoldsau-Schapbach',
#  'Windpark Bad Saulgau (Windpark Schellenberg)',
#  'Windpark Berghülen-Blaubeuren',
#  'Windpark Blaufelden-Langenburg',
#  'Windpark Bobstadt',
#  'Windpark Böhmenkirch',
#  'Windpark Böttingen',
#  'Windpark Boxberg',
#  'Windpark Brandberg-Rosenberg-Virngrund',
#  'Windpark Brandenkopf-Nillkopf',
#  'Windpark Braunsbach',
#  'Windpark Bühlertann',
#  'Windpark Burgberg',
#  'Windpark Büttenbuch',
#  'Windpark Dainbach',
#  'Windpark Dischingen-Ohrberg',
#  'Windpark Dittwar',
#  'Windpark Drackenstein (incl. Windpark Gosbacher Alb)',
#  'Windpark Dunningen',
#  'Windpark Ebnat-Ochsenberg',
#  'Windpark Ellwanger Berge',
#  'Windpark Ettenheim-Kippenheim',
#  'Windpark Falkenhöhe',
#  'Windpark Fichtenau',
#  'Windpark Frauental',
#  'Windpark Freiamt (incl. Windkraftanlage Tännlebühl)',
#  'Windpark Freudenberg',
#  'Windpark Gaildorf (Naturstromspeicher Gaildorf)',
#  'Windpark Gerabronn',
#  'Windpark Gerichtstetten',
#  'Windpark Gnannenweiler',
#  'Windpark Goldboden',
#  'Windpark Großer Wald',
#  'Windpark Gütenbach',
#  'Windpark Hainstadt-Buchen',
#  'Windpark Harthäuser Wald',
#  'Windpark Hasel',
#  'Windpark Heckfeld',
#  'Windpark Herrenzimmern (Windpark Hühnernest)',
#  'Windpark Heide',
#  'Windpark Hilpensberg',
#  'Windpark Himmelberg',
#  'Windpark Hirschlanden',
#  'Windpark Hohenlochen',
#  'Windpark Höhefeld',
#  'Windpark Keltenschanze-Weilerhöhe',
#  'Windpark Holzkirch-Neenstetten',
#  'Windpark Hornberg',
#  'Windpark Hummelsweiler',
#  'Windpark Ilshofen-Ruppertshofen',
#  'Windpark Kambacher Eck',
#  'Windpark Kirchberg',
#  'Windpark Klosterwald',
#  'Windpark Kohlenstraße',
#  'Windpark Krautheim-Eckigbreit',
#  'Windpark Krensheim',
#  'Windpark Külsheim',
#  'Windpark Külsheim-Steinbach',
#  'Windpark Lahr-Seelbach (Windkraftanlagen Kempfenbühl-Schlossbühl)',
#  'Windpark Langenbrand',
#  'Windpark Lauda-Heckfeld',
#  'Windpark Lauterburg',
#  'Windpark Lauterstein',
#  'Windpark Leipferdingen',
#  'Windpark Lindlein',
#  'Windpark Lonsee-Ettlenschieß',
#  'Windpark Löwenstein (Windpark Horkenberg)',
#  'Windpark Nattheim',
#  'Windpark Nonnenholz-Uhl',
#  'Windpark Nordschwarzwald',
#  'Windpark Oberkochen',
#  'Windpark Obersontheim-Bühlenzell',
#  'Windpark Prechtaler Schanze',
#  'Windpark Pülfringen Nord',
#  'Windpark Pülfringen Süd',
#  'Windpark Rauhkasten-Steinfirst',
#  'Windpark Ravenstein',
#  'Windpark Ravensteiner Höhe',
#  'Windpark Rechenberg',
#  'Windpark Renquishausen',
#  'Windpark Rohrenkopf (Windpark Schopfheim)',
#  'Windpark Roßkopf',
#  'Windpark Rot am See (Windpark Hausen am Bach)',
#  'Windpark Rote Steige',
#  'Windpark Rotzeleck',
#  'Windpark Schelklingen',
#  'Windpark Schonach',
#  'Windpark St. Peter (incl. Windpark Plattenhöfe)',
#  'Windpark Stachenhausen',
#  'Windpark Steinbacher Höhe',
#  'Windpark Stödtlen',
#  'Windpark Stötten',
#  'Windpark Straubenhardt',
#  'Windpark Striethof',
#  'Windpark Sturmberg',
#  'Windpark Südliche Ortenau',
#  'Windpark Sulzbach-Laufen',
#  'Windpark Tegelberg',
#  'Windpark Tennenbronn (incl. Windpark Steigers Eck)',
#  'Windpark Tomerdingen-Bermaringen (Windpark Keltische Schanze)',
#  'Windpark Verenafohren',
#  'Windpark Waldhausen',
#  'Windpark Waldmössingen',
#  'Windpark Wallhausen',
#  'Windpark Weilermerkingen-Ohmenheim',
#  'Windpark Weißbach',
#  'Windpark Wenkheim',
#  'Windpark Werbachhausen',
#  'Windpark Werdeck',
#  'Windpark Westerheim',
#  'Windpark Wiesensteig']

# %%
df_bw= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })
df_bw.head(3)
# Out:
#                                   Name Baujahr Gesamt- leistung (MW) Anzahl  \
# 0  Forschungswindkraftanlage RedoxWind    2017                   2,0      1
# 1     Windkraftanlage Alexanderschanze    2003                   1,5      1
# 2           Windkraftanlage Alpirsbach    1999                   2,3      1
#
#               Typ (WKA)                      Ort Land- kreis  \
# 0        Qreon Q82 (1×)                Karlsruhe          KA
# 1      Südwind S70 (1×)  Bad Peterstal-Griesbach          OG
# 2  Enercon E-70 E4 (1×)              Römlinsdorf         FDS
#
#                   Koordinaten                     Projektierer / Betreiber  \
# 0    49° 1′ 9″ N, 8° 31′ 4″ O                               Fraunhofer ICT
# 1  48° 28′ 22″ N, 8° 16′ 7″ O  Schmalz, Windenergieanlage „Bei der Schanz“
# 2  48° 20′ 0″ N, 8° 28′ 34″ O  Windkraft Römlinsdorf, Stadtwerke Stuttgart
#
#                                          Bemerkungen
# 0  Forschungsprojekt mit kombiniertem Batteriespe...
# 1  errichtet an der Schwarzwaldhochstraße im Bere...
# 2  Repowering 2013 (1× Enercon E-70 E4 statt 1× F...

# %%
df_bw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      200 non-null    object
#  1   Baujahr                   200 non-null    object
#  2   Gesamt- leistung (MW)     200 non-null    object
#  3   Anzahl                    200 non-null    object
#  4   Typ (WKA)                 200 non-null    object
#  5   Ort                       200 non-null    object
#  6   Land- kreis               200 non-null    object
#  7   Koordinaten               200 non-null    object
#  8   Projektierer / Betreiber  200 non-null    object
#  9   Bemerkungen               200 non-null    object
# dtypes: object(10)
# memory usage: 15.8+ KB

# %%
#we have to do it because in wikipedia park for this windpark
#the coordinates are absent
df_bw['Koordinaten'].loc[df_bw['Name'].str.contains('Windpark Hohenlochen')]= str('♁48° 17′ N, 8° 11′ O')

# %%
#the make to variable from the 'Koordinaten'
fn = lambda x: pd.Series([i for i in (x.split(','))])
pad = df_bw['Koordinaten'].apply(fn)

pad.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_bw['Latitude']=pad['Latitude']
df_bw['Longitude']=pad['Longitude']

# %%
#we drop some rows with not existing anymore windparks
df_bw.drop(df_bw.loc[df_bw['Bemerkungen'].str.contains('wegen Getriebeschaden abgebaut')].index, inplace=True)
df_bw.drop(df_bw.loc[df_bw['Bemerkungen'].str.contains('im Juli 2014 Abschaltung und Demontage aufgrund Repowering-Bonus')].index, inplace=True)
df_bw.drop(df_bw.loc[df_bw['Bemerkungen'].str.contains('Abbau vermutlich 2008/2009')].index, inplace=True)

df_bw.set_index('Name', inplace=True)
df_bw['Land']='BW'


df_bw['Anzahl'] = [int(str(i)) for i in df_bw['Anzahl']]
df_bw['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_bw['Gesamt- leistung (MW)']]

df_bw.head(3)
# Out:
#                                     Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Forschungswindkraftanlage RedoxWind    2017                    2.0       1
# Windkraftanlage Alexanderschanze       2003                    1.5       1
# Windkraftanlage Alpirsbach             1999                    2.3       1
#
#                                                 Typ (WKA)  \
# Name
# Forschungswindkraftanlage RedoxWind        Qreon Q82 (1×)
# Windkraftanlage Alexanderschanze         Südwind S70 (1×)
# Windkraftanlage Alpirsbach           Enercon E-70 E4 (1×)
#
#                                                          Ort Land- kreis  \
# Name
# Forschungswindkraftanlage RedoxWind                Karlsruhe          KA
# Windkraftanlage Alexanderschanze     Bad Peterstal-Griesbach          OG
# Windkraftanlage Alpirsbach                       Römlinsdorf         FDS
#
#                                                     Koordinaten  \
# Name
# Forschungswindkraftanlage RedoxWind    49° 1′ 9″ N, 8° 31′ 4″ O
# Windkraftanlage Alexanderschanze     48° 28′ 22″ N, 8° 16′ 7″ O
# Windkraftanlage Alpirsbach           48° 20′ 0″ N, 8° 28′ 34″ O
#
#                                                         Projektierer / Betreiber  \
# Name
# Forschungswindkraftanlage RedoxWind                               Fraunhofer ICT
# Windkraftanlage Alexanderschanze     Schmalz, Windenergieanlage „Bei der Schanz“
# Windkraftanlage Alpirsbach           Windkraft Römlinsdorf, Stadtwerke Stuttgart
#
#                                                                            Bemerkungen  \
# Name
# Forschungswindkraftanlage RedoxWind  Forschungsprojekt mit kombiniertem Batteriespe...
# Windkraftanlage Alexanderschanze     errichtet an der Schwarzwaldhochstraße im Bere...
# Windkraftanlage Alpirsbach           Repowering 2013 (1× Enercon E-70 E4 statt 1× F...
#
#                                           Latitude      Longitude Land
# Name
# Forschungswindkraftanlage RedoxWind    49° 1′ 9″ N    8° 31′ 4″ O   BW
# Windkraftanlage Alexanderschanze     48° 28′ 22″ N    8° 16′ 7″ O   BW
# Windkraftanlage Alpirsbach            48° 20′ 0″ N   8° 28′ 34″ O   BW

# %%
df_bw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 197 entries, Forschungswindkraftanlage RedoxWind to Windpark Wiesensteig
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   197 non-null    object
#  1   Gesamt- leistung (MW)     197 non-null    float64
#  2   Anzahl                    197 non-null    int64
#  3   Typ (WKA)                 197 non-null    object
#  4   Ort                       197 non-null    object
#  5   Land- kreis               197 non-null    object
#  6   Koordinaten               197 non-null    object
#  7   Projektierer / Betreiber  197 non-null    object
#  8   Bemerkungen               197 non-null    object
#  9   Latitude                  197 non-null    object
#  10  Longitude                 197 non-null    object
#  11  Land                      197 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 20.0+ KB

# %%
orts_bw=df_bw.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)

orts_bw.head(10)

#we see that some Land-Kreis are mixture of two :GPAA and HNKÜN
#if we use 'land kreis' later, we should something do with this
#to replace such values with one of the Land kreises (research in the internet)
#but if I am going to use only coordinates I can leave it as it is so far
# Out:
#              Anzahl
# Land- kreis
# TBB             137
# SHA             113
# AA               84
# UL               46
# OG               45
# GP               41
# MOS              39
# HDH              38
# GPAA             19
# HNKÜN            18

# %%
orts_bw_MW=df_bw.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)

orts_bw_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# SHA                        350.420
# TBB                        284.500
# AA                         211.040
# OG                         131.885
# HDH                        113.430
# MOS                        104.660
# GP                          80.600
# UL                          68.140
# HNKÜN                       54.900
# GPAA                        52.250

# %%
bw=df_bw[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
bw.head(3)
# Out:
#                                     Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Forschungswindkraftanlage RedoxWind    2017                    2.0       1
# Windkraftanlage Alexanderschanze       2003                    1.5       1
# Windkraftanlage Alpirsbach             1999                    2.3       1
#
#                                                 Typ (WKA)  \
# Name
# Forschungswindkraftanlage RedoxWind        Qreon Q82 (1×)
# Windkraftanlage Alexanderschanze         Südwind S70 (1×)
# Windkraftanlage Alpirsbach           Enercon E-70 E4 (1×)
#
#                                                          Ort Land- kreis  \
# Name
# Forschungswindkraftanlage RedoxWind                Karlsruhe          KA
# Windkraftanlage Alexanderschanze     Bad Peterstal-Griesbach          OG
# Windkraftanlage Alpirsbach                       Römlinsdorf         FDS
#
#                                                         Projektierer / Betreiber  \
# Name
# Forschungswindkraftanlage RedoxWind                               Fraunhofer ICT
# Windkraftanlage Alexanderschanze     Schmalz, Windenergieanlage „Bei der Schanz“
# Windkraftanlage Alpirsbach           Windkraft Römlinsdorf, Stadtwerke Stuttgart
#
#                                                                            Bemerkungen  \
# Name
# Forschungswindkraftanlage RedoxWind  Forschungsprojekt mit kombiniertem Batteriespe...
# Windkraftanlage Alexanderschanze     errichtet an der Schwarzwaldhochstraße im Bere...
# Windkraftanlage Alpirsbach           Repowering 2013 (1× Enercon E-70 E4 statt 1× F...
#
#                                           Latitude      Longitude
# Name
# Forschungswindkraftanlage RedoxWind    49° 1′ 9″ N    8° 31′ 4″ O
# Windkraftanlage Alexanderschanze     48° 28′ 22″ N    8° 16′ 7″ O
# Windkraftanlage Alpirsbach            48° 20′ 0″ N   8° 28′ 34″ O

# %%
print(bw['Land- kreis'].unique())

dict_bw={'AAHDH':'AA',
        'RWOG':'RW',
        'HNKÜN':'HN',
        'GPAA':'GP',
        'CWFDS':'CW',
        'FRFR':'FR',
        'FREM':'FR',
        'OGRWVS':'OG',
        'TBBMOS':'TBB'}

bw['Land- kreis'].replace(dict_bw, inplace=True)
print(bw['Land- kreis'].unique())
# Out:
# ['KA' 'OG' 'FDS' 'VS' 'FR' 'TBB' 'SHA' 'AA' 'BC' 'RW' 'CW' 'LÖ' 'S' 'EM'
#  'LB' 'GP' 'UL' 'SIG' 'KÜN' 'HDH' 'HN' 'WN' 'WT' 'MOS' 'RV' 'TUT' 'RT'
#  'AAHDH' 'RWOG' 'HNKÜN' 'BL' 'GPAA' 'CWFDS' 'TBBMOS' 'FRFR' 'FREM' 'PF'
#  'OGRWVS' 'KN']
# ['KA' 'OG' 'FDS' 'VS' 'FR' 'TBB' 'SHA' 'AA' 'BC' 'RW' 'CW' 'LÖ' 'S' 'EM'
#  'LB' 'GP' 'UL' 'SIG' 'KÜN' 'HDH' 'HN' 'WN' 'WT' 'MOS' 'RV' 'TUT' 'RT'
#  'BL' 'PF' 'KN']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/3202541348.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bw['Land- kreis'].replace(dict_bw, inplace=True)

# %%
bw.head(10)
# Out:
#                                       Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Forschungswindkraftanlage RedoxWind      2017                  2.000       1
# Windkraftanlage Alexanderschanze         2003                  1.500       1
# Windkraftanlage Alpirsbach               1999                  2.300       1
# Windkraftanlage Auenberg                 1990                  0.095       1
# Windkraftanlage auf dem Hohwartsattel    1992                  0.300       1
# Windkraftanlage Bad Mergentheim          2002                  0.800       1
# Windkraftanlage Binselberg               2001                  1.000       1
# Windkraftanlage Birkenzell               2014                  0.800       1
# Windkraftanlage Bopfingen                2020                  0.080       1
# Windkraftanlage Bronn                    2015                  0.800       1
#
#                                                         Typ (WKA)  \
# Name
# Forschungswindkraftanlage RedoxWind                Qreon Q82 (1×)
# Windkraftanlage Alexanderschanze                 Südwind S70 (1×)
# Windkraftanlage Alpirsbach                   Enercon E-70 E4 (1×)
# Windkraftanlage Auenberg                    Reymo DANmark 22 (1×)
# Windkraftanlage auf dem Hohwartsattel           Enercon E-33 (1×)
# Windkraftanlage Bad Mergentheim               Nordex N50/800 (1×)
# Windkraftanlage Binselberg             Fuhrländer FL 1000/54 (1×)
# Windkraftanlage Birkenzell                      Enercon E-53 (1×)
# Windkraftanlage Bopfingen                       Enercon E-18 (1×)
# Windkraftanlage Bronn                           Enercon E-53 (1×)
#
#                                                            Ort Land- kreis  \
# Name
# Forschungswindkraftanlage RedoxWind                  Karlsruhe          KA
# Windkraftanlage Alexanderschanze       Bad Peterstal-Griesbach          OG
# Windkraftanlage Alpirsbach                         Römlinsdorf         FDS
# Windkraftanlage Auenberg                       Hausen vor Wald          VS
# Windkraftanlage auf dem Hohwartsattel                 Breitnau          FR
# Windkraftanlage Bad Mergentheim                      Apfelbach         TBB
# Windkraftanlage Binselberg                          Binselberg         SHA
# Windkraftanlage Birkenzell                          Birkenzell          AA
# Windkraftanlage Bopfingen                            Bopfingen          AA
# Windkraftanlage Bronn                                    Bronn         TBB
#
#                                                           Projektierer / Betreiber  \
# Name
# Forschungswindkraftanlage RedoxWind                                 Fraunhofer ICT
# Windkraftanlage Alexanderschanze       Schmalz, Windenergieanlage „Bei der Schanz“
# Windkraftanlage Alpirsbach             Windkraft Römlinsdorf, Stadtwerke Stuttgart
# Windkraftanlage Auenberg                                Pionier-Windmühle Auenberg
# Windkraftanlage auf dem Hohwartsattel            Christian Riesterer, Uwe Tischler
# Windkraftanlage Bad Mergentheim                                            Glotter
# Windkraftanlage Binselberg                                    Windkraft Binselberg
# Windkraftanlage Birkenzell                                           Alois Erhardt
# Windkraftanlage Bopfingen
# Windkraftanlage Bronn                                         NOW Wasserwerk Bronn
#
#                                                                              Bemerkungen  \
# Name
# Forschungswindkraftanlage RedoxWind    Forschungsprojekt mit kombiniertem Batteriespe...
# Windkraftanlage Alexanderschanze       errichtet an der Schwarzwaldhochstraße im Bere...
# Windkraftanlage Alpirsbach             Repowering 2013 (1× Enercon E-70 E4 statt 1× F...
# Windkraftanlage Auenberg               (*); erste kommerziell betriebene Windkraftanl...
# Windkraftanlage auf dem Hohwartsattel                                                (*)
# Windkraftanlage Bad Mergentheim
# Windkraftanlage Binselberg
# Windkraftanlage Birkenzell
# Windkraftanlage Bopfingen                               errichtet auf 10 Meter Nabenhöhe
# Windkraftanlage Bronn                                     Eigenversorgung von Wasserwerk
#
#                                             Latitude       Longitude
# Name
# Forschungswindkraftanlage RedoxWind      49° 1′ 9″ N     8° 31′ 4″ O
# Windkraftanlage Alexanderschanze       48° 28′ 22″ N     8° 16′ 7″ O
# Windkraftanlage Alpirsbach              48° 20′ 0″ N    8° 28′ 34″ O
# Windkraftanlage Auenberg               47° 53′ 19″ N    8° 28′ 24″ O
# Windkraftanlage auf dem Hohwartsattel  47° 56′ 14″ N     8° 3′ 11″ O
# Windkraftanlage Bad Mergentheim        49° 26′ 18″ N    9° 48′ 31″ O
# Windkraftanlage Binselberg              49° 16′ 5″ N    9° 55′ 35″ O
# Windkraftanlage Birkenzell             48° 59′ 27″ N   10° 15′ 17″ O
# Windkraftanlage Bopfingen              48° 50′ 34″ N   10° 19′ 50″ O
# Windkraftanlage Bronn                  49° 26′ 13″ N     9° 54′ 8″ O

# %% [markdown]
# ### Bayern:

# %%
#Bayerische windaprks
url_bayern="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Bayern"
# use requests.get() method with the provided static_url
response_bayern=requests.get(url_bayern).text
# assign the response to a object
soup_bayern=BeautifulSoup(response_bayern, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_bayern.find_all('title'):
    print(title.get_text())
# Out:
# The title is:
# Liste von Windkraftanlagen in Bayern – Wikipedia

# %%
html_tables=soup_bayern.find_all('table')
table_bayern = html_tables[0]

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_bayern.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)

# %%
print(column_names)
# Out:
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_ba=[]    
for row in table_bayern.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_ba.append(row)

# %%
len(rows_ba)
# Out:
# 353

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]

# %%
#feeling the dictionary
#I decided to leave only the first date
#filling the dictionary
for x in rows_ba[1:len(rows_ba)]:
    
    years=x[1].strip()
    table_dict['Baujahr'].append(years)

table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]

# %%
#filling the dictionaries:

for i in rows_ba[1:len(rows_ba)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_bayern= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

df_bayern.drop(df_bayern.loc[df_bayern['Name']=='Windkraftanlage Nößling'].index, inplace=True)
df_bayern.drop(df_bayern.loc[df_bayern['Name']=='Windkraftanlage Schmidsreute'].index, inplace=True)
df_bayern.drop(df_bayern.loc[df_bayern['Name']=='Windkraftanlage Schnebes'].index, inplace=True)
df_bayern.drop(df_bayern.loc[df_bayern['Name']=='Windkraftanlage Sengenbühl'].index, inplace=True)
               
    
df_bayern.info()


#df.drop(df.loc[df['Brand Name'] == 'OTTERBOX'].index, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 348 entries, 0 to 351
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      348 non-null    object
#  1   Baujahr                   348 non-null    object
#  2   Gesamt- leistung (MW)     348 non-null    object
#  3   Anzahl                    348 non-null    object
#  4   Typ (WKA)                 348 non-null    object
#  5   Ort                       348 non-null    object
#  6   Land- kreis               348 non-null    object
#  7   Koordinaten               348 non-null    object
#  8   Projektierer / Betreiber  348 non-null    object
#  9   Bemerkungen               348 non-null    object
# dtypes: object(10)
# memory usage: 29.9+ KB

# %%
fn = lambda x: pd.Series([i for i in (x.split(','))])
pad = df_bayern['Koordinaten'].apply(fn)

pad.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_bayern['Latitude']=pad['Latitude']
df_bayern['Longitude']=pad['Longitude']

#now we have to see again that we latitide and longitude are correct
df_bayern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 348 entries, 0 to 351
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      348 non-null    object
#  1   Baujahr                   348 non-null    object
#  2   Gesamt- leistung (MW)     348 non-null    object
#  3   Anzahl                    348 non-null    object
#  4   Typ (WKA)                 348 non-null    object
#  5   Ort                       348 non-null    object
#  6   Land- kreis               348 non-null    object
#  7   Koordinaten               348 non-null    object
#  8   Projektierer / Betreiber  348 non-null    object
#  9   Bemerkungen               348 non-null    object
#  10  Latitude                  348 non-null    object
#  11  Longitude                 348 non-null    object
# dtypes: object(12)
# memory usage: 35.3+ KB

# %%
df_bayern.set_index('Name', inplace=True)
df_bayern['Land']='Bayern'

df_bayern['Anzahl']=df_bayern['Anzahl'].fillna(0)
df_bayern['Anzahl'] = [int(str(i)) for i in df_bayern['Anzahl']]
df_bayern['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_bayern['Gesamt- leistung (MW)']]


df_bayern.head(3)
# Out:
#                                  Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Breitungen/Werra    2010                   0.60       1
# Windkraftanlage Cretzschwitz        2010                   2.35       1
# Windkraftanlage Diedorf             2010                   0.60       1
#
#                                               Typ (WKA)               Ort  \
# Name
# Windkraftanlage Breitungen/Werra     Tacke TW 600e (1×)  Breitungen-Winne
# Windkraftanlage Cretzschwitz          Enercon E-92 (1×)      Cretzschwitz
# Windkraftanlage Diedorf           Micon M 1500-600 (1×)           Diedorf
#
#                                  Land- kreis                   Koordinaten  \
# Name
# Windkraftanlage Breitungen/Werra          SM  50° 45′ 22″ N, 10° 21′ 19″ O
# Windkraftanlage Cretzschwitz               G   50° 56′ 12″ N, 12° 6′ 24″ O
# Windkraftanlage Diedorf                   UH  51° 11′ 22″ N, 10° 17′ 32″ O
#
#                                    Projektierer / Betreiber     Bemerkungen  \
# Name
# Windkraftanlage Breitungen/Werra                             Sanierung 2010
# Windkraftanlage Cretzschwitz      GoEn Planungsgesellschaft
# Windkraftanlage Diedorf
#
#                                        Latitude       Longitude    Land
# Name
# Windkraftanlage Breitungen/Werra  50° 45′ 22″ N   10° 21′ 19″ O  Bayern
# Windkraftanlage Cretzschwitz      50° 56′ 12″ N    12° 6′ 24″ O  Bayern
# Windkraftanlage Diedorf           51° 11′ 22″ N   10° 17′ 32″ O  Bayern

# %%
orts_bayern=df_bayern.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_bayern
# Out:
#              Anzahl
# Land- kreis
# HO              109
# SÖM             103
# UH               85
# WAK              83
# KYF              83
# ...             ...
# FO                1
# WM                1
# NU                1
# FRG               1
# CHA               1
#
# [103 rows x 1 columns]

# %%
orts_bayern_MW=df_bayern.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_bayern_MW
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# SÖM                        270.950
# HO                         242.700
# UH                         208.850
# KYF                        180.650
# AN                         171.680
# ...                            ...
# WM                           0.600
# FRG                          0.200
# SÖ                           0.075
# REG                          0.050
# EG                           0.030
#
# [103 rows x 1 columns]

# %%
bayern=df_bayern[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
bayern.head(3)
# Out:
#   Baujahr Gesamt- leistung (MW) Anzahl               Typ (WKA)           Ort  \
# 0    2009                   2,0      1   Vestas V90-2.0MW (1×)        Waller
# 1    2002                   0,6      1  Enercon E-40/6.44 (1×)   Göggelsbuch
# 2    2013                   1,8      1  Vestas V100-1.8MW (1×)  Altmannstein
#
#   Land- kreis Projektierer / Betreiber Bemerkungen       Latitude  \
# 0         LAU  ATM Hartmann, SRE Sachs              49° 25′ 26″ N
# 1          RH                                       49° 12′ 56″ N
# 2          EI          Windkraft Kernl              48° 56′ 25″ N
#
#         Longitude
# 0   11° 29′ 21″ O
# 1   11° 12′ 14″ O
# 2   11° 34′ 54″ O

# %%
print(bayern['Land- kreis'].unique())

dict_ba={'LAUNM':'LAU',
        'ANNEA':'AN',
        'LIFKU':'LIF',
        'BTKU':'BT',
        'EIRH':'EI',
        'ANWUG':'AN',
        'EIWUG':'EI',
        'ASNEW':'AS',
        'MSPSW':'MSP',
        'KCKU':'KC',
        'MSPWÜ':'MSP',
        'AN\nAN':'AN',
        'BALIF':'BA',
        'OALOA':'OAL',
        'NEAERH':'NEA',
        'GZA':'GZ',
        'EG':'PAN',
        'HOBT':'HO'}

bayern['Land- kreis'].replace(dict_ba, inplace=True)
print(bayern['Land- kreis'].unique())
# Out:
# ['LAU' 'RH' 'EI' 'ND' 'AN' 'OAL' 'NM' 'R' 'WÜ' 'MN' 'REG' 'KU' 'KT' 'MSP'
#  'DAH' 'BT' 'M' 'FS' 'PAN' 'AS' 'PAF' 'DLG' 'FÜ' 'OA' 'SW' 'LA' 'FRG'
#  'CHA' 'FO' 'SR' 'KC' 'NEA' 'FFB' 'SAD' 'WUG' 'ERH' 'TIR' 'EBE' 'WM' 'KEH'
#  'RO' 'BA' 'TS' 'NU' 'HO' 'PA' 'WUN' 'DON' 'AIC' 'HAS' 'LL' 'DGF' 'A'
#  'MIL' 'NEW' 'HOBT' 'KG' 'NES' 'LIF' 'CO' 'MB' 'GZ' 'STA']
# ['LAU' 'RH' 'EI' 'ND' 'AN' 'OAL' 'NM' 'R' 'WÜ' 'MN' 'REG' 'KU' 'KT' 'MSP'
#  'DAH' 'BT' 'M' 'FS' 'PAN' 'AS' 'PAF' 'DLG' 'FÜ' 'OA' 'SW' 'LA' 'FRG'
#  'CHA' 'FO' 'SR' 'KC' 'NEA' 'FFB' 'SAD' 'WUG' 'ERH' 'TIR' 'EBE' 'WM' 'KEH'
#  'RO' 'BA' 'TS' 'NU' 'HO' 'PA' 'WUN' 'DON' 'AIC' 'HAS' 'LL' 'DGF' 'A'
#  'MIL' 'NEW' 'KG' 'NES' 'LIF' 'CO' 'MB' 'GZ' 'STA']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/2393131815.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bayern['Land- kreis'].replace(dict_ba, inplace=True)

# %% [markdown]
# ### Berlin and Brandenburg:

# %%
url_be_ba="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Berlin_und_Brandenburg"
# use requests.get() method with the provided static_url
response_be_ba=requests.get(url_be_ba).text
# assign the response to a object
soup_be_ba=BeautifulSoup(response_be_ba, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_be_ba.find_all('title'):
    print(title.get_text())
    
html_tables=soup_be_ba.find_all('table')
table_be_ba = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_be_ba.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Berlin und Brandenburg – Wikipedia
# ['Name', 'Baujahr', 'Gesamt-  Leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land-  kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_be_ba=[]    
for row in table_be_ba.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_be_ba.append(row)
        
        
print(len(rows_be_ba))
# Out:
# 304

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]

# %%
#filling the dictionaries:



for i in rows_be_ba[1:len(rows_be_ba)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_berlin_br= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Bemerkungen'].str.contains('abgebaut')].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlage Althüttendorf'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlage Groß Leppin'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlage Nettelbeck'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Beveringen-Nord'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Drewen'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlage Hohenseefeld'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Horstfelde'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Niemerlang'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windpark Hasenwinkel'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Rüdersdorf'].index, inplace=True)
df_berlin_br.drop(df_berlin_br.loc[df_berlin_br['Name']=='Windkraftanlagen Stöffin'].index, inplace=True)

df_berlin_br.set_index('Name', inplace=True)
df_berlin_br['Land']='Br-Ber'


#splitting the coordinated variable to two
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_berlin_br['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_berlin_br['Latitude']=coord['Latitude']
df_berlin_br['Longitude']=coord['Longitude']






#df_berlin_br['Anzahl']=df_berlin_br['Anzahl'].fillna(0)
df_berlin_br['Anzahl'] = [int(str(i)) for i in df_berlin_br['Anzahl']]
df_berlin_br['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_berlin_br['Gesamt- leistung (MW)']]

df_berlin_br.head(3)
#scraping had some strange results: Gesamt_Leistung(MW) and Landkreis are duplicated (and one of the columns 
#contains NaNs
#we remove them)
# Out:
#                                       Baujahr Gesamt-  Leistung (MW)  Anzahl  \
# Name
# I. Windkraft­anlage Pankow               2010                    NaN       1
# II. und VI.  Wind­kraft­anlage Pankow    2010                    NaN       2
# III. und IV. Wind­kraft­anlage Pankow    2010                    NaN       2
#
#                                                                             Typ (WKA)  \
# Name
# I. Windkraft­anlage Pankow                                          Enercon E-82 (1×)
# II. und VI.  Wind­kraft­anlage Pankow  Enercon E-82 E2 (1×) Enercon E-138 EP3 E2 (1×)
# III. und IV. Wind­kraft­anlage Pankow                               Enercon E-92 (2×)
#
#                                                               Ort  \
# Name
# I. Windkraft­anlage Pankow                                   Buch
# II. und VI.  Wind­kraft­anlage Pankow  Stadtrand­siedlung Malchow
# III. und IV. Wind­kraft­anlage Pankow        Französisch Buchholz
#
#                                       Land-  kreis  \
# Name
# I. Windkraft­anlage Pankow                     NaN
# II. und VI.  Wind­kraft­anlage Pankow          NaN
# III. und IV. Wind­kraft­anlage Pankow          NaN
#
#                                                         Koordinaten  \
# Name
# I. Windkraft­anlage Pankow             52° 38′ 10″ N, 13° 25′ 47″ O
# II. und VI.  Wind­kraft­anlage Pankow   52° 35′ 29″ N, 13° 30′ 4″ O
# III. und IV. Wind­kraft­anlage Pankow  52° 37′ 28″ N, 13° 26′ 23″ O
#
#                                                  Projektierer / Betreiber  \
# Name
# I. Windkraft­anlage Pankow                                            NEB
# II. und VI.  Wind­kraft­anlage Pankow                                 NEB
# III. und IV. Wind­kraft­anlage Pankow  Phase I GmbH & Co Windkraft Pankow
#
#                                                                              Bemerkungen  \
# Name
# I. Windkraft­anlage Pankow             bis Ende 2014 einzige Windkraftanlage in Berli...
# II. und VI.  Wind­kraft­anlage Pankow
# III. und IV. Wind­kraft­anlage Pankow                auf dem Gelände von Heron Fireworks
#
#                                        Gesamt- leistung (MW) Land- kreis  \
# Name
# I. Windkraft­anlage Pankow                               2.0           B
# II. und VI.  Wind­kraft­anlage Pankow                    6.5           B
# III. und IV. Wind­kraft­anlage Pankow                    4.7           B
#
#                                          Land       Latitude       Longitude
# Name
# I. Windkraft­anlage Pankow             Br-Ber  52° 38′ 10″ N   13° 25′ 47″ O
# II. und VI.  Wind­kraft­anlage Pankow  Br-Ber  52° 35′ 29″ N    13° 30′ 4″ O
# III. und IV. Wind­kraft­anlage Pankow  Br-Ber  52° 37′ 28″ N   13° 26′ 23″ O

# %%
df_berlin_br= df_berlin_br.drop(df_berlin_br.columns[1], axis=1)
df_berlin_br= df_berlin_br.drop(df_berlin_br.columns[4], axis=1)

df_berlin_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 292 entries, I. Windkraft­anlage Pankow to Windpark Zossen
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   292 non-null    object
#  1   Anzahl                    292 non-null    int64
#  2   Typ (WKA)                 292 non-null    object
#  3   Ort                       292 non-null    object
#  4   Koordinaten               292 non-null    object
#  5   Projektierer / Betreiber  292 non-null    object
#  6   Bemerkungen               292 non-null    object
#  7   Gesamt- leistung (MW)     292 non-null    float64
#  8   Land- kreis               292 non-null    object
#  9   Land                      292 non-null    object
#  10  Latitude                  292 non-null    object
#  11  Longitude                 292 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 29.7+ KB

# %%
orts_berlin_br=df_berlin_br.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_berlin_br.head(5)
# Out:
#              Anzahl
# Land- kreis
# UM              667
# PR              577
# OPR             315
# EE              303
# MOL             294

# %%
orts_berlin_br_MW=df_berlin_br.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)

orts_berlin_br_MW
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# UM                         1666.85
# PR                         1240.70
# MOL                         707.08
# LDS                         616.40
# EE                          613.50
# TF                          530.35
# OPR                         497.17
# LOS                         466.17
# HVL                         361.50
# BAR                         352.35
# PM                          343.05
# OSL                         334.10
# SPN                         239.85
# PM TF                       239.50
# TF LDS                      203.45
# OSL EE                      180.80
# OHV                         139.45
# TF PM                       133.10
# BAR MOL                      67.90
# LDS LOS                      66.60
# CB                           64.00
# OPR PR                       62.60
# OSL SPN                      53.95
# BAR UM                       31.20
# FF                           21.80
# B                            16.60
# SPN OSL                      13.40
# BRB                           3.00

# %%
br=df_berlin_br[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
br.head(3)
# Out:
#                                       Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# I. Windkraft­anlage Pankow               2010                    2.0       1
# II. und VI.  Wind­kraft­anlage Pankow    2010                    6.5       2
# III. und IV. Wind­kraft­anlage Pankow    2010                    4.7       2
#
#                                                                             Typ (WKA)  \
# Name
# I. Windkraft­anlage Pankow                                          Enercon E-82 (1×)
# II. und VI.  Wind­kraft­anlage Pankow  Enercon E-82 E2 (1×) Enercon E-138 EP3 E2 (1×)
# III. und IV. Wind­kraft­anlage Pankow                               Enercon E-92 (2×)
#
#                                                               Ort Land- kreis  \
# Name
# I. Windkraft­anlage Pankow                                   Buch           B
# II. und VI.  Wind­kraft­anlage Pankow  Stadtrand­siedlung Malchow           B
# III. und IV. Wind­kraft­anlage Pankow        Französisch Buchholz           B
#
#                                                  Projektierer / Betreiber  \
# Name
# I. Windkraft­anlage Pankow                                            NEB
# II. und VI.  Wind­kraft­anlage Pankow                                 NEB
# III. und IV. Wind­kraft­anlage Pankow  Phase I GmbH & Co Windkraft Pankow
#
#                                                                              Bemerkungen  \
# Name
# I. Windkraft­anlage Pankow             bis Ende 2014 einzige Windkraftanlage in Berli...
# II. und VI.  Wind­kraft­anlage Pankow
# III. und IV. Wind­kraft­anlage Pankow                auf dem Gelände von Heron Fireworks
#
#                                             Latitude       Longitude
# Name
# I. Windkraft­anlage Pankow             52° 38′ 10″ N   13° 25′ 47″ O
# II. und VI.  Wind­kraft­anlage Pankow  52° 35′ 29″ N    13° 30′ 4″ O
# III. und IV. Wind­kraft­anlage Pankow  52° 37′ 28″ N   13° 26′ 23″ O

# %%
print(br['Land- kreis'].unique())

dict_br={'TF PM':'LAU',
        'PM TF':'AN',
        'TF LDS':'LIF',
        'BAR MOL':'BT',
        'OSL EE':'EI',
        'OPR PR':'AN',
        'BAR UM':'EI',
        'SPN OSL':'AS',
        'LDS LOS':'MSP',
        'OSL SPN':'KC'}

br['Land- kreis'].replace(dict_br, inplace=True)
print(br['Land- kreis'].unique())
# Out:
# ['B' 'OPR' 'HVL' 'SPN' 'FF' 'MOL' 'OSL' 'PR' 'TF' 'UM' 'LOS' 'PM' 'LDS'
#  'BAR' 'EE' 'BRB' 'TF PM' 'OHV' 'CB' 'TF LDS' 'PM TF' 'BAR MOL' 'OSL EE'
#  'OPR PR' 'BAR UM' 'SPN OSL' 'LDS LOS' 'OSL SPN']
# ['B' 'OPR' 'HVL' 'SPN' 'FF' 'MOL' 'OSL' 'PR' 'TF' 'UM' 'LOS' 'PM' 'LDS'
#  'BAR' 'EE' 'BRB' 'LAU' 'OHV' 'CB' 'LIF' 'AN' 'BT' 'EI' 'AS' 'MSP' 'KC']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/3831024021.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   br['Land- kreis'].replace(dict_br, inplace=True)

# %% [markdown]
# ### Bremen, Hamburg, Niedersachsen:

# %%
url_nord="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Bremen,_Hamburg_und_Niedersachsen"
# use requests.get() method with the provided static_url
response_nord=requests.get(url_nord).text
# assign the response to a object
soup_nord=BeautifulSoup(response_nord, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_nord.find_all('title'):
    print(title.get_text())
    
html_tables=soup_nord.find_all('table')
table_nord = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_nord.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Bremen, Hamburg und Niedersachsen – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_nord=[]    
for row in table_nord.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_nord.append(row)
        
        
print(len(rows_nord))
# Out:
# 1001

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:


for i in rows_nord[1:len(rows_nord)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_nord= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#deleting not existing anymore windparks:
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Abbehausergroden'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Ahndeich'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Apelnstedt'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Auestade'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlagen Aurich-Extum'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Aurich-Haxtum'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlagen Aurich-Tannenhausen'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Aurich-Walle'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Bad Harzburg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Bienerfeld'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Braunschweig-Veltenhof'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Bulsterdeich'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlagen Clausthal-Zellerfeld'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Flessenmoor'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Geeste'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Gräpel'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Gut Wormsthal'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Hachum'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Heisterberg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Hemmoor'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Hilter'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Hooksiel'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Hütten'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Langenhagen-Godshorn'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Mainzholzen'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Meinersen'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Neuschoo'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Nienbrügge'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Nikolausdorf'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Norden'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlagen Nordwohlde'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Obersburg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Ochsenwerder'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Pollhagen'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Sandkrug-Klärwerk'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Schümersdamm'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Seevernserwisch'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Springe'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Stührenberg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windkraftanlage Tarbarg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windpark Fledderweg'].index, inplace=True)
df_nord.drop(df_nord.loc[df_nord['Name']=='Windpark Neu Wulmstorf'].index, inplace=True)


df_nord.set_index('Name', inplace=True)
df_nord['Land']='HH,HB,H'



fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_nord['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_nord['Latitude']=coord['Latitude']
df_nord['Longitude']=coord['Longitude']


df_nord['Anzahl'] = [int(str(i)) for i in df_nord['Anzahl']]
df_nord['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_nord['Gesamt- leistung (MW)']]



df_nord.head(3)
# Out:
#                             Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlagen Afferde       2010                    6.6       2
# Windkraftanlagen Ahlshausen    2010                    1.4       2
# Windkraftanlage Aldorf         2010                    3.3       1
#
#                                                                Typ (WKA)  \
# Name
# Windkraftanlagen Afferde     Vestas V126-3.3MW (1×)Nordex N131/3300 (1×)
# Windkraftanlagen Ahlshausen           Tacke TW 600 (1×)Enercon E-53 (1×)
# Windkraftanlage Aldorf                            Vestas V112-3.3MW (1×)
#
#                                     Ort Land- kreis  \
# Name
# Windkraftanlagen Afferde        Afferde          HM
# Windkraftanlagen Ahlshausen  Ahlshausen         NOM
# Windkraftanlage Aldorf           Aldorf          DH
#
#                                             Koordinaten  \
# Name
# Windkraftanlagen Afferde     52° 6′ 11″ N, 9° 25′ 28″ O
# Windkraftanlagen Ahlshausen  51° 47′ 23″ N, 9° 59′ 6″ O
# Windkraftanlage Aldorf       52° 15′ 6″ N, 8° 29′ 31″ O
#
#                             Projektierer / Betreiber  \
# Name
# Windkraftanlagen Afferde                    Landwind
# Windkraftanlagen Ahlshausen
# Windkraftanlage Aldorf
#
#                                                                    Bemerkungen  \
# Name
# Windkraftanlagen Afferde
# Windkraftanlagen Ahlshausen  2011 Repowering (1× Enercon E-53 statt 1× Ener...
# Windkraftanlage Aldorf
#
#                                 Land       Latitude      Longitude
# Name
# Windkraftanlagen Afferde     HH,HB,H   52° 6′ 11″ N   9° 25′ 28″ O
# Windkraftanlagen Ahlshausen  HH,HB,H  51° 47′ 23″ N    9° 59′ 6″ O
# Windkraftanlage Aldorf       HH,HB,H   52° 15′ 6″ N   8° 29′ 31″ O

# %%
df_nord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 958 entries, Windkraftanlagen Afferde to Windpark Bad Zwischenahn
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   958 non-null    object
#  1   Gesamt- leistung (MW)     958 non-null    float64
#  2   Anzahl                    958 non-null    int64
#  3   Typ (WKA)                 958 non-null    object
#  4   Ort                       958 non-null    object
#  5   Land- kreis               958 non-null    object
#  6   Koordinaten               958 non-null    object
#  7   Projektierer / Betreiber  958 non-null    object
#  8   Bemerkungen               958 non-null    object
#  9   Land                      958 non-null    object
#  10  Latitude                  958 non-null    object
#  11  Longitude                 958 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 97.3+ KB

# %%
orts_nord=df_nord.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_nord
# Out:
#              Anzahl
# Land- kreis
# CUX             516
# EL              499
# AUR             487
# DH              407
# CLP             233
# ...             ...
# DEL               5
# WOB               5
# BS                5
# RI                1
# BH                1
#
# [66 rows x 1 columns]

# %%
orts_nord_MW=df_nord.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_nord_MW
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# EL                        1253.450
# DH                         905.635
# AUR                        868.455
# CUX                        802.075
# STD                        557.565
# ...                            ...
# DEL                          6.000
# HSHG                         5.000
# WOB                          3.400
# BH                           0.150
# RI                           0.050
#
# [66 rows x 1 columns]

# %%
hbh=df_nord[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
hbh.head(3)
# Out:
#                             Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlagen Afferde       2010                    6.6       2
# Windkraftanlagen Ahlshausen    2010                    1.4       2
# Windkraftanlage Aldorf         2010                    3.3       1
#
#                                                                Typ (WKA)  \
# Name
# Windkraftanlagen Afferde     Vestas V126-3.3MW (1×)Nordex N131/3300 (1×)
# Windkraftanlagen Ahlshausen           Tacke TW 600 (1×)Enercon E-53 (1×)
# Windkraftanlage Aldorf                            Vestas V112-3.3MW (1×)
#
#                                     Ort Land- kreis Projektierer / Betreiber  \
# Name
# Windkraftanlagen Afferde        Afferde          HM                 Landwind
# Windkraftanlagen Ahlshausen  Ahlshausen         NOM
# Windkraftanlage Aldorf           Aldorf          DH
#
#                                                                    Bemerkungen  \
# Name
# Windkraftanlagen Afferde
# Windkraftanlagen Ahlshausen  2011 Repowering (1× Enercon E-53 statt 1× Ener...
# Windkraftanlage Aldorf
#
#                                   Latitude      Longitude
# Name
# Windkraftanlagen Afferde      52° 6′ 11″ N   9° 25′ 28″ O
# Windkraftanlagen Ahlshausen  51° 47′ 23″ N    9° 59′ 6″ O
# Windkraftanlage Aldorf        52° 15′ 6″ N   8° 29′ 31″ O

# %%
print(hbh['Land- kreis'].unique())

dict_hbh={'ROWSTD':'ROW',
        'HPE':'H',
        'OSVEC':'OS',
        'PESZHI':'PE',
        'WTMFRI':'WTM',
        'HSHG':'H',
        'OLCLP':'OL',
        'LERWST':'LER',
        'HEMF':'HE',
        'WFSZ':'WF',
        'WTMAUR':'WTM',
        'SHGH':'SHG',
         'HHI':'H',
         'VERROW':'VER',
         'BRAOL':'BRA',
         'SZPE':'SZ',
         'OHZROW':'OHZ',
          'GFWOB':'GF',
         'RI':'SHG',
         'HEWF':'HE',
         'BH':'HB',
         'GIF':'GF'}




hbh['Land- kreis'].replace(dict_hbh, inplace=True)
print(hbh['Land- kreis'].unique())
# Out:
# ['HM' 'NOM' 'DH' 'OL' 'BRA' 'HH' 'OS' 'EL' 'WTM' 'STD' 'AUR' 'NOH' 'LG'
#  'EMD' 'CUX' 'LER' 'HI' 'HB' 'ROW' 'WF' 'NI' 'SHG' 'CLP' 'FRI' 'DEL' 'WL'
#  'H' 'HK' 'WHV' 'GÖ' 'HE' 'PE' 'UE' 'OHZ' 'CE' 'VER' 'DAN' 'VEC' 'HOL'
#  'SZ' 'GF' 'GS' 'GIF' 'WST' 'BS' 'WOB']
# ['HM' 'NOM' 'DH' 'OL' 'BRA' 'HH' 'OS' 'EL' 'WTM' 'STD' 'AUR' 'NOH' 'LG'
#  'EMD' 'CUX' 'LER' 'HI' 'HB' 'ROW' 'WF' 'NI' 'SHG' 'CLP' 'FRI' 'DEL' 'WL'
#  'H' 'HK' 'WHV' 'GÖ' 'HE' 'PE' 'UE' 'OHZ' 'CE' 'VER' 'DAN' 'VEC' 'HOL'
#  'SZ' 'GF' 'GS' 'WST' 'BS' 'WOB']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/3986558060.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hbh['Land- kreis'].replace(dict_hbh, inplace=True)

# %% [markdown]
# ### Hessen:

# %%
url_he="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Hessen"
# use requests.get() method with the provided static_url
response_he=requests.get(url_he).text
# assign the response to a object
soup_he=BeautifulSoup(response_he, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_he.find_all('title'):
    print(title.get_text())
    
html_tables=soup_he.find_all('table')
table_he = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_he.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Hessen – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_he=[]    
for row in table_he.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_he.append(row)
        
        
print(len(rows_he))
# Out:
# 222

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:

for i in rows_he[1:len(rows_he)]:
    years=x[1].strip()
    
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]

for i in rows_he[1:len(rows_he)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
  
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_he= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#split the 'Koordinaten':
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_he['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_he['Latitude']=coord['Latitude']
df_he['Longitude']=coord['Longitude']

#remove not existing wiondparks
df_he.drop(df_he.loc[df_he['Name']=='Windkraftanlage Aarbergen'].index, inplace=True)
df_he.drop(df_he.loc[df_he['Name']=='Windkraftanlagen Zorn'].index, inplace=True)
df_he.drop(df_he.loc[df_he['Name']=='Windpark Alte Schanze'].index, inplace=True)
df_he.drop(df_he.loc[df_he['Name']=='Windpark Hohenzell'].index, inplace=True)
df_he.drop(df_he.loc[df_he['Name']=='Windpark Windhausen-Nord'].index, inplace=True)


df_he.set_index('Name', inplace=True)
df_he['Land']='Hessen'


df_he['Anzahl'] = [int(str(i).replace("[58]", "")) for i in df_he['Anzahl']]
df_he['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_he['Gesamt- leistung (MW)']]



df_he.head(3)
# Out:
#                                                   Baujahr  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)    2010
# Windkraftanlage Friedewald                           2010
# Windkraftanlage Heitzelberg                          2010
#
#                                                    Gesamt- leistung (MW)  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)                    3.3
# Windkraftanlage Friedewald                                           0.6
# Windkraftanlage Heitzelberg                                          5.5
#
#                                                    Anzahl  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)       1
# Windkraftanlage Friedewald                              1
# Windkraftanlage Heitzelberg                             1
#
#                                                                      Typ (WKA)  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)       Vestas V126-3.3MW (1×)
# Windkraftanlage Friedewald                              Enercon E-40/6.44 (1×)
# Windkraftanlage Heitzelberg                        GE Wind Energy 5.5-158 (1×)
#
#                                                            Ort Land- kreis  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  Breidenbach          MR
# Windkraftanlage Friedewald                          Friedewald         HEF
# Windkraftanlage Heitzelberg                        Freienhagen          KB
#
#                                                                    Koordinaten  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  50° 53′ 38″ N, 8° 23′ 53″ O
# Windkraftanlage Friedewald                          50° 53′ 0″ N, 9° 50′ 10″ O
# Windkraftanlage Heitzelberg                          50° 15′ 32″ N, 9° 4′ 2″ O
#
#                                                   Projektierer / Betreiber  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)           Boxbach Energy
# Windkraftanlage Friedewald                          Windenergie Friedewald
# Windkraftanlage Heitzelberg                                            PNE
#
#                                                                                          Bemerkungen  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  zugehörig zum WP Hesselbach auf nordrhein-west...
# Windkraftanlage Friedewald                                                      Errichtet an der A 4
# Windkraftanlage Heitzelberg
#
#                                                         Latitude  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  50° 53′ 38″ N
# Windkraftanlage Friedewald                          50° 53′ 0″ N
# Windkraftanlage Heitzelberg                        50° 15′ 32″ N
#
#                                                        Longitude    Land
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)   8° 23′ 53″ O  Hessen
# Windkraftanlage Friedewald                          9° 50′ 10″ O  Hessen
# Windkraftanlage Heitzelberg                           9° 4′ 2″ O  Hessen

# %%
df_he.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216 entries, Windkraftanlage Breidenbach (Windpark Hesselbach) to Windpark Wirmighausen
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   216 non-null    object
#  1   Gesamt- leistung (MW)     216 non-null    float64
#  2   Anzahl                    216 non-null    int64
#  3   Typ (WKA)                 216 non-null    object
#  4   Ort                       216 non-null    object
#  5   Land- kreis               216 non-null    object
#  6   Koordinaten               216 non-null    object
#  7   Projektierer / Betreiber  216 non-null    object
#  8   Bemerkungen               216 non-null    object
#  9   Latitude                  216 non-null    object
#  10  Longitude                 216 non-null    object
#  11  Land                      216 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 21.9+ KB

# %%
orts_he=df_he.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_he.head(5)
# Out:
#              Anzahl
# Land- kreis
# VB              229
# KB              161
# KS              139
# MKK             109
# MR               91

# %%
orts_he_MW=df_he.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_he_MW.head(5)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# VB                          457.80
# KB                          309.12
# MKK                         287.95
# HEF                         253.50
# KS                          224.40

# %%
he=df_he[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
he.head(3)
# Out:
#                                                   Baujahr  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)    2010
# Windkraftanlage Friedewald                           2010
# Windkraftanlage Heitzelberg                          2010
#
#                                                    Gesamt- leistung (MW)  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)                    3.3
# Windkraftanlage Friedewald                                           0.6
# Windkraftanlage Heitzelberg                                          5.5
#
#                                                    Anzahl  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)       1
# Windkraftanlage Friedewald                              1
# Windkraftanlage Heitzelberg                             1
#
#                                                                      Typ (WKA)  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)       Vestas V126-3.3MW (1×)
# Windkraftanlage Friedewald                              Enercon E-40/6.44 (1×)
# Windkraftanlage Heitzelberg                        GE Wind Energy 5.5-158 (1×)
#
#                                                            Ort Land- kreis  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  Breidenbach          MR
# Windkraftanlage Friedewald                          Friedewald         HEF
# Windkraftanlage Heitzelberg                        Freienhagen          KB
#
#                                                   Projektierer / Betreiber  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)           Boxbach Energy
# Windkraftanlage Friedewald                          Windenergie Friedewald
# Windkraftanlage Heitzelberg                                            PNE
#
#                                                                                          Bemerkungen  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  zugehörig zum WP Hesselbach auf nordrhein-west...
# Windkraftanlage Friedewald                                                      Errichtet an der A 4
# Windkraftanlage Heitzelberg
#
#                                                         Latitude  \
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)  50° 53′ 38″ N
# Windkraftanlage Friedewald                          50° 53′ 0″ N
# Windkraftanlage Heitzelberg                        50° 15′ 32″ N
#
#                                                        Longitude
# Name
# Windkraftanlage Breidenbach (Windpark Hesselbach)   8° 23′ 53″ O
# Windkraftanlage Friedewald                          9° 50′ 10″ O
# Windkraftanlage Heitzelberg                           9° 4′ 2″ O

# %%
print(he['Land- kreis'].unique())

dict_he={'LDKLM':'LDK',
        'LDKMR':'LDK',
        'VBMKK':'VB',
        'HEFVB':'HEF',
        'MRGI':'MR'}

he['Land- kreis'].replace(dict_he, inplace=True)
print(he['Land- kreis'].unique())
# Out:
# ['MR' 'HEF' 'KB' 'HR' 'FD' 'LM' 'MKK' 'LDK' 'VB' 'KS' 'ESW' 'FB' 'RÜD'
#  'DA' 'LDKLM' 'LDKMR' 'ERB' 'VBMKK' 'HG' 'HEFVB' 'HP' 'GI' 'MRGI']
# ['MR' 'HEF' 'KB' 'HR' 'FD' 'LM' 'MKK' 'LDK' 'VB' 'KS' 'ESW' 'FB' 'RÜD'
#  'DA' 'ERB' 'HG' 'HP' 'GI']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/1566879275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   he['Land- kreis'].replace(dict_he, inplace=True)

# %% [markdown]
# ### Mecklenburg-Vorpommen:

# %%
url_mp="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Mecklenburg-Vorpommern"
# use requests.get() method with the provided static_url
response_mp=requests.get(url_mp).text
# assign the response to a object
soup_mp=BeautifulSoup(response_mp, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_mp.find_all('title'):
    print(title.get_text())
    
html_tables=soup_mp.find_all('table')
table_mp = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_mp.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Mecklenburg-Vorpommern – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_mp=[]    
for row in table_mp.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_mp.append(row)
        
        
print(len(rows_mp))
# Out:
# 239

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_mp[1:len(rows_mp)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_mp= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })


#split the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_mp['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_mp['Latitude']=coord['Latitude']
df_mp['Longitude']=coord['Longitude']

#deleting not existing anymore windparks:
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Burow'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Graal-Müritz'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Hafthagen'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Hessenburg'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Langsdorf'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Mattchow'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Michaelsdorf'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Michaelsdorf-Süd'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Mühlengeez'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Neuenlübke'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Penzin'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Rerik'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Schwarbe-Nord'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Schwerin'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Thomashof'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlage Zarnekow'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Hägerfelde'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Poseritz'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Russow'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Schaprode'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Tempel'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Starrvitz'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windkraftanlagen Teßmannsdorf'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='WWindkraftanlagen Trent'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Bodstedt'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Gagzow'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Holstenhagen'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Klein Welzin'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Pragsdorf'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Sagard'].index, inplace=True)
df_mp.drop(df_mp.loc[df_mp['Name']=='Windpark Schwarbe'].index, inplace=True)





df_mp.set_index('Name', inplace=True)
df_mp['Land']='MVP'

df_mp['Anzahl'] = [int(str(i)) for i in df_mp['Anzahl']]
df_mp['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_mp['Gesamt- leistung (MW)']]


df_mp.head(3)
# Out:
#                              Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Altenkirchen    2010                    0.5       1
# Windkraftanlage Borg            2010                    2.0       1
# Windkraftanlage Breitling       2010                    2.5       1
#
#                                            Typ (WKA)                Ort  \
# Name
# Windkraftanlage Altenkirchen  Enercon E-40/5.40 (1×)       Altenkirchen
# Windkraftanlage Borg               Enercon E-70 (1×)  Ribnitz-Damgarten
# Windkraftanlage Breitling       Nordex N90/2500 (1×)               Peez
#
#                              Land- kreis                   Koordinaten  \
# Name
# Windkraftanlage Altenkirchen          VR  54° 37′ 42″ N, 13° 19′ 55″ O
# Windkraftanlage Borg                  VR  54° 14′ 11″ N, 12° 23′ 15″ O
# Windkraftanlage Breitling            HRO    54° 9′ 25″ N, 12° 7′ 33″ O
#
#                              Projektierer / Betreiber  \
# Name
# Windkraftanlage Altenkirchen
# Windkraftanlage Borg                     WIND-Projekt
# Windkraftanlage Breitling        WIND-projekt, Nordex
#
#                                                                     Bemerkungen  \
# Name
# Windkraftanlage Altenkirchen
# Windkraftanlage Borg                            früher noch 1× Lagerwey LW15/75
# Windkraftanlage Breitling     Testanlage zur Simulation eines Standortes unt...
#
#                                    Latitude       Longitude Land
# Name
# Windkraftanlage Altenkirchen  54° 37′ 42″ N   13° 19′ 55″ O  MVP
# Windkraftanlage Borg          54° 14′ 11″ N   12° 23′ 15″ O  MVP
# Windkraftanlage Breitling      54° 9′ 25″ N    12° 7′ 33″ O  MVP

# %%
df_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, Windkraftanlage Altenkirchen to Windpark Züsedom-Fahrenwalde
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   208 non-null    object
#  1   Gesamt- leistung (MW)     208 non-null    float64
#  2   Anzahl                    208 non-null    int64
#  3   Typ (WKA)                 208 non-null    object
#  4   Ort                       208 non-null    object
#  5   Land- kreis               208 non-null    object
#  6   Koordinaten               208 non-null    object
#  7   Projektierer / Betreiber  208 non-null    object
#  8   Bemerkungen               208 non-null    object
#  9   Latitude                  208 non-null    object
#  10  Longitude                 208 non-null    object
#  11  Land                      208 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 21.1+ KB

# %%
orts_mp_MW=df_mp.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_mp_MW
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# LUP                        830.980
# LRO                        787.160
# VG                         707.720
# MSE                        705.260
# VR                         456.635
# NWM                        337.655
# VGVR                        61.570
# HRO                          8.400

# %%
orts_mp=df_mp.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_mp
# Out:
#              Anzahl
# Land- kreis
# VG              389
# LUP             361
# LRO             342
# MSE             317
# VR              279
# NWM             172
# VGVR             26
# HRO               9

# %%
mvp=df_mp[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
mvp.head(3)
# Out:
#                              Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Altenkirchen    2010                    0.5       1
# Windkraftanlage Borg            2010                    2.0       1
# Windkraftanlage Breitling       2010                    2.5       1
#
#                                            Typ (WKA)                Ort  \
# Name
# Windkraftanlage Altenkirchen  Enercon E-40/5.40 (1×)       Altenkirchen
# Windkraftanlage Borg               Enercon E-70 (1×)  Ribnitz-Damgarten
# Windkraftanlage Breitling       Nordex N90/2500 (1×)               Peez
#
#                              Land- kreis Projektierer / Betreiber  \
# Name
# Windkraftanlage Altenkirchen          VR
# Windkraftanlage Borg                  VR             WIND-Projekt
# Windkraftanlage Breitling            HRO     WIND-projekt, Nordex
#
#                                                                     Bemerkungen  \
# Name
# Windkraftanlage Altenkirchen
# Windkraftanlage Borg                            früher noch 1× Lagerwey LW15/75
# Windkraftanlage Breitling     Testanlage zur Simulation eines Standortes unt...
#
#                                    Latitude       Longitude
# Name
# Windkraftanlage Altenkirchen  54° 37′ 42″ N   13° 19′ 55″ O
# Windkraftanlage Borg          54° 14′ 11″ N   12° 23′ 15″ O
# Windkraftanlage Breitling      54° 9′ 25″ N    12° 7′ 33″ O

# %%
print(mvp['Land- kreis'].unique())

dict_mvp={'VGVR':'VG',
         'LRO':'HRO'}

mvp['Land- kreis'].replace(dict_mvp, inplace=True)
print(mvp['Land- kreis'].unique())
# Out:
# ['VR' 'HRO' 'LRO' 'VG' 'LUP' 'NWM' 'MSE']
# ['VR' 'HRO' 'VG' 'LUP' 'NWM' 'MSE']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/247991496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mvp['Land- kreis'].replace(dict_mvp, inplace=True)

# %% [markdown]
# ### Nordrhein-Westfalien:

# %%
url_nw="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Nordrhein-Westfalen"
# use requests.get() method with the provided static_url
response_nw=requests.get(url_nw).text
# assign the response to a object
soup_nw=BeautifulSoup(response_nw, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_nw.find_all('title'):
    print(title.get_text())
    
html_tables=soup_nw.find_all('table')
table_nw = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_nw.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Nordrhein-Westfalen – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_nw=[]    
for row in table_nw.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_nw.append(row)
        
        
print(len(rows_nw))
# Out:
# 815

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_nw[1:len(rows_nw)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    
    
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    
    
    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_nw= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split('N,'))])
coord = df_nw['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_nw['Latitude']=coord['Latitude']
df_nw['Longitude']=coord['Longitude']



##remove not existing wiondparks
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Aachen-Melaten'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Bedburg-Hau'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Budberg'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlagen Buke'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlagen Gangelt'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Geisecke'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Geldern-Walbeck'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Gütersloh-Hollen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Isselhorst'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Kaldenkirchen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Mettingen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Minden-Päpinghausen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlagen Obringhausen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Oer-Erkenschwick „Owi“'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Oppenwehe'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Ortfeld'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlagen Obringhausen'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlagen Vreden Süd'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Setterich'].index, inplace=True)
df_nw.drop(df_nw.loc[df_nw['Name']=='Windkraftanlage Selkentrop'].index, inplace=True)






df_nw.set_index('Name', inplace=True)
df_nw['Land']='NW'
#df_nw['Anzahl']=df_nw['Anzahl'].fillna(0)
df_nw['Anzahl'] = [int(str(i)) for i in df_nw['Anzahl']]
df_nw['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_nw['Gesamt- leistung (MW)']]


df_nw.head(3)
# Out:
#                                  Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Aachen-Orsbach      2010                   0.08       1
# Windkraftanlage Affeln              2010                   0.60       1
# Windkraftanlagen Ahlen-Gemmerich    2010                   8.40       2
#
#                                                   Typ (WKA)        Ort  \
# Name
# Windkraftanlage Aachen-Orsbach            Enercon E-18 (1×)    Orsbach
# Windkraftanlage Affeln                    Tacke TW 600 (1×)     Affeln
# Windkraftanlagen Ahlen-Gemmerich  Enercon E-138 EP3 E2 (2×)  Gemmerich
#
#                                  Land- kreis               Koordinaten  \
# Name
# Windkraftanlage Aachen-Orsbach            AC    50,790556° N, 6,009° O
# Windkraftanlage Affeln                    MK   51,27842° N, 7,89391° O
# Windkraftanlagen Ahlen-Gemmerich         WAF  51,73053° N, 7,884509° O
#
#                                   Projektierer / Betreiber Bemerkungen  \
# Name
# Windkraftanlage Aachen-Orsbach            Wind e.V. Aachen
# Windkraftanlage Affeln                        Windinvestor
# Windkraftanlagen Ahlen-Gemmerich  Vento Ludens GmbH ＆Co.KG      in Bau
#
#                                      Latitude     Longitude Land
# Name
# Windkraftanlage Aachen-Orsbach    50,790556°       6,009° O   NW
# Windkraftanlage Affeln             51,27842°     7,89391° O   NW
# Windkraftanlagen Ahlen-Gemmerich   51,73053°    7,884509° O   NW

# %%
df_nw['Latitude']=df_nw['Latitude'].apply(lambda x: x.replace(',', '.'))
df_nw['Longitude']=df_nw['Longitude'].apply(lambda x: x.replace(',', '.'))

# %%
df_nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 795 entries, Windkraftanlage Aachen-Orsbach to Windpark Zülpich
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   795 non-null    object
#  1   Gesamt- leistung (MW)     795 non-null    float64
#  2   Anzahl                    795 non-null    int64
#  3   Typ (WKA)                 795 non-null    object
#  4   Ort                       795 non-null    object
#  5   Land- kreis               795 non-null    object
#  6   Koordinaten               795 non-null    object
#  7   Projektierer / Betreiber  795 non-null    object
#  8   Bemerkungen               795 non-null    object
#  9   Latitude                  795 non-null    object
#  10  Longitude                 795 non-null    object
#  11  Land                      795 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 80.7+ KB

# %%
orts_nw_MW=df_nw.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_nw_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# PB                        1358.505
# BOR                        652.480
# ST                         630.875
# DN                         481.640
# WAF                        412.370
# SO                         408.010
# KLE                        406.730
# HSK                        329.762
# HX                         317.520
# COE                        292.470

# %%
orts_nw=df_nw.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_nw.head(10)
# Out:
#              Anzahl
# Land- kreis
# PB              544
# ST              286
# BOR             284
# SO              279
# WAF             211
# KLE             206
# DN              184
# HX              176
# LIP             143
# EU              124

# %%
nw=df_nw[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
nw.head(3)
# Out:
#                                  Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Aachen-Orsbach      2010                   0.08       1
# Windkraftanlage Affeln              2010                   0.60       1
# Windkraftanlagen Ahlen-Gemmerich    2010                   8.40       2
#
#                                                   Typ (WKA)        Ort  \
# Name
# Windkraftanlage Aachen-Orsbach            Enercon E-18 (1×)    Orsbach
# Windkraftanlage Affeln                    Tacke TW 600 (1×)     Affeln
# Windkraftanlagen Ahlen-Gemmerich  Enercon E-138 EP3 E2 (2×)  Gemmerich
#
#                                  Land- kreis  Projektierer / Betreiber  \
# Name
# Windkraftanlage Aachen-Orsbach            AC          Wind e.V. Aachen
# Windkraftanlage Affeln                    MK              Windinvestor
# Windkraftanlagen Ahlen-Gemmerich         WAF  Vento Ludens GmbH ＆Co.KG
#
#                                  Bemerkungen     Latitude     Longitude
# Name
# Windkraftanlage Aachen-Orsbach                50.790556°       6.009° O
# Windkraftanlage Affeln                         51.27842°     7.89391° O
# Windkraftanlagen Ahlen-Gemmerich      in Bau   51.73053°    7.884509° O

# %%
print(nw['Land- kreis'].unique())

dict_nw={'HAMK':'HA',
        'OESI':'OE',
        'ACDN':'AC',
        'HSDN':'HS',
         'HSKPB':'HS',
        'REWES':'RE',
        'BMNE':'BM',
        'WESRE':'WES',
        'BORST':'BOR',
        'MIHF':'MI',
        'BIGT':'BI',
        'OWL':'BI'}

   




nw['Land- kreis'].replace(dict_nw, inplace=True)
print(nw['Land- kreis'].unique())
# Out:
# ['AC' 'MK' 'WAF' 'LIP' 'UN' 'OE' 'KLE' 'HAM' 'GT' 'COE' 'RE' 'DN' 'EN'
#  'GM' 'EU' 'HF' 'SO' 'MI' 'BOR' 'BOT' 'VIE' 'HX' 'PB' 'WES' 'BM' 'ST' 'MS'
#  'HSK' 'DO' 'HS' 'SI' 'HA' 'GE' 'ME' 'BI' 'NE' 'RS' 'MH' 'OWL' 'GS' 'GL'
#  'W' 'KR' 'MG' 'SU']
# ['AC' 'MK' 'WAF' 'LIP' 'UN' 'OE' 'KLE' 'HAM' 'GT' 'COE' 'RE' 'DN' 'EN'
#  'GM' 'EU' 'HF' 'SO' 'MI' 'BOR' 'BOT' 'VIE' 'HX' 'PB' 'WES' 'BM' 'ST' 'MS'
#  'HSK' 'DO' 'HS' 'SI' 'HA' 'GE' 'ME' 'BI' 'NE' 'RS' 'MH' 'GS' 'GL' 'W'
#  'KR' 'MG' 'SU']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/2187008208.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nw['Land- kreis'].replace(dict_nw, inplace=True)

# %% [markdown]
# ### Rheinland-Pfalz:

# %%
url_rp="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Rheinland-Pfalz"
# use requests.get() method with the provided static_url
response_rp=requests.get(url_rp).text
# assign the response to a object
soup_rp=BeautifulSoup(response_rp, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_rp.find_all('title'):
    print(title.get_text())
    
html_tables=soup_rp.find_all('table')
table_rp = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_rp.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Rheinland-Pfalz – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_rp=[]    
for row in table_rp.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_rp.append(row)
        
        
print(len(rows_rp))
# Out:
# 311

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_rp[1:len(rows_rp)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_rp= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_rp['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_rp['Latitude']=coord['Latitude']
df_rp['Longitude']=coord['Longitude']

#remove not existing windparks
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Bleckhausen'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Bleialf'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Irrhausen'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Kell am See'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Pintesfeld'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Reifferscheid'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Reinsfeld'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlage Wiebelsheim'].index, inplace=True)
df_rp.drop(df_rp.loc[df_rp['Name']=='Windkraftanlagen Felsbergerhof'].index, inplace=True)



df_rp.set_index('Name', inplace=True)
df_rp['Land']='RP'


df_rp['Anzahl'] = [int(str(i)) for i in df_rp['Anzahl']]
df_rp['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_rp['Gesamt- leistung (MW)']]


df_rp.head(3)
# Out:
#                            Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Badenheim     2010                   3.05       1
# Windkraftanlage Berghausen    2010                   1.30       1
# Windkraftanlage Burg          2010                   1.50       1
#
#                                         Typ (WKA)         Ort Land- kreis  \
# Name
# Windkraftanlage Badenheim      Enercon E-101 (1×)   Badenheim          MZ
# Windkraftanlage Berghausen  AN Bonus 1300/62 (1×)  Berghausen         EMS
# Windkraftanlage Burg             Südwind S70 (1×)        Burg         BIT
#
#                                             Koordinaten  \
# Name
# Windkraftanlage Badenheim   49° 49′ 58″ N, 7° 59′ 15″ O
# Windkraftanlage Berghausen    50° 15′ 24″ N, 8° 1′ 0″ O
# Windkraftanlage Burg          49° 57′ 8″ N, 6° 21′ 0″ O
#
#                            Projektierer / Betreiber  \
# Name
# Windkraftanlage Badenheim                      GAIA
# Windkraftanlage Berghausen             VS Windkraft
# Windkraftanlage Burg
#
#                                                                   Bemerkungen  \
# Name
# Windkraftanlage Badenheim
# Windkraftanlage Berghausen  eine Seewind 25/132 wurde 2013 zugunsten eines...
# Windkraftanlage Burg
#
#                                  Latitude      Longitude Land
# Name
# Windkraftanlage Badenheim   49° 49′ 58″ N   7° 59′ 15″ O   RP
# Windkraftanlage Berghausen  50° 15′ 24″ N     8° 1′ 0″ O   RP
# Windkraftanlage Burg         49° 57′ 8″ N    6° 21′ 0″ O   RP

# %%
df_rp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, Windkraftanlage Badenheim to Windpark Zilshausen
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   301 non-null    object
#  1   Gesamt- leistung (MW)     301 non-null    float64
#  2   Anzahl                    301 non-null    int64
#  3   Typ (WKA)                 301 non-null    object
#  4   Ort                       301 non-null    object
#  5   Land- kreis               301 non-null    object
#  6   Koordinaten               301 non-null    object
#  7   Projektierer / Betreiber  301 non-null    object
#  8   Bemerkungen               301 non-null    object
#  9   Latitude                  301 non-null    object
#  10  Longitude                 301 non-null    object
#  11  Land                      301 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 30.6+ KB

# %%
orts_rp_MW=df_rp.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_rp_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# SIM                         676.45
# BIT                         437.92
# AZ                          413.58
# TR                          243.20
# WIL                         241.87
# KIB                         213.00
# DAU                         187.65
# BIR                         172.00
# WW                          165.38
# COC                         164.35

# %%
orts_rp=df_rp.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_rp.head(10)
# Out:
#              Anzahl
# Land- kreis
# SIM             268
# BIT             252
# AZ              137
# DAU             112
# TR              101
# WW              100
# COC              86
# BIR              72
# WIL              71
# KIB              71

# %%
rp=df_rp[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
rp.head(3)
# Out:
#                            Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Badenheim     2010                   3.05       1
# Windkraftanlage Berghausen    2010                   1.30       1
# Windkraftanlage Burg          2010                   1.50       1
#
#                                         Typ (WKA)         Ort Land- kreis  \
# Name
# Windkraftanlage Badenheim      Enercon E-101 (1×)   Badenheim          MZ
# Windkraftanlage Berghausen  AN Bonus 1300/62 (1×)  Berghausen         EMS
# Windkraftanlage Burg             Südwind S70 (1×)        Burg         BIT
#
#                            Projektierer / Betreiber  \
# Name
# Windkraftanlage Badenheim                      GAIA
# Windkraftanlage Berghausen             VS Windkraft
# Windkraftanlage Burg
#
#                                                                   Bemerkungen  \
# Name
# Windkraftanlage Badenheim
# Windkraftanlage Berghausen  eine Seewind 25/132 wurde 2013 zugunsten eines...
# Windkraftanlage Burg
#
#                                  Latitude      Longitude
# Name
# Windkraftanlage Badenheim   49° 49′ 58″ N   7° 59′ 15″ O
# Windkraftanlage Berghausen  50° 15′ 24″ N     8° 1′ 0″ O
# Windkraftanlage Burg         49° 57′ 8″ N    6° 21′ 0″ O

# %%
print(rp['Land- kreis'].unique())

dict_rp={'DÜWRP':'DÜW',
        'AZMZ':'AZ',
        'MZMZ':'MZ',
        'BIRKUS':'BIR',
         'AZKIB':'AZ',
        'KHKIB':'KH',
        'KLPS':'KL',
        'AZDÜWKIB':'AZ',
        'KHSIMMZ':'KH',
        'COCSIM':'COC',
        'KUSKIB':'KUS',
        'RHKMZ':'RHK',
        'GERSÜW':'GER',
        'SIMKH':'SIM',
        'AWMYK':'AW',
        'TRBIT':'TR',
        'AZWO':'AZ',
        'KUSKL':'KUS',
        'KLKUS':'KL',
        'MAY':'MYK',
        'RHK':'SIM'}

rp['Land- kreis'].replace(dict_rp, inplace=True)
print(rp['Land- kreis'].unique())
# Out:
# ['MZ' 'EMS' 'BIT' 'BIR' 'KL' 'WW' 'KIB' 'WIL' 'PS' 'SIM' 'DAU' 'AK' 'COC'
#  'AZ' 'RP' 'KH' 'KUS' 'DÜW' 'MYK' 'GER' 'TR' 'MAY' 'SÜW' 'RHK' 'AW']
# ['MZ' 'EMS' 'BIT' 'BIR' 'KL' 'WW' 'KIB' 'WIL' 'PS' 'SIM' 'DAU' 'AK' 'COC'
#  'AZ' 'RP' 'KH' 'KUS' 'DÜW' 'MYK' 'GER' 'TR' 'SÜW' 'AW']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/1344177576.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rp['Land- kreis'].replace(dict_rp, inplace=True)

# %% [markdown]
# ### Saarland:

# %%
url_sa="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_im_Saarland"
# use requests.get() method with the provided static_url
response_sa=requests.get(url_sa).text
# assign the response to a object
soup_sa=BeautifulSoup(response_sa, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_sa.find_all('title'):
    print(title.get_text())
    
html_tables=soup_sa.find_all('table')
table_sa = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_sa.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen im Saarland – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_sa=[]    
for row in table_sa.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_sa.append(row)
        
        
print(len(rows_sa))
# Out:
# 51

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_sa[1:len(rows_sa)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_sa= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_sa['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_sa['Latitude']=coord['Latitude']
df_sa['Longitude']=coord['Longitude']



df_sa.set_index('Name', inplace=True)
df_sa['Land']='SA'
#df_nw['Anzahl']=df_nw['Anzahl'].fillna(0)
df_sa['Anzahl'] = [int(str(i)) for i in df_sa['Anzahl']]
df_sa['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_sa['Gesamt- leistung (MW)']]


df_sa.head(3)
# Out:
#                             Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Erkershöhe     2010                   3.00       1
# Windkraftanlage Riesweiler     2010                   0.25       1
# Windkraftanlagen Gersweiler    2010                   9.76       2
#
#                                                                      Typ (WKA)  \
# Name
# Windkraftanlage Erkershöhe                               Nordex N131/3000 (1×)
# Windkraftanlage Riesweiler                                 Nordex N29/250 (1×)
# Windkraftanlagen Gersweiler  Enercon E-138 EP3 E2 (1×)Enercon E-160 EP5 E3 ...
#
#                                        Ort Land- kreis  \
# Name
# Windkraftanlage Erkershöhe   Wemmetsweiler          NK
# Windkraftanlage Riesweiler      Riesweiler         HOM
# Windkraftanlagen Gersweiler     Gersweiler          SB
#
#                                              Koordinaten  \
# Name
# Windkraftanlage Erkershöhe    49° 20′ 31″ N, 7° 4′ 30″ O
# Windkraftanlage Riesweiler     49° 8′ 3″ N, 7° 18′ 22″ O
# Windkraftanlagen Gersweiler  49° 12′ 35″ N, 6° 53′ 32″ O
#
#                             Projektierer / Betreiber Bemerkungen  \
# Name
# Windkraftanlage Erkershöhe           montanWIND GmbH
# Windkraftanlage Riesweiler
# Windkraftanlagen Gersweiler                  DunoAir
#
#                                   Latitude      Longitude Land
# Name
# Windkraftanlage Erkershöhe   49° 20′ 31″ N    7° 4′ 30″ O   SA
# Windkraftanlage Riesweiler     49° 8′ 3″ N   7° 18′ 22″ O   SA
# Windkraftanlagen Gersweiler  49° 12′ 35″ N   6° 53′ 32″ O   SA

# %%
df_sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Windkraftanlage Erkershöhe to Windpark Wolfersweiler
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   50 non-null     object
#  1   Gesamt- leistung (MW)     50 non-null     float64
#  2   Anzahl                    50 non-null     int64
#  3   Typ (WKA)                 50 non-null     object
#  4   Ort                       50 non-null     object
#  5   Land- kreis               50 non-null     object
#  6   Koordinaten               50 non-null     object
#  7   Projektierer / Betreiber  50 non-null     object
#  8   Bemerkungen               50 non-null     object
#  9   Latitude                  50 non-null     object
#  10  Longitude                 50 non-null     object
#  11  Land                      50 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 5.1+ KB

# %%
orts_sa_MW=df_sa.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_sa_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# MZG                         177.70
# WND                         165.35
# SLS                          63.50
# NKWND                        51.35
# NK                           35.50
# WNDMZG                       24.05
# NKHOM                        16.50
# HOM                          16.00
# SB                           15.76

# %%
orts_sa=df_sa.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_sa.head(10)
# Out:
#              Anzahl
# Land- kreis
# WND              71
# MZG              68
# SLS              21
# NKWND            19
# NK               16
# WNDMZG           10
# HOM               8
# NKHOM             5
# SB                4

# %%
sa=df_sa[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
sa.head(3)
# Out:
#                             Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Erkershöhe     2010                   3.00       1
# Windkraftanlage Riesweiler     2010                   0.25       1
# Windkraftanlagen Gersweiler    2010                   9.76       2
#
#                                                                      Typ (WKA)  \
# Name
# Windkraftanlage Erkershöhe                               Nordex N131/3000 (1×)
# Windkraftanlage Riesweiler                                 Nordex N29/250 (1×)
# Windkraftanlagen Gersweiler  Enercon E-138 EP3 E2 (1×)Enercon E-160 EP5 E3 ...
#
#                                        Ort Land- kreis  \
# Name
# Windkraftanlage Erkershöhe   Wemmetsweiler          NK
# Windkraftanlage Riesweiler      Riesweiler         HOM
# Windkraftanlagen Gersweiler     Gersweiler          SB
#
#                             Projektierer / Betreiber Bemerkungen  \
# Name
# Windkraftanlage Erkershöhe           montanWIND GmbH
# Windkraftanlage Riesweiler
# Windkraftanlagen Gersweiler                  DunoAir
#
#                                   Latitude      Longitude
# Name
# Windkraftanlage Erkershöhe   49° 20′ 31″ N    7° 4′ 30″ O
# Windkraftanlage Riesweiler     49° 8′ 3″ N   7° 18′ 22″ O
# Windkraftanlagen Gersweiler  49° 12′ 35″ N   6° 53′ 32″ O

# %%
print(sa['Land- kreis'].unique())

dict_sa={
        'NKWND':'NK',
        'NKHOM':'NK',
        'WNDMZG':'WND'}

sa['Land- kreis'].replace(dict_sa, inplace=True)
print(sa['Land- kreis'].unique())
# Out:
# ['NK' 'HOM' 'SB' 'SLS' 'MZG' 'WND' 'NKWND' 'NKHOM' 'WNDMZG']
# ['NK' 'HOM' 'SB' 'SLS' 'MZG' 'WND']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/3992823916.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sa['Land- kreis'].replace(dict_sa, inplace=True)

# %% [markdown]
# ### Sachsen:

# %%
url_s="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Sachsen"
# use requests.get() method with the provided static_url
response_s=requests.get(url_s).text
# assign the response to a object
soup_s=BeautifulSoup(response_s, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_s.find_all('title'):
    print(title.get_text())
    
html_tables=soup_s.find_all('table')
table_s = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_s.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)


rows_s=[]    
for row in table_s.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_s.append(row)
        
        
print(len(rows_s))
# Out:
# The title is:
# Liste von Windkraftanlagen in Sachsen – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']
# 174

# %%
table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_s[1:len(rows_s)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())

# %%
df_s= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })





#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_s['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_s['Latitude']=coord['Latitude']
df_s['Longitude']=coord['Longitude']


#remove not existing wiondparks
df_s.drop(df_s.loc[df_s['Name']=='Windkraftanlage Ruppersdorf'].index, inplace=True)
df_s.drop(df_s.loc[df_s['Name']=='Windkraftanlage Seifersdorf'].index, inplace=True)
df_s.drop(df_s.loc[df_s['Name']=='Windkraftanlagen Zaulsdorf'].index, inplace=True)
df_s.drop(df_s.loc[df_s['Name']=='Windpark Bernsbach'].index, inplace=True)
df_s.drop(df_s.loc[df_s['Name']=='Windkraftpark Nossen (Windpark Zellsteig)'].index, inplace=True)



df_s.set_index('Name', inplace=True)
df_s['Land']='SA'
#df_nw['Anzahl']=df_nw['Anzahl'].fillna(0)
df_s['Anzahl'] = [int(str(i)) for i in df_s['Anzahl']]
df_s['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_s['Gesamt- leistung (MW)']]


df_s.head(3)
# Out:
#                           Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Altenhain    2010                   0.25       1
# Windkraftanlage Börnichen    2010                   1.80       1
# Windkraftanlage Ebersdorf    2010                   0.60       1
#
#                                          Typ (WKA)        Ort Land- kreis  \
# Name
# Windkraftanlage Altenhain      Nordex N29/250 (1×)  Altenhain           L
# Windkraftanlage Börnichen  Enercon E-66/18.70 (1×)  Börnichen         ERZ
# Windkraftanlage Ebersdorf   Enercon E-40/6.44 (1×)  Ebersdorf          GR
#
#                                            Koordinaten  \
# Name
# Windkraftanlage Altenhain  51° 17′ 4″ N, 12° 42′ 16″ O
# Windkraftanlage Börnichen  50° 45′ 26″ N, 13° 7′ 40″ O
# Windkraftanlage Ebersdorf   51° 4′ 8″ N, 14° 40′ 39″ O
#
#                           Projektierer / Betreiber  \
# Name
# Windkraftanlage Altenhain
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                                        Bemerkungen  \
# Name
# Windkraftanlage Altenhain  eine Nordex N27/150 wurde 2015 abgebaut
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                 Latitude       Longitude Land
# Name
# Windkraftanlage Altenhain   51° 17′ 4″ N   12° 42′ 16″ O   SA
# Windkraftanlage Börnichen  50° 45′ 26″ N    13° 7′ 40″ O   SA
# Windkraftanlage Ebersdorf    51° 4′ 8″ N   14° 40′ 39″ O   SA

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, Windkraftanlage Altenhain to Windpark Zwickau-Lippoldsruh
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   168 non-null    object
#  1   Gesamt- leistung (MW)     168 non-null    float64
#  2   Anzahl                    168 non-null    int64
#  3   Typ (WKA)                 168 non-null    object
#  4   Ort                       168 non-null    object
#  5   Land- kreis               168 non-null    object
#  6   Koordinaten               168 non-null    object
#  7   Projektierer / Betreiber  168 non-null    object
#  8   Bemerkungen               168 non-null    object
#  9   Latitude                  168 non-null    object
#  10  Longitude                 168 non-null    object
#  11  Land                      168 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 17.1+ KB

# %%
orts_s_MW=df_s.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_s_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# FG                         243.010
# GR                         213.100
# MEI                        186.970
# Z                          138.785
# BZ                         138.510
# L                          129.460
# TDO                        107.660
# FGERZ                       59.000
# PIR                         46.770
# ERZ                         44.360

# %%
orts_s=df_s.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_s.head(10)
# Out:
#              Anzahl
# Land- kreis
# FG              171
# GR              123
# L                90
# TDO              90
# BZ               86
# MEI              81
# Z                53
# PIR              51
# ERZ              40
# FGERZ            28

# %%
s=df_s[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
s.head(3)
# Out:
#                           Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Altenhain    2010                   0.25       1
# Windkraftanlage Börnichen    2010                   1.80       1
# Windkraftanlage Ebersdorf    2010                   0.60       1
#
#                                          Typ (WKA)        Ort Land- kreis  \
# Name
# Windkraftanlage Altenhain      Nordex N29/250 (1×)  Altenhain           L
# Windkraftanlage Börnichen  Enercon E-66/18.70 (1×)  Börnichen         ERZ
# Windkraftanlage Ebersdorf   Enercon E-40/6.44 (1×)  Ebersdorf          GR
#
#                           Projektierer / Betreiber  \
# Name
# Windkraftanlage Altenhain
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                                        Bemerkungen  \
# Name
# Windkraftanlage Altenhain  eine Nordex N27/150 wurde 2015 abgebaut
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                 Latitude       Longitude
# Name
# Windkraftanlage Altenhain   51° 17′ 4″ N   12° 42′ 16″ O
# Windkraftanlage Börnichen  50° 45′ 26″ N    13° 7′ 40″ O
# Windkraftanlage Ebersdorf    51° 4′ 8″ N   14° 40′ 39″ O

# %%
print(s['Land- kreis'].unique())

dict_s={
        'TDOL':'TDO',
        'FGERZ':'FG',
        'PIRBZ':'PIR',
          'FGZ':'FG'}

s['Land- kreis'].replace(dict_s, inplace=True)
print(s['Land- kreis'].unique())
# Out:
# ['L' 'ERZ' 'GR' 'FG' 'TDO' 'BZ' 'PIR' 'Z' 'V' 'C' 'MEI' 'TDOL' 'FGERZ'
#  'FGZ' 'PIRBZ']
# ['L' 'ERZ' 'GR' 'FG' 'TDO' 'BZ' 'PIR' 'Z' 'V' 'C' 'MEI']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/814807473.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['Land- kreis'].replace(dict_s, inplace=True)

# %% [markdown]
# ### Sachsen-Anhalt:

# %%
url_an="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Sachsen-Anhalt"
# use requests.get() method with the provided static_url
response_an=requests.get(url_an).text
# assign the response to a object
soup_an=BeautifulSoup(response_an, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_an.find_all('title'):
    print(title.get_text())
    
html_tables=soup_an.find_all('table')
table_an = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_an.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Sachsen-Anhalt – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_an=[]    
for row in table_an.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_an.append(row)
        
        
print(len(rows_an))




table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_an[1:len(rows_an)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())
# Out:
# 237

# %%
df_an= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })


#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_an['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_an['Latitude']=coord['Latitude']
df_an['Longitude']=coord['Longitude']


#remove not existing wiondparks
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Großgräfendorf'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Harsleben'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Klein Quenstedt'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Rohrsheim'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Roßberg'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Stegelitz'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlage Wust'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlagen Altenroda'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlagen Ditfurt'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windkraftanlagen Schwenda'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windpark Baumgarten'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windpark Galgenberg'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windpark Gleina'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windpark Obermöllern'].index, inplace=True)
df_an.drop(df_an.loc[df_an['Name']=='Windpark Klein Schwechten'].index, inplace=True)




df_an.set_index('Name', inplace=True)
df_an['Land']='SA'

df_an['Anzahl'] = [int(str(i)) for i in df_an['Anzahl']]
df_an['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_an['Gesamt- leistung (MW)']]


df_an.head(3)
# Out:
#                           Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Altenhain    2010                   0.25       1
# Windkraftanlage Börnichen    2010                   1.80       1
# Windkraftanlage Ebersdorf    2010                   0.60       1
#
#                                          Typ (WKA)        Ort Land- kreis  \
# Name
# Windkraftanlage Altenhain      Nordex N29/250 (1×)  Altenhain           L
# Windkraftanlage Börnichen  Enercon E-66/18.70 (1×)  Börnichen         ERZ
# Windkraftanlage Ebersdorf   Enercon E-40/6.44 (1×)  Ebersdorf          GR
#
#                                            Koordinaten  \
# Name
# Windkraftanlage Altenhain  51° 17′ 4″ N, 12° 42′ 16″ O
# Windkraftanlage Börnichen  50° 45′ 26″ N, 13° 7′ 40″ O
# Windkraftanlage Ebersdorf   51° 4′ 8″ N, 14° 40′ 39″ O
#
#                           Projektierer / Betreiber  \
# Name
# Windkraftanlage Altenhain
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                                        Bemerkungen  \
# Name
# Windkraftanlage Altenhain  eine Nordex N27/150 wurde 2015 abgebaut
# Windkraftanlage Börnichen
# Windkraftanlage Ebersdorf
#
#                                 Latitude       Longitude Land
# Name
# Windkraftanlage Altenhain   51° 17′ 4″ N   12° 42′ 16″ O   SA
# Windkraftanlage Börnichen  50° 45′ 26″ N    13° 7′ 40″ O   SA
# Windkraftanlage Ebersdorf    51° 4′ 8″ N   14° 40′ 39″ O   SA

# %%
df_an.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221 entries, Windkraftanlage Ackendorf to Windpark Zschornewitz
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   221 non-null    object
#  1   Gesamt- leistung (MW)     221 non-null    float64
#  2   Anzahl                    221 non-null    int64
#  3   Typ (WKA)                 221 non-null    object
#  4   Ort                       221 non-null    object
#  5   Land- kreis               221 non-null    object
#  6   Koordinaten               221 non-null    object
#  7   Projektierer / Betreiber  221 non-null    object
#  8   Bemerkungen               221 non-null    object
#  9   Latitude                  221 non-null    object
#  10  Longitude                 221 non-null    object
#  11  Land                      221 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 22.4+ KB

# %%
orts_an=df_an.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_an.head(10)
# Out:
#              Anzahl
# Land- kreis
# BK              415
# SLK             384
# SDL             308
# BLK             253
# ABI             242
# SAW             213
# MSH             178
# SK              171
# WB              150
# JL              138

# %%
orts_an_MW=df_an.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_an_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# SDL                         857.32
# BK                          725.60
# SLK                         723.25
# BLK                         568.22
# ABI                         505.38
# SAW                         401.25
# WB                          364.46
# SK                          326.55
# MSH                         287.57
# JL                          286.25

# %%
an=df_an[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
an.head(3)
# Out:
#                              Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Ackendorf       2010                    1.5       1
# Windkraftanlage Breitenstein    2010                    0.5       1
# Windkraftanlage Bretsch         2010                    0.5       1
#
#                                               Typ (WKA)           Ort  \
# Name
# Windkraftanlage Ackendorf     GE Wind Energy 1.5sl (1×)  Haldensleben
# Windkraftanlage Breitenstein     Enercon E-40/5.40 (1×)  Breitenstein
# Windkraftanlage Bretsch          Enercon E-40/5.40 (1×)       Bretsch
#
#                              Land- kreis Projektierer / Betreiber Bemerkungen  \
# Name
# Windkraftanlage Ackendorf             BK        Germania Windpark
# Windkraftanlage Breitenstein         MSH
# Windkraftanlage Bretsch              SDL
#
#                                    Latitude       Longitude
# Name
# Windkraftanlage Ackendorf     52° 13′ 29″ N   11° 25′ 34″ O
# Windkraftanlage Breitenstein  51° 37′ 26″ N   10° 56′ 29″ O
# Windkraftanlage Bretsch       52° 50′ 13″ N   11° 38′ 20″ O

# %%
print(an['Land- kreis'].unique())

dict_an={
        'SKMSH':'SK',
        'SKSLK':'SK',
        'MSHSK':'MSH',
        'JLSDL':'JL',
        'SAWSDL':'SAW',
         'MSHSLK':'MSH',
          'BKHZ':'BK'}

an['Land- kreis'].replace(dict_an, inplace=True)
print(an['Land- kreis'].unique())
# Out:
# ['BK' 'MSH' 'SDL' 'WB' 'HZ' 'SK' 'JL' 'BLK' 'ABI' 'MD' 'DE' 'SAW' 'SLK'
#  'SKMSH' 'SKSLK' 'MSHSK' 'JLSDL' 'SAWSDL' 'MSHSLK' 'BKHZ']
# ['BK' 'MSH' 'SDL' 'WB' 'HZ' 'SK' 'JL' 'BLK' 'ABI' 'MD' 'DE' 'SAW' 'SLK']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/3289970966.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   an['Land- kreis'].replace(dict_an, inplace=True)

# %% [markdown]
# ### Schleswig-Holstein:

# %%
url_ho="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Schleswig-Holstein"
# use requests.get() method with the provided static_url
response_ho=requests.get(url_ho).text
# assign the response to a object
soup_ho=BeautifulSoup(response_ho, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_ho.find_all('title'):
    print(title.get_text())
    
html_tables=soup_ho.find_all('table')
table_ho = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_ho.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)
# Out:
# The title is:
# Liste von Windkraftanlagen in Schleswig-Holstein – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']

# %%
rows_ho=[]    
for row in table_ho.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_ho.append(row)
        
        
print(len(rows_ho))




table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_ho[1:len(rows_ho)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())
# Out:
# 493

# %%
df_ho= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })


#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_ho['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_ho['Latitude']=coord['Latitude']
df_ho['Longitude']=coord['Longitude']


#remove not existing wiondparks
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Am Kählerhof'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Apeldör'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Arkebek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Ascheberg'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Aventoft'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Bargenstedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Barlteraltendeich'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Beidenfleth'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Blieschendorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Boksee'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Bögelhuusfeld'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Dellweg'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Eesch'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Eckernstrom'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Evensbüller Chaussee'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Fedderingen'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Flintbek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Fäkalstraße'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Garbek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Garding'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Grüner Deich'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Tating-Geestgraben'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Geesthacht-Pumpwerk['].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Glücksburg-Bremsbergallee'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Gollendorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Goosefeld'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Gremmerup'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Haffdeich'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Harmswöhrden'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Heide'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Helgoland'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Hollingstedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Klausdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Kläranlage Meldorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Kleihörn'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Köhnholz-Ost'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Kömdiek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Königsacker'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Krogaspe'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Lehe'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Malente'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Neuberend'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Neudorf-Bornstein'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Neufresenburg'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Neuhof'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Neustadt-Rettin'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Niebüll'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Nienborstel I'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Nordhastedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Norderheistedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Oersberg'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Oeverwisch'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Osterhof'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Oster-Ohrstedtfeld'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Passade'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Porrenkoog-Sielzug'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Poppenbüll'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Possfeld'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Püttsee'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Rader Insel'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Reesdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Sankt Michaelisdonn-Klärwerk'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Sankt Michaelisdonn-Moorstrich'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Sankt Peter-Ording'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Scharfenstein'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Schnarup'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Schöpfwerk Adamsiel'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Schülper Feld'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Stedesand'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Sönke-Nissen-Koog'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Süderhastedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Süderholm'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Süderschmedeby'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Trendermarschweg'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Ulsnis'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Unewatt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Vadersdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Viöl'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Wedel-Yachthafen'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Westermarkelsdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Westeroffenbülldeich'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlagen Wewelsfleth'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Wolmersdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windkraftanlage Ünnern Diek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Avendorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Brodten'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Elpersbüttel'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Glüsing'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Hennstedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Immenstedt'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Petersdorf'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Tammensiel'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Vollerwiek'].index, inplace=True)
df_ho.drop(df_ho.loc[df_ho['Name']=='Windpark Wyk auf Föhr'].index, inplace=True)


df_ho.set_index('Name', inplace=True)
df_ho['Land']='Sch-H'

df_ho['Anzahl'] = [int(str(i)) for i in df_ho['Anzahl']]
df_ho['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_ho['Gesamt- leistung (MW)']]


df_ho.head(3)
# Out:
#                                Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Ahrenshöft        2010                   1.50       1
# Windkraftanlage Albersdorf Süd    2010                   5.56       1
# Windkraftanlagen Arup             2010                   1.00       2
#
#                                                 Typ (WKA)         Ort  \
# Name
# Windkraftanlage Ahrenshöft            Vensys 77/1500 (1×)  Ahrenshöft
# Windkraftanlage Albersdorf Süd  Enercon E-160 EP5 E3 (1×)  Albersdorf
# Windkraftanlagen Arup            Nordtank NTK 500/41 (2×)   Struxdorf
#
#                                Land- kreis                 Koordinaten  \
# Name
# Windkraftanlage Ahrenshöft              NF  54° 33′ 39″ N, 9° 5′ 16″ O
# Windkraftanlage Albersdorf Süd         HEI  54° 7′ 18″ N, 9° 15′ 39″ O
# Windkraftanlagen Arup                   SL  54° 37′ 20″ N, 9° 38′ 3″ O
#
#                                     Projektierer / Betreiber  \
# Name
# Windkraftanlage Ahrenshöft      Ahrenshöfter Naturkraftwerke
# Windkraftanlage Albersdorf Süd                     WP Schlaa
# Windkraftanlagen Arup                 Westangler Windenergie
#
#                                                                       Bemerkungen  \
# Name
# Windkraftanlage Ahrenshöft      Von 1998 bis 2003 stand im Windpark eine weite...
# Windkraftanlage Albersdorf Süd                              errichtet an der A 23
# Windkraftanlagen Arup
#
#                                      Latitude      Longitude   Land
# Name
# Windkraftanlage Ahrenshöft      54° 33′ 39″ N    9° 5′ 16″ O  Sch-H
# Windkraftanlage Albersdorf Süd   54° 7′ 18″ N   9° 15′ 39″ O  Sch-H
# Windkraftanlagen Arup           54° 37′ 20″ N    9° 38′ 3″ O  Sch-H

# %%
df_ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399 entries, Windkraftanlage Ahrenshöft to Windtestfeld Nord
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   399 non-null    object
#  1   Gesamt- leistung (MW)     399 non-null    float64
#  2   Anzahl                    399 non-null    int64
#  3   Typ (WKA)                 399 non-null    object
#  4   Ort                       399 non-null    object
#  5   Land- kreis               399 non-null    object
#  6   Koordinaten               399 non-null    object
#  7   Projektierer / Betreiber  399 non-null    object
#  8   Bemerkungen               399 non-null    object
#  9   Latitude                  399 non-null    object
#  10  Longitude                 399 non-null    object
#  11  Land                      399 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 40.5+ KB

# %%
orts_ho=df_ho.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_ho.head(10)
# Out:
#              Anzahl
# Land- kreis
# HEI             854
# NF              854
# SL              521
# OH              332
# IZ              306
# RD              224
# SE               76
# RZ               63
# OD               43
# PLÖ              41

# %%
orts_ho_MW=df_ho.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_ho_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# NF                        2480.540
# HEI                       2312.723
# SL                        1448.220
# IZ                         822.900
# OH                         759.975
# RD                         653.405
# SE                         308.980
# RZ                         104.550
# OHSE                        91.500
# SG                          67.500

# %%
ho=df_ho[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
ho.head(3)
# Out:
#                                Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Ahrenshöft        2010                   1.50       1
# Windkraftanlage Albersdorf Süd    2010                   5.56       1
# Windkraftanlagen Arup             2010                   1.00       2
#
#                                                 Typ (WKA)         Ort  \
# Name
# Windkraftanlage Ahrenshöft            Vensys 77/1500 (1×)  Ahrenshöft
# Windkraftanlage Albersdorf Süd  Enercon E-160 EP5 E3 (1×)  Albersdorf
# Windkraftanlagen Arup            Nordtank NTK 500/41 (2×)   Struxdorf
#
#                                Land- kreis      Projektierer / Betreiber  \
# Name
# Windkraftanlage Ahrenshöft              NF  Ahrenshöfter Naturkraftwerke
# Windkraftanlage Albersdorf Süd         HEI                     WP Schlaa
# Windkraftanlagen Arup                   SL        Westangler Windenergie
#
#                                                                       Bemerkungen  \
# Name
# Windkraftanlage Ahrenshöft      Von 1998 bis 2003 stand im Windpark eine weite...
# Windkraftanlage Albersdorf Süd                              errichtet an der A 23
# Windkraftanlagen Arup
#
#                                      Latitude      Longitude
# Name
# Windkraftanlage Ahrenshöft      54° 33′ 39″ N    9° 5′ 16″ O
# Windkraftanlage Albersdorf Süd   54° 7′ 18″ N   9° 15′ 39″ O
# Windkraftanlagen Arup           54° 37′ 20″ N    9° 38′ 3″ O

# %%
print(ho['Land- kreis'].unique())

dict_ho={
        'OHSE':'OH'}

ho['Land- kreis'].replace(dict_ho, inplace=True)
print(ho['Land- kreis'].unique())
# Out:
# ['NF' 'HEI' 'SL' 'OD' 'RD' 'IZ' 'FL' 'OH' 'RZ' 'SE' 'PI' 'HL' 'PLÖ' 'KI'
#  'SG' 'OHSE']
# ['NF' 'HEI' 'SL' 'OD' 'RD' 'IZ' 'FL' 'OH' 'RZ' 'SE' 'PI' 'HL' 'PLÖ' 'KI'
#  'SG']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/1038083720.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ho['Land- kreis'].replace(dict_ho, inplace=True)

# %% [markdown]
# ### Thuringen:

# %%
url_th="https://de.wikipedia.org/wiki/Liste_von_Windkraftanlagen_in_Thüringen"
# use requests.get() method with the provided static_url
response_th=requests.get(url_th).text
# assign the response to a object
soup_th=BeautifulSoup(response_th, 'html.parser')
# Use soup.title attribute
print('The title is:')
for title in soup_th.find_all('title'):
    print(title.get_text())
    
html_tables=soup_th.find_all('table')
table_th = html_tables[0]

column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

columns=table_th.find_all('th')
for column in columns:
    name=extract_column_from_header(column)
    
    if name!= None:
        if len(name)>0:
            column_names.append(name)
    
print(column_names)


rows_th=[]    
for row in table_th.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_th.append(row)
        
        
print(len(rows_th))
# Out:
# The title is:
# Liste von Windkraftanlagen in Thüringen – Wikipedia
# ['Name', 'Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Koordinaten', 'Projektierer / Betreiber', 'Bemerkungen']
# 102

# %%
rows_th=[]    
for row in table_th.find_all('tr'):
        td = row.find_all('td')
        row = [row.text for row in td]
        rows_th.append(row)
        
        
print(len(rows_th))




table_dict= dict.fromkeys(column_names)



# Let's initial the table_dict with each value to be an empty list
table_dict['Name'] = []
table_dict['Baujahr'] = []
table_dict['Gesamt- leistung (MW)'] = []
table_dict['Anzahl'] = []
table_dict['Typ (WKA)'] = []
table_dict['Ort'] = []
table_dict['Land- kreis'] = []

table_dict['Koordinaten']=[]
table_dict['Projektierer / Betreiber']=[]
table_dict['Bemerkungen']=[]


#filling the dictionaries:



for i in rows_th[1:len(rows_th)]:
    if i[0]!=None:
        name=i[0].strip()
        name=re.sub(r'\[\d+\]', '', name)
        table_dict['Name'].append(name)
        
    years=x[1].strip()
    table_dict['Baujahr'].append(years)
    table_dict['Baujahr'] = [x[0:4] for x in table_dict['Baujahr']]
    
    table_dict['Gesamt- leistung (MW)'].append(i[2].strip())
    table_dict['Anzahl'].append(i[3].strip())
    table_dict['Typ (WKA)'].append(i[4].strip())
    table_dict['Ort'].append(i[5].strip())
    table_dict['Land- kreis'].append(i[6].strip())

    table_dict['Koordinaten'].append(i[7].strip())
    table_dict['Projektierer / Betreiber'].append(i[8].strip())
    table_dict['Bemerkungen'].append(i[-1].strip())
# Out:
# 102

# %%
df_th= pd.DataFrame({ key:pd.Series(value) for key, value in table_dict.items() })

#splitting the coordinates:
fn = lambda x: pd.Series([i for i in (x.split(','))])
coord = df_th['Koordinaten'].apply(fn)
coord.rename(columns={0:'Latitude',1:'Longitude'},inplace=True)
df_th['Latitude']=coord['Latitude']
df_th['Longitude']=coord['Longitude']


df_th.set_index('Name', inplace=True)
df_th['Land']='Th'

df_th['Anzahl'] = [int(str(i)) for i in df_th['Anzahl']]
df_th['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in df_th['Gesamt- leistung (MW)']]


df_th.head(3)
# Out:
#                                  Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Breitungen/Werra    2010                   0.60       1
# Windkraftanlage Cretzschwitz        2010                   2.35       1
# Windkraftanlage Diedorf             2010                   0.60       1
#
#                                               Typ (WKA)               Ort  \
# Name
# Windkraftanlage Breitungen/Werra     Tacke TW 600e (1×)  Breitungen-Winne
# Windkraftanlage Cretzschwitz          Enercon E-92 (1×)      Cretzschwitz
# Windkraftanlage Diedorf           Micon M 1500-600 (1×)           Diedorf
#
#                                  Land- kreis                   Koordinaten  \
# Name
# Windkraftanlage Breitungen/Werra          SM  50° 45′ 22″ N, 10° 21′ 19″ O
# Windkraftanlage Cretzschwitz               G   50° 56′ 12″ N, 12° 6′ 24″ O
# Windkraftanlage Diedorf                   UH  51° 11′ 22″ N, 10° 17′ 32″ O
#
#                                    Projektierer / Betreiber     Bemerkungen  \
# Name
# Windkraftanlage Breitungen/Werra                             Sanierung 2010
# Windkraftanlage Cretzschwitz      GoEn Planungsgesellschaft
# Windkraftanlage Diedorf
#
#                                        Latitude       Longitude Land
# Name
# Windkraftanlage Breitungen/Werra  50° 45′ 22″ N   10° 21′ 19″ O   Th
# Windkraftanlage Cretzschwitz      50° 56′ 12″ N    12° 6′ 24″ O   Th
# Windkraftanlage Diedorf           51° 11′ 22″ N   10° 17′ 32″ O   Th

# %%
orts_th=df_th.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
orts_th.head(10)
# Out:
#              Anzahl
# Land- kreis
# SÖM             103
# UH               85
# WAK              83
# KYF              83
# ABG              64
# GTHUH            64
# SHK              58
# EIC              57
# AP               50
# EF               36

# %%
orts_th_MW=df_th.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
orts_th_MW.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# SÖM                         270.95
# UH                          208.85
# KYF                         180.65
# GTHUH                       158.85
# WAK                         133.87
# SHK                         117.70
# ABG                         113.30
# EIC                         100.50
# AP                           93.50
# NDH                          83.75

# %%
th=df_th[['Baujahr', 'Gesamt- leistung (MW)', 'Anzahl', 'Typ (WKA)', 'Ort', 'Land- kreis', 'Projektierer / Betreiber', 'Bemerkungen', 'Latitude', 'Longitude']]
th.head(3)
# Out:
#                                  Baujahr  Gesamt- leistung (MW)  Anzahl  \
# Name
# Windkraftanlage Breitungen/Werra    2010                   0.60       1
# Windkraftanlage Cretzschwitz        2010                   2.35       1
# Windkraftanlage Diedorf             2010                   0.60       1
#
#                                               Typ (WKA)               Ort  \
# Name
# Windkraftanlage Breitungen/Werra     Tacke TW 600e (1×)  Breitungen-Winne
# Windkraftanlage Cretzschwitz          Enercon E-92 (1×)      Cretzschwitz
# Windkraftanlage Diedorf           Micon M 1500-600 (1×)           Diedorf
#
#                                  Land- kreis   Projektierer / Betreiber  \
# Name
# Windkraftanlage Breitungen/Werra          SM
# Windkraftanlage Cretzschwitz               G  GoEn Planungsgesellschaft
# Windkraftanlage Diedorf                   UH
#
#                                      Bemerkungen       Latitude  \
# Name
# Windkraftanlage Breitungen/Werra  Sanierung 2010  50° 45′ 22″ N
# Windkraftanlage Cretzschwitz                      50° 56′ 12″ N
# Windkraftanlage Diedorf                           51° 11′ 22″ N
#
#                                        Longitude
# Name
# Windkraftanlage Breitungen/Werra   10° 21′ 19″ O
# Windkraftanlage Cretzschwitz        12° 6′ 24″ O
# Windkraftanlage Diedorf            10° 17′ 32″ O

# %%
print(th['Land- kreis'].unique())

dict_th={'SHKAP':'SHK',
        'KYFSÖM':'KYF',
        'KYFUH':'KYF',
        'APSLF':'AP',
        'WAKGTH':'WAK',
        'GTHUH':'GTH',
        'SÖ':'SÖM'}

th['Land- kreis'].replace(dict_th, inplace=True)
print(th['Land- kreis'].unique())
# Out:
# ['SM' 'G' 'UH' 'WAK' 'EIC' 'SOK' 'SHK' 'GRZ' 'SÖ' 'ABG' 'SLF' 'HBN' 'SÖM'
#  'AP' 'GTH' 'KYF' 'EF' 'NDH' 'IK']
# ['SM' 'G' 'UH' 'WAK' 'EIC' 'SOK' 'SHK' 'GRZ' 'SÖM' 'ABG' 'SLF' 'HBN' 'AP'
#  'GTH' 'KYF' 'EF' 'NDH' 'IK']
# /var/folders/bg/6h6fxpzx7_v6jgvd0c31r_7m0000gn/T/ipykernel_3643/4119317117.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th['Land- kreis'].replace(dict_th, inplace=True)

# %%
landes_list=[bw, th, ho, an, s , sa, rp, nw, bayern, mvp, hbh, he, br]
landes=pd.concat(landes_list)
landes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4254 entries, Forschungswindkraftanlage RedoxWind to Windpark Zossen
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   4254 non-null   object
#  1   Gesamt- leistung (MW)     4254 non-null   object
#  2   Anzahl                    4254 non-null   object
#  3   Typ (WKA)                 4254 non-null   object
#  4   Ort                       4254 non-null   object
#  5   Land- kreis               4254 non-null   object
#  6   Projektierer / Betreiber  4254 non-null   object
#  7   Bemerkungen               4254 non-null   object
#  8   Latitude                  4254 non-null   object
#  9   Longitude                 4254 non-null   object
# dtypes: object(10)
# memory usage: 365.6+ KB

# %%
landes.head(3)
# Out:
#                                     Baujahr Gesamt- leistung (MW) Anzahl  \
# Forschungswindkraftanlage RedoxWind    2017                   2.0      1
# Windkraftanlage Alexanderschanze       2003                   1.5      1
# Windkraftanlage Alpirsbach             1999                   2.3      1
#
#                                                 Typ (WKA)  \
# Forschungswindkraftanlage RedoxWind        Qreon Q82 (1×)
# Windkraftanlage Alexanderschanze         Südwind S70 (1×)
# Windkraftanlage Alpirsbach           Enercon E-70 E4 (1×)
#
#                                                          Ort Land- kreis  \
# Forschungswindkraftanlage RedoxWind                Karlsruhe          KA
# Windkraftanlage Alexanderschanze     Bad Peterstal-Griesbach          OG
# Windkraftanlage Alpirsbach                       Römlinsdorf         FDS
#
#                                                         Projektierer / Betreiber  \
# Forschungswindkraftanlage RedoxWind                               Fraunhofer ICT
# Windkraftanlage Alexanderschanze     Schmalz, Windenergieanlage „Bei der Schanz“
# Windkraftanlage Alpirsbach           Windkraft Römlinsdorf, Stadtwerke Stuttgart
#
#                                                                            Bemerkungen  \
# Forschungswindkraftanlage RedoxWind  Forschungsprojekt mit kombiniertem Batteriespe...
# Windkraftanlage Alexanderschanze     errichtet an der Schwarzwaldhochstraße im Bere...
# Windkraftanlage Alpirsbach           Repowering 2013 (1× Enercon E-70 E4 statt 1× F...
#
#                                           Latitude      Longitude
# Forschungswindkraftanlage RedoxWind    49° 1′ 9″ N    8° 31′ 4″ O
# Windkraftanlage Alexanderschanze     48° 28′ 22″ N    8° 16′ 7″ O
# Windkraftanlage Alpirsbach            48° 20′ 0″ N   8° 28′ 34″ O

# %%
data=pd.read_csv('Landkreis_ID.csv', index_col=False)
data.head(5)
# Out:
#     Code           NUTS 1.1   NUTS 2.1                       Name Land- kreis
# 0  DEB12    Rheinland-Pfalz    Koblenz                  Ahrweiler          AW
# 1  DE275             Bayern   Schwaben          Aichach-Friedberg         AIC
# 2  DE145  Baden-Württemberg   Tübingen            Alb-Donau-Kreis          UL
# 3  DEG0M          Thüringen  Thüringen           Altenburger Land         ABG
# 4  DEB13    Rheinland-Pfalz    Koblenz  Altenkirchen (Westerwald)          AK

# %%
data.to_csv('Windanlage_DE.csv')

# %%
new_data=pd.merge(landes,data, how='left', on='Land- kreis')

# %%
new_data['Code'].loc[new_data['Land- kreis']=='CB']='DE402'
new_data['Code'].loc[new_data['Land- kreis']=='HOM']='DEC05'
new_data['NUTS 1.1'].loc[new_data['Land- kreis']=='CB']='DE4'
new_data['NUTS 1.1'].loc[new_data['Land- kreis']=='HOM']='DEC'

new_data['NUTS 2.1'].loc[new_data['Land- kreis']=='CB']='DE40'
new_data['NUTS 2.1'].loc[new_data['Land- kreis']=='HOM']='DEC0'
new_data['Name'].loc[new_data['Land- kreis']=='CB']='Cottbus, Kreisfreie Stadt'
new_data['Name'].loc[new_data['Land- kreis']=='HOM']='Saarpfalz-Kreis'

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4693 entries, 0 to 4692
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Baujahr                   4693 non-null   object
#  1   Gesamt- leistung (MW)     4693 non-null   object
#  2   Anzahl                    4693 non-null   object
#  3   Typ (WKA)                 4693 non-null   object
#  4   Ort                       4693 non-null   object
#  5   Land- kreis               4693 non-null   object
#  6   Projektierer / Betreiber  4693 non-null   object
#  7   Bemerkungen               4693 non-null   object
#  8   Latitude                  4693 non-null   object
#  9   Longitude                 4693 non-null   object
#  10  Code                      4693 non-null   object
#  11  NUTS 1.1                  4693 non-null   object
#  12  NUTS 2.1                  4693 non-null   object
#  13  Name                      4693 non-null   object
# dtypes: object(14)
# memory usage: 513.4+ KB

# %%
new_data['Anzahl'] = [int(str(i)) for i in new_data['Anzahl']]
new_data['Gesamt- leistung (MW)'] = [float(str(i).replace(",", ".")) for i in new_data['Gesamt- leistung (MW)']]



new_data_numbers=new_data.groupby(['Land- kreis']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
new_data_numbers.head(10)
# Out:
#              Anzahl
# Land- kreis
# HEI             854
# NF              854
# HRO             702
# UM              667
# PR              577
# PB              544
# SL              521
# CUX             516
# EL              499
# AN              490

# %%
new_data_mw=new_data.groupby(['Land- kreis']).agg({'Gesamt- leistung (MW)':'sum'}).sort_values(by='Gesamt- leistung (MW)',ascending=False)
new_data_mw.head(10)
# Out:
#              Gesamt- leistung (MW)
# Land- kreis
# NF                        2480.540
# HEI                       2312.723
# UM                        1666.850
# HRO                       1591.120
# SL                        1448.220
# PB                        1358.505
# EL                        1253.450
# PR                        1240.700
# OS                        1132.780
# AN                        1035.160

# %%
new_data['Latitude'] = new_data['Latitude'].str.split('N', n=1).str.get(0)
new_data['Longitude'] = new_data['Longitude'].str.split('O', n=1).str.get(0)
new_data.head()
# Out:
#   Baujahr  Gesamt- leistung (MW)  Anzahl              Typ (WKA)  \
# 0    2017                  2.000       1         Qreon Q82 (1×)
# 1    2017                  2.000       1         Qreon Q82 (1×)
# 2    2003                  1.500       1       Südwind S70 (1×)
# 3    1999                  2.300       1   Enercon E-70 E4 (1×)
# 4    1990                  0.095       1  Reymo DANmark 22 (1×)
#
#                        Ort Land- kreis  \
# 0                Karlsruhe          KA
# 1                Karlsruhe          KA
# 2  Bad Peterstal-Griesbach          OG
# 3              Römlinsdorf         FDS
# 4          Hausen vor Wald          VS
#
#                       Projektierer / Betreiber  \
# 0                               Fraunhofer ICT
# 1                               Fraunhofer ICT
# 2  Schmalz, Windenergieanlage „Bei der Schanz“
# 3  Windkraft Römlinsdorf, Stadtwerke Stuttgart
# 4                   Pionier-Windmühle Auenberg
#
#                                          Bemerkungen      Latitude  \
# 0  Forschungsprojekt mit kombiniertem Batteriespe...    49° 1′ 9″
# 1  Forschungsprojekt mit kombiniertem Batteriespe...    49° 1′ 9″
# 2  errichtet an der Schwarzwaldhochstraße im Bere...  48° 28′ 22″
# 3  Repowering 2013 (1× Enercon E-70 E4 statt 1× F...   48° 20′ 0″
# 4  (*); erste kommerziell betriebene Windkraftanl...  47° 53′ 19″
#
#       Longitude   Code           NUTS 1.1   NUTS 2.1                    Name
# 0    8° 31′ 4″   DE123  Baden-Württemberg  Karlsruhe    Karlsruhe, Landkreis
# 1    8° 31′ 4″   DE122  Baden-Württemberg  Karlsruhe   Karlsruhe, Stadtkreis
# 2    8° 16′ 7″   DE134  Baden-Württemberg   Freiburg            Ortenaukreis
# 3   8° 28′ 34″   DE12C  Baden-Württemberg  Karlsruhe            Freudenstadt
# 4   8° 28′ 24″   DE136  Baden-Württemberg   Freiburg  Schwarzwald-Baar-Kreis

# %%
new_data_coord=new_data.groupby(['Latitude','Longitude', 'Land- kreis', 'Name', 'Code']).agg({'Anzahl':'sum'}).sort_values(by='Anzahl',ascending=False)
new_data_coord.head(10)
# Out:
#                                                                         Anzahl
# Latitude     Longitude     Land- kreis Name                      Code
# 53° 36′ 37″   7° 25′ 45″   WTM         Wittmund                  DE94H     144
# 53° 58′ 26″   8° 56′ 0″    HEI         Dithmarschen              DEF05     135
# 51° 52′ 34″   13° 31′ 15″  LIF         Lichtenfels               DE24C     114
# 52° 0′ 3″     12° 49′ 31″  AN          Ansbach, Kreisfreie Stadt DE251     114
#                                        Ansbach, Landkreis        DE256     114
# 53° 21′ 24″   13° 56′ 0″   UM          Uckermark                 DE40I     113
# 54° 36′ 24″   8° 54′ 8″    NF          Nordfriesland             DEF07      88
# 51.638056°    8.915°       PB          Paderborn                 DEA47      85
# 51° 7′ 32″    11° 57′ 31″  BLK         Burgenlandkreis           DEE08      82
# 52° 32′ 14″   12° 52′ 11″  HVL         Havelland                 DE408      82

# %%
new_data.to_csv('Landkreis_id-windanlage.csv')

# %%
new_data_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4692 entries, ('53°\xa036′\xa037″\xa0', ' 7°\xa025′\xa045″\xa0', 'WTM', 'Wittmund', 'DE94H') to ('50.886667°\xa0', ' 8.298056°\xa0', 'SI', 'Siegen-Wittgenstein', 'DEA5A')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Anzahl  4692 non-null   int64
# dtypes: int64(1)
# memory usage: 152.6+ KB
